# %%
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
# from adjustText import adjust_text
from Bio import SeqIO
from Bio.Seq import Seq
# %matplotlib inline

# import gzip
# from cyvcf2 import VCF

from matplotlib import gridspec
from matplotlib.gridspec import GridSpec

from itertools import combinations
from ast import literal_eval

import sys
import os

home_dir = '~/Documents/Stanford/Research/EvolvingFront'
home_dir = os.path.expanduser(home_dir)

# tools_path = f'{home_dir}/code/processing/tools/tools.py'
# sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
# import tools as tools

# atish_assay_path =f'2%5%_FitnessMeasurement/code/fitness_assay_grantedits.py'
# sys.path.append(os.path.dirname(os.path.expanduser(atish_assay_path)))
# import fitness_assay_grantedits as atish

tools_path = f'{home_dir}/code/processing/tools/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools as tools

sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

# %%
from matplotlib.collections import LineCollection

def multiline(xs, ys, c, ax=None, **kwargs):
    """Plot lines with different colorings

    Parameters
    ----------
    xs : iterable container of x coordinates
    ys : iterable container of y coordinates
    c : iterable container of numbers mapped to colormap
    ax (optional): Axes to plot on.
    kwargs (optional): passed to LineCollection

    Notes:
        len(xs) == len(ys) == len(c) is the number of line segments
        len(xs[i]) == len(ys[i]) is the number of points for each line (indexed by i)

    Returns
    -------
    lc : LineCollection instance.
    """

    # find axes
    ax = plt.gca() if ax is None else ax

    # create LineCollection
    segments = [np.column_stack([x, y]) for x, y in zip(xs, ys)]
    lc = LineCollection(segments, **kwargs)

    # set coloring of line segments
    #    Note: I get an error if I pass c as a list here... not sure why.
    lc.set_array(np.asarray(c))

    # add lines to axes and rescale 
    #    Note: adding a collection doesn't autoscalee xlim/ylim
    ax.add_collection(lc)
    ax.autoscale()
    return lc

# %%
ancestor = 'Ira1_Mis'
evolution_condition = 'Evo2D'

ancestor_colors = {'CYR1':tools.anc_color_map['CYR1'],
                   'GPB2':tools.anc_color_map['GPB2'],
                   'TOR1':tools.anc_color_map['TOR1'],
                    'EVO1D_IRA1_MIS':'orange',
                   'EVO1D_IRA1_NON':tools.anc_color_map['IRA1_NON'],
                  'unknown':'gray'}

condition = 'Evo1D_IRAs'
reps = [1,2]
timepoints = [0,1,4,7,10,13,16,19,22,24]
ancestors_included = ['EVO1D_IRA1_MIS','EVO1D_IRA1_NON']


# condition = 'Evo1D_TCG'
# reps = [1,2]
# timepoints = [0,1,4,8,10,13,16,19,22,24]
# ancestors_included = ['CYR1','GPB2','TOR1']

# condition = 'Evo2D_Ira1_Mis'
# condition = 'Evo2D_Ira1_Non'
# reps = [1,2]
# timepoints = [0,1,4,7,10,13,17,21,25]

# condition = 'Evo3D_Ira1_Mis'
# # condition = 'Evo3D_Ira1_Non'
# reps = [1,2,3]
# timepoints = [0,1,4,7,10,14,17,21]

# # condition = 'Evo3D_TCG'
# # reps = [1,2]
# # timepoints = [0,1,4,7,10,14,17,21]



all_samples = []
for time in timepoints:
    if time == 0:
        all_samples.append(f'{condition}_0_0')
    else:
        for rep in reps:
            all_samples.append(f'{condition}_{rep}_{time}')

# %%
df = p.read_csv(f'{home_dir}/data/EvolutionTrajectory_counts/{condition}_counts_curated.csv')

ancs = []
for low_bc in df['low_diversity_BC'].values:
    if low_bc in tools.new_lowcomplexity_bc_to_entry_dict:
        ancs.append(tools.new_lowcomplexity_bc_to_entry_dict[low_bc])
    else:
        ancs.append('unknown')
    
df['ancestor'] = ancs
df = df.sort_values(['ancestor','fused_bc'])

# %%
color_set = {'CYR1':'Reds','GPB2':'Greens','TOR1':'Purples','unknown':'Greys',
            'EVO1D_IRA1_MIS':'Oranges','EVO1D_IRA1_NON':'Blues'}

color_map  = []

n_colors = 15

for a,anc in enumerate(df['ancestor'].values):
    color_map.append(sns.color_palette(color_set[anc],n_colors)[(a%n_colors)])

# %%
coverage_cutoff = 1e5
# coverage_cutoff = 100



for rep in reps:
    
    plt.figure()
    
    fig = plt.figure(figsize=(16,8))
    outer_gs = gridspec.GridSpec(1, 2,width_ratios=[2,2])
    
    inner_gs = gridspec.GridSpecFromSubplotSpec(2,2,subplot_spec = outer_gs[1],wspace=0.25,hspace=0.25)
    
    exclude_times = []
    these_timepoints = [time for time in timepoints if time not in exclude_times]

    these_times = [f'{condition}_{rep}_{time}_count' for time in these_timepoints if time != 0]
    these_times = [f'{condition}_0_0_count'] + these_times

    these_counts = df[these_times].values
    
    these_freqs = these_counts/np.nansum(these_counts,axis=0)
#     these_freqs = these_counts[:1000,:]/np.nansum(these_counts[:1000,:],axis=0)
    print(np.nansum(these_counts,axis=0))
    
    these_ts = np.tile(timepoints,these_counts.shape[0]).reshape(these_counts.shape)
    these_freqs = (these_counts/np.nansum(these_counts,axis=0))
    these_freqs = these_freqs
    
    fig.add_subplot(outer_gs[0])
    
    xs = these_ts
    ys= these_freqs
    segments = [np.column_stack([x, y]) for x, y in zip(xs, ys)]
    lc = LineCollection(segments,colors=np.asarray(color_map),lw=0.5)

    # set coloring of line segments
    #    Note: I get an error if I pass c as a list here... not sure why.
#     lc.set_array(np.asarray(c))

    # add lines to axes and rescale 
    #    Note: adding a collection doesn't autoscalee xlim/ylim
    plt.gca().add_collection(lc)
    plt.gca().autoscale()
    
    plt.yscale('log')
    plt.xlabel('Transfer')
    plt.ylabel('Frequency')
    plt.xticks(timepoints,timepoints)
    
    for a,anc in enumerate(ancestors_included):
        
        ax = fig.add_subplot(inner_gs[a])
        
        this_anc_locs = np.where(df['ancestor']==anc)[0]
        
        this_anc = df[df['ancestor']==anc]
        
        these_counts = this_anc[these_times].values
        
        these_freqs = these_counts/np.nansum(these_counts,axis=0)

        these_ts = np.tile(timepoints,these_counts.shape[0]).reshape(these_counts.shape)
        these_freqs = (these_counts/np.nansum(these_counts,axis=0))
        these_freqs = these_freqs
        
        xs = these_ts
        ys= these_freqs
        segments = [np.column_stack([x, y]) for x, y in zip(xs, ys)]
        lc = LineCollection(segments,colors=np.asarray(color_map)[this_anc_locs],lw=0.5)
        
        ax.add_collection(lc)
        ax.autoscale()
        
        plt.yscale('log')
        plt.xlabel('Transfer')
        plt.ylabel('Frequency')
        plt.xticks(timepoints,timepoints)
        
        
    ax = fig.add_subplot(inner_gs[a+1])
    
    unique_ancestors_here = np.unique(df['ancestor'].values)
    anc_freqs = np.zeros((len(unique_ancestors_here),len(timepoints)))

    for a,anc in enumerate(unique_ancestors_here):

        this_anc = df[df['ancestor']==anc]
        these_counts = this_anc[these_times].values

        anc_freqs[a,:] = np.sum(these_counts,axis=0)

    c_map = [ancestor_colors[anc] for anc in unique_ancestors_here]

    these_ts = np.tile(timepoints,anc_freqs.shape[0]).reshape(anc_freqs.shape)
    anc_freqs = anc_freqs/np.sum(anc_freqs,axis=0)
    # these_freqs = these_freqs

    xs = these_ts
    ys= anc_freqs
    segments = [np.column_stack([x, y]) for x, y in zip(xs, ys)]
    lc = LineCollection(segments,colors=np.asarray(c_map),lw=1)

    plt.gca().add_collection(lc)
    plt.gca().autoscale()
    plt.xticks(timepoints,timepoints)
    plt.ylabel('Genotype Frequency')
    plt.xlabel('Transfer')
    
    plt.savefig(f'{home_dir}/figures/analysis/evolution_trajectories/multi-genotype_trajectories_{condition}_{rep}.pdf',bbox_inches='tight')

# %%
unique_ancestors_here
# Out:
# array(['CYR1', 'EVO1D_IRA1_MIS', 'EVO1D_IRA1_NON', 'GPB2', 'TOR1',
#        'unknown'], dtype=object)

# %%
# plt.plot(timepoints,anc_freqs.swapaxes(0,1),colors=np.asarray(c_map))
# Out:
# 0 CYR1
# 1 EVO1D_IRA1_MIS
# 2 EVO1D_IRA1_NON
# 3 GPB2
# 4 TOR1
# 5 unknown
# [[1.000000e+00 0.000000e+00 5.000000e+00 5.000000e+00 7.000000e+00
#   2.000000e+00 3.000000e+00 4.000000e+00 2.000000e+00 1.030000e+02]
#  [1.967150e+06 2.363447e+06 2.445726e+06 1.983422e+06 1.860850e+06
#   1.534573e+06 1.223795e+06 9.562040e+05 6.676020e+05 3.450280e+05]
#  [1.259490e+06 9.683750e+05 1.174667e+06 1.258742e+06 1.584119e+06
#   1.794059e+06 2.087288e+06 2.641669e+06 3.353629e+06 2.752615e+06]
#  [1.000000e+00 2.000000e+00 3.000000e+00 5.000000e+00 9.000000e+00
#   2.000000e+00 1.000000e+00 3.000000e+00 0.000000e+00 8.100000e+01]
#  [2.000000e+00 0.000000e+00 3.000000e+00 4.000000e+00 1.000000e+00
#   1.000000e+00 4.000000e+00 1.000000e+00 0.000000e+00 4.800000e+01]
#  [2.687000e+03 2.556000e+03 3.056000e+03 2.890000e+03 4.192000e+03
#   6.913000e+03 1.420100e+04 3.737700e+04 8.536300e+04 9.519400e+04]]
# ([<matplotlib.axis.XTick at 0x1526b3c40>,
#   <matplotlib.axis.XTick at 0x1526b3c10>,
#   <matplotlib.axis.XTick at 0x1526b32e0>,
#   <matplotlib.axis.XTick at 0x1526eb6a0>,
#   <matplotlib.axis.XTick at 0x1526ebdf0>,
#   <matplotlib.axis.XTick at 0x1526ebb80>,
#   <matplotlib.axis.XTick at 0x1526f3730>,
#   <matplotlib.axis.XTick at 0x1526f3e80>,
#   <matplotlib.axis.XTick at 0x1526f7610>,
#   <matplotlib.axis.XTick at 0x1526f7d60>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(4, 0, '4'),
#   Text(7, 0, '7'),
#   Text(10, 0, '10'),
#   Text(13, 0, '13'),
#   Text(16, 0, '16'),
#   Text(19, 0, '19'),
#   Text(22, 0, '22'),
#   Text(24, 0, '24')])

# %%
anc_freqs/np.sum(anc_freqs,axis=0)
# Out:
# array([[3.09661661e-07, 0.00000000e+00, 1.37989656e-06, 1.54079976e-06,
#         2.02946905e-06, 5.99601265e-07, 9.02176410e-07, 1.10033456e-06,
#         4.87021368e-07, 3.22573674e-05],
#        [6.09150936e-01, 7.08811533e-01, 6.74969780e-01, 6.11211229e-01,
#         5.39505355e-01, 4.60065956e-01, 3.68026327e-01, 2.63036076e-01,
#         1.62568220e-01, 1.08055291e-01],
#        [3.90015765e-01, 2.90421308e-01, 3.24183791e-01, 3.87893875e-01,
#         4.59274355e-01, 5.37860023e-01, 6.27700665e-01, 7.26679922e-01,
#         8.16644491e-01, 8.62059354e-01],
#        [3.09661661e-07, 5.99811659e-07, 8.27937938e-07, 1.54079976e-06,
#         2.60931735e-06, 5.99601265e-07, 3.00725470e-07, 8.25250918e-07,
#         0.00000000e+00, 2.53674443e-05],
#        [6.19323321e-07, 0.00000000e+00, 8.27937938e-07, 1.23263981e-06,
#         2.89924150e-07, 2.99800633e-07, 1.20290188e-06, 2.75083639e-07,
#         0.00000000e+00, 1.50325596e-05],
#        [8.32060882e-04, 7.66559300e-04, 8.43392779e-04, 8.90582262e-04,
#         1.21536204e-03, 2.07252177e-03, 4.27060240e-03, 1.02818012e-02,
#         2.07868025e-02, 2.98126974e-02]])

# %%
coverage_cutoff = 1e5
# coverage_cutoff = 100

for rep in reps:
    exclude_times = []
    these_timepoints = [time for time in timepoints if time not in exclude_times]

    these_times = [f'{condition}_{rep}_{time}_count' for time in these_timepoints if time != 0]
    these_times = [f'{condition}_0_0_count'] + these_times

    these_counts = df[these_times].values
    

    these_freqs = these_counts/np.nansum(these_counts,axis=0)
#     these_freqs = these_counts[:1000,:]/np.nansum(these_counts[:1000,:],axis=0)
    print(np.nansum(these_counts,axis=0))
    
    
    low_coverage = np.where(np.nansum(these_counts,axis=0)<coverage_cutoff)[0]
    
    these_freqs = np.delete(these_freqs,low_coverage,axis=1)
    these_times = np.delete(these_times,low_coverage)
    these_timepoints = np.delete(these_timepoints,low_coverage)
    
    plt.figure()
    plt.stackplot(these_timepoints,these_freqs,lw=0,color=color_map)
    
#     plt.figure()
#     plt.plot(these_timepoints,these_freqs.swapaxes(0,1)[:,:],alpha=0.1)
#     plt.yscale('log')
    plt.xticks(these_timepoints,these_timepoints)
#     plt.xlabel('Transfer')
    plt.ylabel('Frequency')
    plt.title(f'{condition} - Rep {rep}')
#     plt.savefig(f'{condition}_{rep}_trajectories_dark.pdf',bbox_inches='tight')
    plt.savefig(f'{home_dir}/figures/analysis/evolution_trajectories/{condition}_{rep}_muller.pdf',bbox_inches='tight')
    plt.savefig(f'{home_dir}/figures/analysis/evolution_trajectories/{condition}_{rep}_muller.png',dpi=300,bbox_inches='tight')
# Out:
# [ 707082.  742966.  849992.  932954. 1279072. 1658039. 1682808. 2313036.
#  3076076. 2832664.]

# %%
# these_timepoints

# %%
these_counts[:100,:].shape
# Out:
# (100, 9)

# %%
# these_freqs = these_counts[:,:100]/np.nansum(these_counts[:,:100],axis=0)

# %%
plt.stackplot(these_timepoints,these_freqs)
# Out:
# [<matplotlib.collections.PolyCollection at 0x17cc7a310>,
#  <matplotlib.collections.PolyCollection at 0x17cc7a5e0>,
#  <matplotlib.collections.PolyCollection at 0x17cc7a9d0>,
#  <matplotlib.collections.PolyCollection at 0x17cc7ad90>,
#  <matplotlib.collections.PolyCollection at 0x17ccc4190>,
#  <matplotlib.collections.PolyCollection at 0x17ccc4550>,
#  <matplotlib.collections.PolyCollection at 0x17cc7a5b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccc4ca0>,
#  <matplotlib.collections.PolyCollection at 0x17ccd70a0>,
#  <matplotlib.collections.PolyCollection at 0x17ccd7460>,
#  <matplotlib.collections.PolyCollection at 0x17cc7a2b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccd7bb0>,
#  <matplotlib.collections.PolyCollection at 0x17ccd7f70>,
#  <matplotlib.collections.PolyCollection at 0x17cce2370>,
#  <matplotlib.collections.PolyCollection at 0x17cce2730>,
#  <matplotlib.collections.PolyCollection at 0x17cce2af0>,
#  <matplotlib.collections.PolyCollection at 0x17cce2eb0>,
#  <matplotlib.collections.PolyCollection at 0x17ccef2b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccef670>,
#  <matplotlib.collections.PolyCollection at 0x17ccefa30>,
#  <matplotlib.collections.PolyCollection at 0x17ccefdf0>,
#  <matplotlib.collections.PolyCollection at 0x17ccfd1f0>,
#  <matplotlib.collections.PolyCollection at 0x17ccfd5b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccfd970>,
#  <matplotlib.collections.PolyCollection at 0x17ccfdd30>,
#  <matplotlib.collections.PolyCollection at 0x17cc87130>,
#  <matplotlib.collections.PolyCollection at 0x17cc874f0>,
#  <matplotlib.collections.PolyCollection at 0x17cc878b0>,
#  <matplotlib.collections.PolyCollection at 0x17cc87c70>,
#  <matplotlib.collections.PolyCollection at 0x17cc94070>,
#  <matplotlib.collections.PolyCollection at 0x17cc94430>,
#  <matplotlib.collections.PolyCollection at 0x17cc947f0>,
#  <matplotlib.collections.PolyCollection at 0x17cc94bb0>,
#  <matplotlib.collections.PolyCollection at 0x17cc94f70>,
#  <matplotlib.collections.PolyCollection at 0x17cca3370>,
#  <matplotlib.collections.PolyCollection at 0x17cca3730>,
#  <matplotlib.collections.PolyCollection at 0x17cca3af0>,
#  <matplotlib.collections.PolyCollection at 0x17cca3eb0>,
#  <matplotlib.collections.PolyCollection at 0x17ccae2b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccae670>,
#  <matplotlib.collections.PolyCollection at 0x17ccaea30>,
#  <matplotlib.collections.PolyCollection at 0x17ccaedf0>,
#  <matplotlib.collections.PolyCollection at 0x17ccbc1f0>,
#  <matplotlib.collections.PolyCollection at 0x17ccbc5b0>,
#  <matplotlib.collections.PolyCollection at 0x17ccbc970>,
#  <matplotlib.collections.PolyCollection at 0x17ccbcd30>,
#  <matplotlib.collections.PolyCollection at 0x1768ea130>,
#  <matplotlib.collections.PolyCollection at 0x1768ea4f0>,
#  <matplotlib.collections.PolyCollection at 0x1768ea8b0>,
#  <matplotlib.collections.PolyCollection at 0x1768eac70>,
#  <matplotlib.collections.PolyCollection at 0x1768f7070>,
#  <matplotlib.collections.PolyCollection at 0x1768f7430>,
#  <matplotlib.collections.PolyCollection at 0x1768f77f0>,
#  <matplotlib.collections.PolyCollection at 0x1768f7bb0>,
#  <matplotlib.collections.PolyCollection at 0x1768f7f70>,
#  <matplotlib.collections.PolyCollection at 0x176902370>,
#  <matplotlib.collections.PolyCollection at 0x176902730>,
#  <matplotlib.collections.PolyCollection at 0x176902af0>,
#  <matplotlib.collections.PolyCollection at 0x176902eb0>,
#  <matplotlib.collections.PolyCollection at 0x17690e2b0>,
#  <matplotlib.collections.PolyCollection at 0x17690e670>,
#  <matplotlib.collections.PolyCollection at 0x17690ea30>,
#  <matplotlib.collections.PolyCollection at 0x17690edf0>,
#  <matplotlib.collections.PolyCollection at 0x17691b1f0>,
#  <matplotlib.collections.PolyCollection at 0x17691b5b0>,
#  <matplotlib.collections.PolyCollection at 0x17691b970>,
#  <matplotlib.collections.PolyCollection at 0x17691bd30>,
#  <matplotlib.collections.PolyCollection at 0x176927130>,
#  <matplotlib.collections.PolyCollection at 0x1769274f0>,
#  <matplotlib.collections.PolyCollection at 0x1769278b0>,
#  <matplotlib.collections.PolyCollection at 0x176927c70>,
#  <matplotlib.collections.PolyCollection at 0x176936070>,
#  <matplotlib.collections.PolyCollection at 0x176936430>,
#  <matplotlib.collections.PolyCollection at 0x1769367f0>,
#  <matplotlib.collections.PolyCollection at 0x176936bb0>,
#  <matplotlib.collections.PolyCollection at 0x176936f70>,
#  <matplotlib.collections.PolyCollection at 0x176942370>,
#  <matplotlib.collections.PolyCollection at 0x176942730>,
#  <matplotlib.collections.PolyCollection at 0x176942af0>,
#  <matplotlib.collections.PolyCollection at 0x176942eb0>,
#  <matplotlib.collections.PolyCollection at 0x17694b2b0>,
#  <matplotlib.collections.PolyCollection at 0x17694b670>,
#  <matplotlib.collections.PolyCollection at 0x17694ba30>,
#  <matplotlib.collections.PolyCollection at 0x17694bdf0>,
#  <matplotlib.collections.PolyCollection at 0x1769591f0>,
#  <matplotlib.collections.PolyCollection at 0x1769595b0>,
#  <matplotlib.collections.PolyCollection at 0x176959970>,
#  <matplotlib.collections.PolyCollection at 0x176959d30>,
#  <matplotlib.collections.PolyCollection at 0x176966130>,
#  <matplotlib.collections.PolyCollection at 0x1769664f0>,
#  <matplotlib.collections.PolyCollection at 0x1769668b0>,
#  <matplotlib.collections.PolyCollection at 0x176966c70>,
#  <matplotlib.collections.PolyCollection at 0x176972070>,
#  <matplotlib.collections.PolyCollection at 0x176972430>,
#  <matplotlib.collections.PolyCollection at 0x1769727f0>,
#  <matplotlib.collections.PolyCollection at 0x176972bb0>,
#  <matplotlib.collections.PolyCollection at 0x176972f70>,
#  <matplotlib.collections.PolyCollection at 0x17697f370>,
#  <matplotlib.collections.PolyCollection at 0x17697f730>,
#  <matplotlib.collections.PolyCollection at 0x17697faf0>,
#  <matplotlib.collections.PolyCollection at 0x17697feb0>,
#  <matplotlib.collections.PolyCollection at 0x17698b2b0>,
#  <matplotlib.collections.PolyCollection at 0x17698b670>,
#  <matplotlib.collections.PolyCollection at 0x17698ba30>,
#  <matplotlib.collections.PolyCollection at 0x17698bdf0>,
#  <matplotlib.collections.PolyCollection at 0x1769981f0>,
#  <matplotlib.collections.PolyCollection at 0x1769985b0>,
#  <matplotlib.collections.PolyCollection at 0x176998970>,
#  <matplotlib.collections.PolyCollection at 0x176998d30>,
#  <matplotlib.collections.PolyCollection at 0x1769a4130>,
#  <matplotlib.collections.PolyCollection at 0x1769a44f0>,
#  <matplotlib.collections.PolyCollection at 0x1769a48b0>,
#  <matplotlib.collections.PolyCollection at 0x1769a4c70>,
#  <matplotlib.collections.PolyCollection at 0x1769b2070>,
#  <matplotlib.collections.PolyCollection at 0x1769b2430>,
#  <matplotlib.collections.PolyCollection at 0x1769b27f0>,
#  <matplotlib.collections.PolyCollection at 0x1769b2bb0>,
#  <matplotlib.collections.PolyCollection at 0x1769b2f70>,
#  <matplotlib.collections.PolyCollection at 0x1769bd370>,
#  <matplotlib.collections.PolyCollection at 0x1769bd730>,
#  <matplotlib.collections.PolyCollection at 0x1769bdaf0>,
#  <matplotlib.collections.PolyCollection at 0x1769bdeb0>,
#  <matplotlib.collections.PolyCollection at 0x1769c72b0>,
#  <matplotlib.collections.PolyCollection at 0x1769c7670>,
#  <matplotlib.collections.PolyCollection at 0x1769c7a30>,
#  <matplotlib.collections.PolyCollection at 0x1769c7df0>,
#  <matplotlib.collections.PolyCollection at 0x1769d61f0>,
#  <matplotlib.collections.PolyCollection at 0x1769d65b0>,
#  <matplotlib.collections.PolyCollection at 0x1769d6970>,
#  <matplotlib.collections.PolyCollection at 0x1769d6d30>,
#  <matplotlib.collections.PolyCollection at 0x1769e2130>,
#  <matplotlib.collections.PolyCollection at 0x1769e24f0>,
#  <matplotlib.collections.PolyCollection at 0x1769e28b0>,
#  <matplotlib.collections.PolyCollection at 0x1769e2c70>,
#  <matplotlib.collections.PolyCollection at 0x1769f0070>,
#  <matplotlib.collections.PolyCollection at 0x1769f0430>,
#  <matplotlib.collections.PolyCollection at 0x1769f07f0>,
#  <matplotlib.collections.PolyCollection at 0x1769f0bb0>,
#  <matplotlib.collections.PolyCollection at 0x1769f0f70>,
#  <matplotlib.collections.PolyCollection at 0x1769fc370>,
#  <matplotlib.collections.PolyCollection at 0x1769fc730>,
#  <matplotlib.collections.PolyCollection at 0x1769fcaf0>,
#  <matplotlib.collections.PolyCollection at 0x1769fceb0>,
#  <matplotlib.collections.PolyCollection at 0x176a092b0>,
#  <matplotlib.collections.PolyCollection at 0x176a09670>,
#  <matplotlib.collections.PolyCollection at 0x176a09a30>,
#  <matplotlib.collections.PolyCollection at 0x176a09df0>,
#  <matplotlib.collections.PolyCollection at 0x176a161f0>,
#  <matplotlib.collections.PolyCollection at 0x176a165b0>,
#  <matplotlib.collections.PolyCollection at 0x176a16970>,
#  <matplotlib.collections.PolyCollection at 0x176a16d30>,
#  <matplotlib.collections.PolyCollection at 0x176a22130>,
#  <matplotlib.collections.PolyCollection at 0x176a224f0>,
#  <matplotlib.collections.PolyCollection at 0x176a228b0>,
#  <matplotlib.collections.PolyCollection at 0x176a22c70>,
#  <matplotlib.collections.PolyCollection at 0x176a2f070>,
#  <matplotlib.collections.PolyCollection at 0x176a2f430>,
#  <matplotlib.collections.PolyCollection at 0x176a2f7f0>,
#  <matplotlib.collections.PolyCollection at 0x176a2fbb0>,
#  <matplotlib.collections.PolyCollection at 0x176a2ff70>,
#  <matplotlib.collections.PolyCollection at 0x176a3c370>,
#  <matplotlib.collections.PolyCollection at 0x176a3c730>,
#  <matplotlib.collections.PolyCollection at 0x176a3caf0>,
#  <matplotlib.collections.PolyCollection at 0x176a3ceb0>,
#  <matplotlib.collections.PolyCollection at 0x176a462b0>,
#  <matplotlib.collections.PolyCollection at 0x176a46670>,
#  <matplotlib.collections.PolyCollection at 0x176a46a30>,
#  <matplotlib.collections.PolyCollection at 0x176a46df0>,
#  <matplotlib.collections.PolyCollection at 0x176a531f0>,
#  <matplotlib.collections.PolyCollection at 0x176a535b0>,
#  <matplotlib.collections.PolyCollection at 0x176a53970>,
#  <matplotlib.collections.PolyCollection at 0x176a53d30>,
#  <matplotlib.collections.PolyCollection at 0x176a60130>,
#  <matplotlib.collections.PolyCollection at 0x176a604f0>,
#  <matplotlib.collections.PolyCollection at 0x176a608b0>,
#  <matplotlib.collections.PolyCollection at 0x176a60c70>,
#  <matplotlib.collections.PolyCollection at 0x176a6e070>,
#  <matplotlib.collections.PolyCollection at 0x176a6e430>,
#  <matplotlib.collections.PolyCollection at 0x176a6e7f0>,
#  <matplotlib.collections.PolyCollection at 0x176a6ebb0>,
#  <matplotlib.collections.PolyCollection at 0x176a6ef70>,
#  <matplotlib.collections.PolyCollection at 0x176a7a370>,
#  <matplotlib.collections.PolyCollection at 0x176a7a730>,
#  <matplotlib.collections.PolyCollection at 0x176a7aaf0>,
#  <matplotlib.collections.PolyCollection at 0x176a7aeb0>,
#  <matplotlib.collections.PolyCollection at 0x176a862b0>,
#  <matplotlib.collections.PolyCollection at 0x176a86670>,
#  <matplotlib.collections.PolyCollection at 0x176a86a30>,
#  <matplotlib.collections.PolyCollection at 0x176a86df0>,
#  <matplotlib.collections.PolyCollection at 0x176a931f0>,
#  <matplotlib.collections.PolyCollection at 0x176a935b0>,
#  <matplotlib.collections.PolyCollection at 0x176a93970>,
#  <matplotlib.collections.PolyCollection at 0x176a93d30>,
#  <matplotlib.collections.PolyCollection at 0x176a9f130>,
#  <matplotlib.collections.PolyCollection at 0x176a9f4f0>,
#  <matplotlib.collections.PolyCollection at 0x176a9f8b0>,
#  <matplotlib.collections.PolyCollection at 0x176a9fc70>,
#  <matplotlib.collections.PolyCollection at 0x176aad070>,
#  <matplotlib.collections.PolyCollection at 0x176aad430>,
#  <matplotlib.collections.PolyCollection at 0x176aad7f0>,
#  <matplotlib.collections.PolyCollection at 0x176aadbb0>,
#  <matplotlib.collections.PolyCollection at 0x176aadf70>,
#  <matplotlib.collections.PolyCollection at 0x176ab9370>,
#  <matplotlib.collections.PolyCollection at 0x176ab9730>,
#  <matplotlib.collections.PolyCollection at 0x176ab9af0>,
#  <matplotlib.collections.PolyCollection at 0x176ab9eb0>,
#  <matplotlib.collections.PolyCollection at 0x176ac32b0>,
#  <matplotlib.collections.PolyCollection at 0x176ac3670>,
#  <matplotlib.collections.PolyCollection at 0x176ac3a30>,
#  <matplotlib.collections.PolyCollection at 0x176ac3df0>,
#  <matplotlib.collections.PolyCollection at 0x176ad01f0>,
#  <matplotlib.collections.PolyCollection at 0x176ad05b0>,
#  <matplotlib.collections.PolyCollection at 0x176ad0970>,
#  <matplotlib.collections.PolyCollection at 0x176ad0d30>,
#  <matplotlib.collections.PolyCollection at 0x176ade130>,
#  <matplotlib.collections.PolyCollection at 0x176ade4f0>,
#  <matplotlib.collections.PolyCollection at 0x176ade8b0>,
#  <matplotlib.collections.PolyCollection at 0x176adec70>,
#  <matplotlib.collections.PolyCollection at 0x176aec070>,
#  <matplotlib.collections.PolyCollection at 0x176aec430>,
#  <matplotlib.collections.PolyCollection at 0x176aec7f0>,
#  <matplotlib.collections.PolyCollection at 0x176aecbb0>,
#  <matplotlib.collections.PolyCollection at 0x176aecf70>,
#  <matplotlib.collections.PolyCollection at 0x176af7370>,
#  <matplotlib.collections.PolyCollection at 0x176af7730>,
#  <matplotlib.collections.PolyCollection at 0x176af7af0>,
#  <matplotlib.collections.PolyCollection at 0x176af7eb0>,
#  <matplotlib.collections.PolyCollection at 0x176b032b0>,
#  <matplotlib.collections.PolyCollection at 0x176b03670>,
#  <matplotlib.collections.PolyCollection at 0x176b03a30>,
#  <matplotlib.collections.PolyCollection at 0x176b03df0>,
#  <matplotlib.collections.PolyCollection at 0x176b111f0>,
#  <matplotlib.collections.PolyCollection at 0x176b115b0>,
#  <matplotlib.collections.PolyCollection at 0x176b11970>,
#  <matplotlib.collections.PolyCollection at 0x176b11d30>,
#  <matplotlib.collections.PolyCollection at 0x176b1c130>,
#  <matplotlib.collections.PolyCollection at 0x176b1c4f0>,
#  <matplotlib.collections.PolyCollection at 0x176b1c8b0>,
#  <matplotlib.collections.PolyCollection at 0x176b1cc70>,
#  <matplotlib.collections.PolyCollection at 0x176b2c070>,
#  <matplotlib.collections.PolyCollection at 0x176b2c430>,
#  <matplotlib.collections.PolyCollection at 0x176b2c7f0>,
#  <matplotlib.collections.PolyCollection at 0x176b2cbb0>,
#  <matplotlib.collections.PolyCollection at 0x176b2cf70>,
#  <matplotlib.collections.PolyCollection at 0x176b39370>,
#  <matplotlib.collections.PolyCollection at 0x176b39730>,
#  <matplotlib.collections.PolyCollection at 0x176b39af0>,
#  <matplotlib.collections.PolyCollection at 0x176b39eb0>,
#  <matplotlib.collections.PolyCollection at 0x176b432b0>,
#  <matplotlib.collections.PolyCollection at 0x176b43670>,
#  <matplotlib.collections.PolyCollection at 0x176b43a30>,
#  <matplotlib.collections.PolyCollection at 0x176b43df0>,
#  <matplotlib.collections.PolyCollection at 0x176b4f1f0>,
#  <matplotlib.collections.PolyCollection at 0x176b4f5b0>,
#  <matplotlib.collections.PolyCollection at 0x176b4f970>,
#  <matplotlib.collections.PolyCollection at 0x176b4fd30>,
#  <matplotlib.collections.PolyCollection at 0x176b5f130>,
#  <matplotlib.collections.PolyCollection at 0x176b5f4f0>,
#  <matplotlib.collections.PolyCollection at 0x176b5f8b0>,
#  <matplotlib.collections.PolyCollection at 0x176b5fc70>,
#  <matplotlib.collections.PolyCollection at 0x176b6c070>,
#  <matplotlib.collections.PolyCollection at 0x176b6c430>,
#  <matplotlib.collections.PolyCollection at 0x176b6c7f0>,
#  <matplotlib.collections.PolyCollection at 0x176b6cbb0>,
#  <matplotlib.collections.PolyCollection at 0x176b6cf70>,
#  <matplotlib.collections.PolyCollection at 0x176b79370>,
#  <matplotlib.collections.PolyCollection at 0x176b79730>,
#  <matplotlib.collections.PolyCollection at 0x176b79af0>,
#  <matplotlib.collections.PolyCollection at 0x176b79eb0>,
#  <matplotlib.collections.PolyCollection at 0x176b872b0>,
#  <matplotlib.collections.PolyCollection at 0x176b87670>,
#  <matplotlib.collections.PolyCollection at 0x176b87a30>,
#  <matplotlib.collections.PolyCollection at 0x176b87df0>,
#  <matplotlib.collections.PolyCollection at 0x176b931f0>,
#  <matplotlib.collections.PolyCollection at 0x176b935b0>,
#  <matplotlib.collections.PolyCollection at 0x176b93970>,
#  <matplotlib.collections.PolyCollection at 0x176b93d30>,
#  <matplotlib.collections.PolyCollection at 0x176ba0130>,
#  <matplotlib.collections.PolyCollection at 0x176ba04f0>,
#  <matplotlib.collections.PolyCollection at 0x176ba08b0>,
#  <matplotlib.collections.PolyCollection at 0x176ba0c70>,
#  <matplotlib.collections.PolyCollection at 0x176bae070>,
#  <matplotlib.collections.PolyCollection at 0x176bae430>,
#  <matplotlib.collections.PolyCollection at 0x176bae7f0>,
#  <matplotlib.collections.PolyCollection at 0x176baebb0>,
#  <matplotlib.collections.PolyCollection at 0x176baef70>,
#  <matplotlib.collections.PolyCollection at 0x176bbb370>,
#  <matplotlib.collections.PolyCollection at 0x176bbb730>,
#  <matplotlib.collections.PolyCollection at 0x176bbbaf0>,
#  <matplotlib.collections.PolyCollection at 0x176bbbeb0>,
#  <matplotlib.collections.PolyCollection at 0x176bc62b0>,
#  <matplotlib.collections.PolyCollection at 0x176bc6670>,
#  <matplotlib.collections.PolyCollection at 0x176bc6a30>,
#  <matplotlib.collections.PolyCollection at 0x176bc6df0>,
#  <matplotlib.collections.PolyCollection at 0x176bd51f0>,
#  <matplotlib.collections.PolyCollection at 0x176bd55b0>,
#  <matplotlib.collections.PolyCollection at 0x176bd5970>,
#  <matplotlib.collections.PolyCollection at 0x176bd5d30>,
#  <matplotlib.collections.PolyCollection at 0x176be1130>,
#  <matplotlib.collections.PolyCollection at 0x176be14f0>,
#  <matplotlib.collections.PolyCollection at 0x176be18b0>,
#  <matplotlib.collections.PolyCollection at 0x176be1c70>,
#  <matplotlib.collections.PolyCollection at 0x176bee070>,
#  <matplotlib.collections.PolyCollection at 0x176bee430>,
#  <matplotlib.collections.PolyCollection at 0x176bee7f0>,
#  <matplotlib.collections.PolyCollection at 0x176beebb0>,
#  <matplotlib.collections.PolyCollection at 0x176beef70>,
#  <matplotlib.collections.PolyCollection at 0x176bfc370>,
#  <matplotlib.collections.PolyCollection at 0x176bfc730>,
#  <matplotlib.collections.PolyCollection at 0x176bfcaf0>,
#  <matplotlib.collections.PolyCollection at 0x176bfceb0>,
#  <matplotlib.collections.PolyCollection at 0x176c082b0>,
#  <matplotlib.collections.PolyCollection at 0x176c08670>,
#  <matplotlib.collections.PolyCollection at 0x176c08a30>,
#  <matplotlib.collections.PolyCollection at 0x176c08df0>,
#  <matplotlib.collections.PolyCollection at 0x176c151f0>,
#  <matplotlib.collections.PolyCollection at 0x176c155b0>,
#  <matplotlib.collections.PolyCollection at 0x176c15970>,
#  <matplotlib.collections.PolyCollection at 0x176c15d30>,
#  <matplotlib.collections.PolyCollection at 0x176c23130>,
#  <matplotlib.collections.PolyCollection at 0x176c234f0>,
#  <matplotlib.collections.PolyCollection at 0x176c238b0>,
#  <matplotlib.collections.PolyCollection at 0x176c23c70>,
#  <matplotlib.collections.PolyCollection at 0x176c30070>,
#  <matplotlib.collections.PolyCollection at 0x176c30430>,
#  <matplotlib.collections.PolyCollection at 0x176c307f0>,
#  <matplotlib.collections.PolyCollection at 0x176c30bb0>,
#  <matplotlib.collections.PolyCollection at 0x176c30f70>,
#  <matplotlib.collections.PolyCollection at 0x176c3e370>,
#  <matplotlib.collections.PolyCollection at 0x176c3e730>,
#  <matplotlib.collections.PolyCollection at 0x176c3eaf0>,
#  <matplotlib.collections.PolyCollection at 0x176c3eeb0>,
#  <matplotlib.collections.PolyCollection at 0x176c492b0>,
#  <matplotlib.collections.PolyCollection at 0x176c49670>,
#  <matplotlib.collections.PolyCollection at 0x176c49a30>,
#  <matplotlib.collections.PolyCollection at 0x176c49df0>,
#  <matplotlib.collections.PolyCollection at 0x176c561f0>,
#  <matplotlib.collections.PolyCollection at 0x176c565b0>,
#  <matplotlib.collections.PolyCollection at 0x176c56970>,
#  <matplotlib.collections.PolyCollection at 0x176c56d30>,
#  <matplotlib.collections.PolyCollection at 0x176c63130>,
#  <matplotlib.collections.PolyCollection at 0x176c634f0>,
#  <matplotlib.collections.PolyCollection at 0x176c638b0>,
#  <matplotlib.collections.PolyCollection at 0x176c63c70>,
#  <matplotlib.collections.PolyCollection at 0x176c71070>,
#  <matplotlib.collections.PolyCollection at 0x176c71430>,
#  <matplotlib.collections.PolyCollection at 0x176c717f0>,
#  <matplotlib.collections.PolyCollection at 0x176c71bb0>,
#  <matplotlib.collections.PolyCollection at 0x176c71f70>,
#  <matplotlib.collections.PolyCollection at 0x176c7c370>,
#  <matplotlib.collections.PolyCollection at 0x176c7c730>,
#  <matplotlib.collections.PolyCollection at 0x176c7caf0>,
#  <matplotlib.collections.PolyCollection at 0x176c7ceb0>,
#  <matplotlib.collections.PolyCollection at 0x176c892b0>,
#  <matplotlib.collections.PolyCollection at 0x176c89670>,
#  <matplotlib.collections.PolyCollection at 0x176c89a30>,
#  <matplotlib.collections.PolyCollection at 0x176c89df0>,
#  <matplotlib.collections.PolyCollection at 0x176c991f0>,
#  <matplotlib.collections.PolyCollection at 0x176c995b0>,
#  <matplotlib.collections.PolyCollection at 0x176c99970>,
#  <matplotlib.collections.PolyCollection at 0x176c99d30>,
#  <matplotlib.collections.PolyCollection at 0x176ca4130>,
#  <matplotlib.collections.PolyCollection at 0x176ca44f0>,
#  <matplotlib.collections.PolyCollection at 0x176ca48b0>,
#  <matplotlib.collections.PolyCollection at 0x176ca4c70>,
#  <matplotlib.collections.PolyCollection at 0x176cb2070>,
#  <matplotlib.collections.PolyCollection at 0x176cb2430>,
#  <matplotlib.collections.PolyCollection at 0x176cb27f0>,
#  <matplotlib.collections.PolyCollection at 0x176cb2bb0>,
#  <matplotlib.collections.PolyCollection at 0x176cb2f70>,
#  <matplotlib.collections.PolyCollection at 0x176cc0370>,
#  <matplotlib.collections.PolyCollection at 0x176cc0730>,
#  <matplotlib.collections.PolyCollection at 0x176cc0af0>,
#  <matplotlib.collections.PolyCollection at 0x176cc0eb0>,
#  <matplotlib.collections.PolyCollection at 0x176cca2b0>,
#  <matplotlib.collections.PolyCollection at 0x176cca670>,
#  <matplotlib.collections.PolyCollection at 0x176ccaa30>,
#  <matplotlib.collections.PolyCollection at 0x176ccadf0>,
#  <matplotlib.collections.PolyCollection at 0x176cd71f0>,
#  <matplotlib.collections.PolyCollection at 0x176cd75b0>,
#  <matplotlib.collections.PolyCollection at 0x176cd7970>,
#  <matplotlib.collections.PolyCollection at 0x176cd7d30>,
#  <matplotlib.collections.PolyCollection at 0x176ce6130>,
#  <matplotlib.collections.PolyCollection at 0x176ce64f0>,
#  <matplotlib.collections.PolyCollection at 0x176ce68b0>,
#  <matplotlib.collections.PolyCollection at 0x176ce6c70>,
#  <matplotlib.collections.PolyCollection at 0x176cf3070>,
#  <matplotlib.collections.PolyCollection at 0x176cf3430>,
#  <matplotlib.collections.PolyCollection at 0x176cf37f0>,
#  <matplotlib.collections.PolyCollection at 0x176cf3bb0>,
#  <matplotlib.collections.PolyCollection at 0x176cf3f70>,
#  <matplotlib.collections.PolyCollection at 0x176cff370>,
#  <matplotlib.collections.PolyCollection at 0x176cff730>,
#  <matplotlib.collections.PolyCollection at 0x176cffaf0>,
#  <matplotlib.collections.PolyCollection at 0x176cffeb0>,
#  <matplotlib.collections.PolyCollection at 0x176d0c2b0>,
#  <matplotlib.collections.PolyCollection at 0x176d0c670>,
#  <matplotlib.collections.PolyCollection at 0x176d0ca30>,
#  <matplotlib.collections.PolyCollection at 0x176d0cdf0>,
#  <matplotlib.collections.PolyCollection at 0x176d1b1f0>,
#  <matplotlib.collections.PolyCollection at 0x176d1b5b0>,
#  <matplotlib.collections.PolyCollection at 0x176d1b970>,
#  <matplotlib.collections.PolyCollection at 0x176d1bd30>,
#  <matplotlib.collections.PolyCollection at 0x176d26130>,
#  <matplotlib.collections.PolyCollection at 0x176d264f0>,
#  <matplotlib.collections.PolyCollection at 0x176d268b0>,
#  <matplotlib.collections.PolyCollection at 0x176d26c70>,
#  <matplotlib.collections.PolyCollection at 0x176d36070>,
#  <matplotlib.collections.PolyCollection at 0x176d36430>,
#  <matplotlib.collections.PolyCollection at 0x176d367f0>,
#  <matplotlib.collections.PolyCollection at 0x176d36bb0>,
#  <matplotlib.collections.PolyCollection at 0x176d36f70>,
#  <matplotlib.collections.PolyCollection at 0x176d43370>,
#  <matplotlib.collections.PolyCollection at 0x176d43730>,
#  <matplotlib.collections.PolyCollection at 0x176d43af0>,
#  <matplotlib.collections.PolyCollection at 0x176d43eb0>,
#  <matplotlib.collections.PolyCollection at 0x176d4c2b0>,
#  <matplotlib.collections.PolyCollection at 0x176d4c670>,
#  <matplotlib.collections.PolyCollection at 0x176d4ca30>,
#  <matplotlib.collections.PolyCollection at 0x176d4cdf0>,
#  <matplotlib.collections.PolyCollection at 0x176d5a1f0>,
#  <matplotlib.collections.PolyCollection at 0x176d5a5b0>,
#  <matplotlib.collections.PolyCollection at 0x176d5a970>,
#  <matplotlib.collections.PolyCollection at 0x176d5ad30>,
#  <matplotlib.collections.PolyCollection at 0x176d68130>,
#  <matplotlib.collections.PolyCollection at 0x176d684f0>,
#  <matplotlib.collections.PolyCollection at 0x176d688b0>,
#  <matplotlib.collections.PolyCollection at 0x176d68c70>,
#  <matplotlib.collections.PolyCollection at 0x176d76070>,
#  <matplotlib.collections.PolyCollection at 0x176d76430>,
#  <matplotlib.collections.PolyCollection at 0x176d767f0>,
#  <matplotlib.collections.PolyCollection at 0x176d76bb0>,
#  <matplotlib.collections.PolyCollection at 0x176d76f70>,
#  <matplotlib.collections.PolyCollection at 0x176d84370>,
#  <matplotlib.collections.PolyCollection at 0x176d84730>,
#  <matplotlib.collections.PolyCollection at 0x176d84af0>,
#  <matplotlib.collections.PolyCollection at 0x176d84eb0>,
#  <matplotlib.collections.PolyCollection at 0x176d902b0>,
#  <matplotlib.collections.PolyCollection at 0x176d90670>,
#  <matplotlib.collections.PolyCollection at 0x176d90a30>,
#  <matplotlib.collections.PolyCollection at 0x176d90df0>,
#  <matplotlib.collections.PolyCollection at 0x176d9d1f0>,
#  <matplotlib.collections.PolyCollection at 0x176d9d5b0>,
#  <matplotlib.collections.PolyCollection at 0x176d9d970>,
#  <matplotlib.collections.PolyCollection at 0x176d9dd30>,
#  <matplotlib.collections.PolyCollection at 0x176da8130>,
#  <matplotlib.collections.PolyCollection at 0x176da84f0>,
#  <matplotlib.collections.PolyCollection at 0x176da88b0>,
#  <matplotlib.collections.PolyCollection at 0x176da8c70>,
#  <matplotlib.collections.PolyCollection at 0x176db8070>,
#  <matplotlib.collections.PolyCollection at 0x176db8430>,
#  <matplotlib.collections.PolyCollection at 0x176db87f0>,
#  <matplotlib.collections.PolyCollection at 0x176db8bb0>,
#  <matplotlib.collections.PolyCollection at 0x176db8f70>,
#  <matplotlib.collections.PolyCollection at 0x176dc6370>,
#  <matplotlib.collections.PolyCollection at 0x176dc6730>,
#  <matplotlib.collections.PolyCollection at 0x176dc6af0>,
#  <matplotlib.collections.PolyCollection at 0x176dc6eb0>,
#  <matplotlib.collections.PolyCollection at 0x176dd02b0>,
#  <matplotlib.collections.PolyCollection at 0x176dd0670>,
#  <matplotlib.collections.PolyCollection at 0x176dd0a30>,
#  <matplotlib.collections.PolyCollection at 0x176dd0df0>,
#  <matplotlib.collections.PolyCollection at 0x176dde1f0>,
#  <matplotlib.collections.PolyCollection at 0x176dde5b0>,
#  <matplotlib.collections.PolyCollection at 0x176dde970>,
#  <matplotlib.collections.PolyCollection at 0x176dded30>,
#  <matplotlib.collections.PolyCollection at 0x176dec130>,
#  <matplotlib.collections.PolyCollection at 0x176dec4f0>,
#  <matplotlib.collections.PolyCollection at 0x176dec8b0>,
#  <matplotlib.collections.PolyCollection at 0x176decc70>,
#  <matplotlib.collections.PolyCollection at 0x176df9070>,
#  <matplotlib.collections.PolyCollection at 0x176df9430>,
#  <matplotlib.collections.PolyCollection at 0x176df97f0>,
#  <matplotlib.collections.PolyCollection at 0x176df9bb0>,
#  <matplotlib.collections.PolyCollection at 0x176df9f70>,
#  <matplotlib.collections.PolyCollection at 0x176e06370>,
#  <matplotlib.collections.PolyCollection at 0x176e06730>,
#  <matplotlib.collections.PolyCollection at 0x176e06af0>,
#  <matplotlib.collections.PolyCollection at 0x176e06eb0>,
#  <matplotlib.collections.PolyCollection at 0x176e122b0>,
#  <matplotlib.collections.PolyCollection at 0x176e12670>,
#  <matplotlib.collections.PolyCollection at 0x176e12a30>,
#  <matplotlib.collections.PolyCollection at 0x176e12df0>,
#  <matplotlib.collections.PolyCollection at 0x176e201f0>,
#  <matplotlib.collections.PolyCollection at 0x176e205b0>,
#  <matplotlib.collections.PolyCollection at 0x176e20970>,
#  <matplotlib.collections.PolyCollection at 0x176e20d30>,
#  <matplotlib.collections.PolyCollection at 0x176e2c130>,
#  <matplotlib.collections.PolyCollection at 0x176e2c4f0>,
#  <matplotlib.collections.PolyCollection at 0x176e2c8b0>,
#  <matplotlib.collections.PolyCollection at 0x176e2cc70>,
#  <matplotlib.collections.PolyCollection at 0x176e3a070>,
#  <matplotlib.collections.PolyCollection at 0x176e3a430>,
#  <matplotlib.collections.PolyCollection at 0x176e3a7f0>,
#  <matplotlib.collections.PolyCollection at 0x176e3abb0>,
#  <matplotlib.collections.PolyCollection at 0x176e3af70>,
#  <matplotlib.collections.PolyCollection at 0x176e47370>,
#  <matplotlib.collections.PolyCollection at 0x176e47730>,
#  <matplotlib.collections.PolyCollection at 0x176e47af0>,
#  <matplotlib.collections.PolyCollection at 0x176e47eb0>,
#  <matplotlib.collections.PolyCollection at 0x176e532b0>,
#  <matplotlib.collections.PolyCollection at 0x176e53670>,
#  <matplotlib.collections.PolyCollection at 0x176e53a30>,
#  <matplotlib.collections.PolyCollection at 0x176e53df0>,
#  <matplotlib.collections.PolyCollection at 0x176e601f0>,
#  <matplotlib.collections.PolyCollection at 0x176e605b0>,
#  <matplotlib.collections.PolyCollection at 0x176e60970>,
#  <matplotlib.collections.PolyCollection at 0x176e60d30>,
#  <matplotlib.collections.PolyCollection at 0x176e6e130>,
#  <matplotlib.collections.PolyCollection at 0x176e6e4f0>,
#  <matplotlib.collections.PolyCollection at 0x176e6e8b0>,
#  <matplotlib.collections.PolyCollection at 0x176e6ec70>,
#  <matplotlib.collections.PolyCollection at 0x176e7b070>,
#  <matplotlib.collections.PolyCollection at 0x176e7b430>,
#  <matplotlib.collections.PolyCollection at 0x176e7b7f0>,
#  <matplotlib.collections.PolyCollection at 0x176e7bbb0>,
#  <matplotlib.collections.PolyCollection at 0x176e7bf70>,
#  <matplotlib.collections.PolyCollection at 0x176e88370>,
#  <matplotlib.collections.PolyCollection at 0x176e88730>,
#  <matplotlib.collections.PolyCollection at 0x176e88af0>,
#  <matplotlib.collections.PolyCollection at 0x176e88eb0>,
#  <matplotlib.collections.PolyCollection at 0x176e952b0>,
#  <matplotlib.collections.PolyCollection at 0x176e95670>,
#  <matplotlib.collections.PolyCollection at 0x176e95a30>,
#  <matplotlib.collections.PolyCollection at 0x176e95df0>,
#  <matplotlib.collections.PolyCollection at 0x176ea21f0>,
#  <matplotlib.collections.PolyCollection at 0x176ea25b0>,
#  <matplotlib.collections.PolyCollection at 0x176ea2970>,
#  <matplotlib.collections.PolyCollection at 0x176ea2d30>,
#  <matplotlib.collections.PolyCollection at 0x176eaf130>,
#  <matplotlib.collections.PolyCollection at 0x176eaf4f0>,
#  <matplotlib.collections.PolyCollection at 0x176eaf8b0>,
#  <matplotlib.collections.PolyCollection at 0x176eafc70>,
#  <matplotlib.collections.PolyCollection at 0x176ebd070>,
#  <matplotlib.collections.PolyCollection at 0x176ebd430>,
#  <matplotlib.collections.PolyCollection at 0x176ebd7f0>,
#  <matplotlib.collections.PolyCollection at 0x17cc4f9a0>,
#  <matplotlib.collections.PolyCollection at 0x176ebdd60>,
#  <matplotlib.collections.PolyCollection at 0x176ec9160>,
#  <matplotlib.collections.PolyCollection at 0x176ec9520>,
#  <matplotlib.collections.PolyCollection at 0x176ec98e0>,
#  <matplotlib.collections.PolyCollection at 0x176ec9ca0>,
#  <matplotlib.collections.PolyCollection at 0x176ed40a0>,
#  <matplotlib.collections.PolyCollection at 0x176ed4460>,
#  <matplotlib.collections.PolyCollection at 0x176ed4820>,
#  <matplotlib.collections.PolyCollection at 0x176ed4be0>,
#  <matplotlib.collections.PolyCollection at 0x176ed4fa0>,
#  <matplotlib.collections.PolyCollection at 0x176ee23a0>,
#  <matplotlib.collections.PolyCollection at 0x176ee2760>,
#  <matplotlib.collections.PolyCollection at 0x176ee2b20>,
#  <matplotlib.collections.PolyCollection at 0x176ee2ee0>,
#  <matplotlib.collections.PolyCollection at 0x176eed2e0>,
#  <matplotlib.collections.PolyCollection at 0x176eed6a0>,
#  <matplotlib.collections.PolyCollection at 0x176eeda60>,
#  <matplotlib.collections.PolyCollection at 0x176eede20>,
#  <matplotlib.collections.PolyCollection at 0x176efc220>,
#  <matplotlib.collections.PolyCollection at 0x176efc5e0>,
#  <matplotlib.collections.PolyCollection at 0x176efc9a0>,
#  <matplotlib.collections.PolyCollection at 0x176efcd60>,
#  <matplotlib.collections.PolyCollection at 0x176f08160>,
#  <matplotlib.collections.PolyCollection at 0x176f08520>,
#  <matplotlib.collections.PolyCollection at 0x176f088e0>,
#  <matplotlib.collections.PolyCollection at 0x176f08ca0>,
#  <matplotlib.collections.PolyCollection at 0x176f170a0>,
#  <matplotlib.collections.PolyCollection at 0x176f17460>,
#  <matplotlib.collections.PolyCollection at 0x176f17820>,
#  <matplotlib.collections.PolyCollection at 0x176f17be0>,
#  <matplotlib.collections.PolyCollection at 0x176f17fa0>,
#  <matplotlib.collections.PolyCollection at 0x176f253a0>,
#  <matplotlib.collections.PolyCollection at 0x176f25760>,
#  <matplotlib.collections.PolyCollection at 0x176f25b20>,
#  <matplotlib.collections.PolyCollection at 0x176f25ee0>,
#  <matplotlib.collections.PolyCollection at 0x176f2f2e0>,
#  <matplotlib.collections.PolyCollection at 0x176f2f6a0>,
#  <matplotlib.collections.PolyCollection at 0x176f2fa60>,
#  <matplotlib.collections.PolyCollection at 0x176f2fe20>,
#  <matplotlib.collections.PolyCollection at 0x176f3c220>,
#  <matplotlib.collections.PolyCollection at 0x176f3c5e0>,
#  <matplotlib.collections.PolyCollection at 0x176f3c9a0>,
#  <matplotlib.collections.PolyCollection at 0x176f3cd60>,
#  <matplotlib.collections.PolyCollection at 0x176f4b160>,
#  <matplotlib.collections.PolyCollection at 0x176f4b520>,
#  <matplotlib.collections.PolyCollection at 0x176f4b8e0>,
#  <matplotlib.collections.PolyCollection at 0x176f4bca0>,
#  <matplotlib.collections.PolyCollection at 0x176f550a0>,
#  <matplotlib.collections.PolyCollection at 0x176f55460>,
#  <matplotlib.collections.PolyCollection at 0x176f55820>,
#  <matplotlib.collections.PolyCollection at 0x176f55be0>,
#  <matplotlib.collections.PolyCollection at 0x176f55fa0>,
#  <matplotlib.collections.PolyCollection at 0x176f643a0>,
#  <matplotlib.collections.PolyCollection at 0x176f64760>,
#  <matplotlib.collections.PolyCollection at 0x176f64b20>,
#  <matplotlib.collections.PolyCollection at 0x176f64ee0>,
#  <matplotlib.collections.PolyCollection at 0x176f722e0>,
#  <matplotlib.collections.PolyCollection at 0x176f726a0>,
#  <matplotlib.collections.PolyCollection at 0x176f72a60>,
#  <matplotlib.collections.PolyCollection at 0x176f72e20>,
#  <matplotlib.collections.PolyCollection at 0x176f7e220>,
#  <matplotlib.collections.PolyCollection at 0x176f7e5e0>,
#  <matplotlib.collections.PolyCollection at 0x176f7e9a0>,
#  <matplotlib.collections.PolyCollection at 0x176f7ed60>,
#  <matplotlib.collections.PolyCollection at 0x176f8b160>,
#  <matplotlib.collections.PolyCollection at 0x176f8b520>,
#  <matplotlib.collections.PolyCollection at 0x176f8b8e0>,
#  <matplotlib.collections.PolyCollection at 0x176f8bca0>,
#  <matplotlib.collections.PolyCollection at 0x176f990a0>,
#  <matplotlib.collections.PolyCollection at 0x176f99460>,
#  <matplotlib.collections.PolyCollection at 0x176f99820>,
#  <matplotlib.collections.PolyCollection at 0x176f99be0>,
#  <matplotlib.collections.PolyCollection at 0x176f99fa0>,
#  <matplotlib.collections.PolyCollection at 0x176fa63a0>,
#  <matplotlib.collections.PolyCollection at 0x176fa6760>,
#  <matplotlib.collections.PolyCollection at 0x176fa6b20>,
#  <matplotlib.collections.PolyCollection at 0x176fa6ee0>,
#  <matplotlib.collections.PolyCollection at 0x176fb22e0>,
#  <matplotlib.collections.PolyCollection at 0x176fb26a0>,
#  <matplotlib.collections.PolyCollection at 0x176fb2a60>,
#  <matplotlib.collections.PolyCollection at 0x176fb2e20>,
#  <matplotlib.collections.PolyCollection at 0x176fc0220>,
#  <matplotlib.collections.PolyCollection at 0x176fc05e0>,
#  <matplotlib.collections.PolyCollection at 0x176fc09a0>,
#  <matplotlib.collections.PolyCollection at 0x176fc0d60>,
#  <matplotlib.collections.PolyCollection at 0x176fcd160>,
#  <matplotlib.collections.PolyCollection at 0x176fcd520>,
#  <matplotlib.collections.PolyCollection at 0x176fcd8e0>,
#  <matplotlib.collections.PolyCollection at 0x176fcdca0>,
#  <matplotlib.collections.PolyCollection at 0x176fd90a0>,
#  <matplotlib.collections.PolyCollection at 0x176fd9460>,
#  <matplotlib.collections.PolyCollection at 0x176fd9820>,
#  <matplotlib.collections.PolyCollection at 0x176fd9be0>,
#  <matplotlib.collections.PolyCollection at 0x176fd9fa0>,
#  <matplotlib.collections.PolyCollection at 0x176fe73a0>,
#  <matplotlib.collections.PolyCollection at 0x176fe7760>,
#  <matplotlib.collections.PolyCollection at 0x176fe7b20>,
#  <matplotlib.collections.PolyCollection at 0x176fe7ee0>,
#  <matplotlib.collections.PolyCollection at 0x176ff42e0>,
#  <matplotlib.collections.PolyCollection at 0x176ff46a0>,
#  <matplotlib.collections.PolyCollection at 0x176ff4a60>,
#  <matplotlib.collections.PolyCollection at 0x176ff4e20>,
#  <matplotlib.collections.PolyCollection at 0x177000220>,
#  <matplotlib.collections.PolyCollection at 0x1770005e0>,
#  <matplotlib.collections.PolyCollection at 0x1770009a0>,
#  <matplotlib.collections.PolyCollection at 0x177000d60>,
#  <matplotlib.collections.PolyCollection at 0x17700d160>,
#  <matplotlib.collections.PolyCollection at 0x17700d520>,
#  <matplotlib.collections.PolyCollection at 0x17700d8e0>,
#  <matplotlib.collections.PolyCollection at 0x17700dca0>,
#  <matplotlib.collections.PolyCollection at 0x17701a0a0>,
#  <matplotlib.collections.PolyCollection at 0x17701a460>,
#  <matplotlib.collections.PolyCollection at 0x17701a820>,
#  <matplotlib.collections.PolyCollection at 0x17701abe0>,
#  <matplotlib.collections.PolyCollection at 0x17701afa0>,
#  <matplotlib.collections.PolyCollection at 0x1770293a0>,
#  <matplotlib.collections.PolyCollection at 0x177029760>,
#  <matplotlib.collections.PolyCollection at 0x177029b20>,
#  <matplotlib.collections.PolyCollection at 0x177029ee0>,
#  <matplotlib.collections.PolyCollection at 0x1770362e0>,
#  <matplotlib.collections.PolyCollection at 0x1770366a0>,
#  <matplotlib.collections.PolyCollection at 0x177036a60>,
#  <matplotlib.collections.PolyCollection at 0x177036e20>,
#  <matplotlib.collections.PolyCollection at 0x177043220>,
#  <matplotlib.collections.PolyCollection at 0x1770435e0>,
#  <matplotlib.collections.PolyCollection at 0x1770439a0>,
#  <matplotlib.collections.PolyCollection at 0x177043d60>,
#  <matplotlib.collections.PolyCollection at 0x177051160>,
#  <matplotlib.collections.PolyCollection at 0x177051520>,
#  <matplotlib.collections.PolyCollection at 0x1770518e0>,
#  <matplotlib.collections.PolyCollection at 0x177051ca0>,
#  <matplotlib.collections.PolyCollection at 0x17705c0a0>,
#  <matplotlib.collections.PolyCollection at 0x17705c460>,
#  <matplotlib.collections.PolyCollection at 0x17705c820>,
#  <matplotlib.collections.PolyCollection at 0x17705cbe0>,
#  <matplotlib.collections.PolyCollection at 0x17705cfa0>,
#  <matplotlib.collections.PolyCollection at 0x1770693a0>,
#  <matplotlib.collections.PolyCollection at 0x177069760>,
#  <matplotlib.collections.PolyCollection at 0x177069b20>,
#  <matplotlib.collections.PolyCollection at 0x177069ee0>,
#  <matplotlib.collections.PolyCollection at 0x1770762e0>,
#  <matplotlib.collections.PolyCollection at 0x1770766a0>,
#  <matplotlib.collections.PolyCollection at 0x177076a60>,
#  <matplotlib.collections.PolyCollection at 0x177076e20>,
#  <matplotlib.collections.PolyCollection at 0x177080220>,
#  <matplotlib.collections.PolyCollection at 0x1770805e0>,
#  <matplotlib.collections.PolyCollection at 0x1770809a0>,
#  <matplotlib.collections.PolyCollection at 0x177080d60>,
#  <matplotlib.collections.PolyCollection at 0x177091160>,
#  <matplotlib.collections.PolyCollection at 0x177091520>,
#  <matplotlib.collections.PolyCollection at 0x1770918e0>,
#  <matplotlib.collections.PolyCollection at 0x177091ca0>,
#  <matplotlib.collections.PolyCollection at 0x17709c0a0>,
#  <matplotlib.collections.PolyCollection at 0x17709c460>,
#  <matplotlib.collections.PolyCollection at 0x17709c820>,
#  <matplotlib.collections.PolyCollection at 0x17709cbe0>,
#  <matplotlib.collections.PolyCollection at 0x17709cfa0>,
#  <matplotlib.collections.PolyCollection at 0x1770ab3a0>,
#  <matplotlib.collections.PolyCollection at 0x1770ab760>,
#  <matplotlib.collections.PolyCollection at 0x1770abb20>,
#  <matplotlib.collections.PolyCollection at 0x1770abee0>,
#  <matplotlib.collections.PolyCollection at 0x1770b72e0>,
#  <matplotlib.collections.PolyCollection at 0x1770b76a0>,
#  <matplotlib.collections.PolyCollection at 0x1770b7a60>,
#  <matplotlib.collections.PolyCollection at 0x1770b7e20>,
#  <matplotlib.collections.PolyCollection at 0x1770c4220>,
#  <matplotlib.collections.PolyCollection at 0x1770c45e0>,
#  <matplotlib.collections.PolyCollection at 0x1770c49a0>,
#  <matplotlib.collections.PolyCollection at 0x1770c4d60>,
#  <matplotlib.collections.PolyCollection at 0x1770d3160>,
#  <matplotlib.collections.PolyCollection at 0x1770d3520>,
#  <matplotlib.collections.PolyCollection at 0x1770d38e0>,
#  <matplotlib.collections.PolyCollection at 0x1770d3ca0>,
#  <matplotlib.collections.PolyCollection at 0x1770de0a0>,
#  <matplotlib.collections.PolyCollection at 0x1770de460>,
#  <matplotlib.collections.PolyCollection at 0x1770de820>,
#  <matplotlib.collections.PolyCollection at 0x1770debe0>,
#  <matplotlib.collections.PolyCollection at 0x1770defa0>,
#  <matplotlib.collections.PolyCollection at 0x1770ea3a0>,
#  <matplotlib.collections.PolyCollection at 0x1770ea760>,
#  <matplotlib.collections.PolyCollection at 0x1770eab20>,
#  <matplotlib.collections.PolyCollection at 0x1770eaee0>,
#  <matplotlib.collections.PolyCollection at 0x1770f82e0>,
#  <matplotlib.collections.PolyCollection at 0x1770f86a0>,
#  <matplotlib.collections.PolyCollection at 0x1770f8a60>,
#  <matplotlib.collections.PolyCollection at 0x1770f8e20>,
#  <matplotlib.collections.PolyCollection at 0x177106220>,
#  <matplotlib.collections.PolyCollection at 0x1771065e0>,
#  <matplotlib.collections.PolyCollection at 0x1771069a0>,
#  <matplotlib.collections.PolyCollection at 0x177106d60>,
#  <matplotlib.collections.PolyCollection at 0x177113160>,
#  <matplotlib.collections.PolyCollection at 0x177113520>,
#  <matplotlib.collections.PolyCollection at 0x1771138e0>,
#  <matplotlib.collections.PolyCollection at 0x177113ca0>,
#  <matplotlib.collections.PolyCollection at 0x1771200a0>,
#  <matplotlib.collections.PolyCollection at 0x177120460>,
#  <matplotlib.collections.PolyCollection at 0x177120820>,
#  <matplotlib.collections.PolyCollection at 0x177120be0>,
#  <matplotlib.collections.PolyCollection at 0x177120fa0>,
#  <matplotlib.collections.PolyCollection at 0x17712e3a0>,
#  <matplotlib.collections.PolyCollection at 0x17712e760>,
#  <matplotlib.collections.PolyCollection at 0x17712eb20>,
#  <matplotlib.collections.PolyCollection at 0x17712eee0>,
#  <matplotlib.collections.PolyCollection at 0x1771382e0>,
#  <matplotlib.collections.PolyCollection at 0x1771386a0>,
#  <matplotlib.collections.PolyCollection at 0x177138a60>,
#  <matplotlib.collections.PolyCollection at 0x177138e20>,
#  <matplotlib.collections.PolyCollection at 0x177146220>,
#  <matplotlib.collections.PolyCollection at 0x1771465e0>,
#  <matplotlib.collections.PolyCollection at 0x1771469a0>,
#  <matplotlib.collections.PolyCollection at 0x177146d60>,
#  <matplotlib.collections.PolyCollection at 0x177154160>,
#  <matplotlib.collections.PolyCollection at 0x177154520>,
#  <matplotlib.collections.PolyCollection at 0x1771548e0>,
#  <matplotlib.collections.PolyCollection at 0x177154ca0>,
#  <matplotlib.collections.PolyCollection at 0x17715e0a0>,
#  <matplotlib.collections.PolyCollection at 0x17715e460>,
#  <matplotlib.collections.PolyCollection at 0x17715e820>,
#  <matplotlib.collections.PolyCollection at 0x17715ebe0>,
#  <matplotlib.collections.PolyCollection at 0x17715efa0>,
#  <matplotlib.collections.PolyCollection at 0x17716e3a0>,
#  <matplotlib.collections.PolyCollection at 0x17716e760>,
#  <matplotlib.collections.PolyCollection at 0x17716eb20>,
#  <matplotlib.collections.PolyCollection at 0x17716eee0>,
#  <matplotlib.collections.PolyCollection at 0x17717b2e0>,
#  <matplotlib.collections.PolyCollection at 0x17717b6a0>,
#  <matplotlib.collections.PolyCollection at 0x17717ba60>,
#  <matplotlib.collections.PolyCollection at 0x17717be20>,
#  <matplotlib.collections.PolyCollection at 0x177187220>,
#  <matplotlib.collections.PolyCollection at 0x1771875e0>,
#  <matplotlib.collections.PolyCollection at 0x1771879a0>,
#  <matplotlib.collections.PolyCollection at 0x177187d60>,
#  <matplotlib.collections.PolyCollection at 0x177194160>,
#  <matplotlib.collections.PolyCollection at 0x177194520>,
#  <matplotlib.collections.PolyCollection at 0x1771948e0>,
#  <matplotlib.collections.PolyCollection at 0x177194ca0>,
#  <matplotlib.collections.PolyCollection at 0x1771a30a0>,
#  <matplotlib.collections.PolyCollection at 0x1771a3460>,
#  <matplotlib.collections.PolyCollection at 0x1771a3820>,
#  <matplotlib.collections.PolyCollection at 0x1771a3be0>,
#  <matplotlib.collections.PolyCollection at 0x1771a3fa0>,
#  <matplotlib.collections.PolyCollection at 0x1771b03a0>,
#  <matplotlib.collections.PolyCollection at 0x1771b0760>,
#  <matplotlib.collections.PolyCollection at 0x1771b0b20>,
#  <matplotlib.collections.PolyCollection at 0x1771b0ee0>,
#  <matplotlib.collections.PolyCollection at 0x1771bc2e0>,
#  <matplotlib.collections.PolyCollection at 0x1771bc6a0>,
#  <matplotlib.collections.PolyCollection at 0x1771bca60>,
#  <matplotlib.collections.PolyCollection at 0x1771bce20>,
#  <matplotlib.collections.PolyCollection at 0x1771ca220>,
#  <matplotlib.collections.PolyCollection at 0x1771ca5e0>,
#  <matplotlib.collections.PolyCollection at 0x1771ca9a0>,
#  <matplotlib.collections.PolyCollection at 0x1771cad60>,
#  <matplotlib.collections.PolyCollection at 0x1771d7160>,
#  <matplotlib.collections.PolyCollection at 0x1771d7520>,
#  <matplotlib.collections.PolyCollection at 0x1771d78e0>,
#  <matplotlib.collections.PolyCollection at 0x1771d7ca0>,
#  <matplotlib.collections.PolyCollection at 0x1771e20a0>,
#  <matplotlib.collections.PolyCollection at 0x1771e2460>,
#  <matplotlib.collections.PolyCollection at 0x1771e2820>,
#  <matplotlib.collections.PolyCollection at 0x1771e2be0>,
#  <matplotlib.collections.PolyCollection at 0x1771e2fa0>,
#  <matplotlib.collections.PolyCollection at 0x1771f13a0>,
#  <matplotlib.collections.PolyCollection at 0x1771f1760>,
#  <matplotlib.collections.PolyCollection at 0x1771f1b20>,
#  <matplotlib.collections.PolyCollection at 0x1771f1ee0>,
#  <matplotlib.collections.PolyCollection at 0x1771fe2e0>,
#  <matplotlib.collections.PolyCollection at 0x1771fe6a0>,
#  <matplotlib.collections.PolyCollection at 0x1771fea60>,
#  <matplotlib.collections.PolyCollection at 0x1771fee20>,
#  <matplotlib.collections.PolyCollection at 0x17720b220>,
#  <matplotlib.collections.PolyCollection at 0x17720b5e0>,
#  <matplotlib.collections.PolyCollection at 0x17720b9a0>,
#  <matplotlib.collections.PolyCollection at 0x17720bd60>,
#  <matplotlib.collections.PolyCollection at 0x177217160>,
#  <matplotlib.collections.PolyCollection at 0x177217520>,
#  <matplotlib.collections.PolyCollection at 0x1772178e0>,
#  <matplotlib.collections.PolyCollection at 0x177217ca0>,
#  <matplotlib.collections.PolyCollection at 0x1772250a0>,
#  <matplotlib.collections.PolyCollection at 0x177225460>,
#  <matplotlib.collections.PolyCollection at 0x177225820>,
#  <matplotlib.collections.PolyCollection at 0x177225be0>,
#  <matplotlib.collections.PolyCollection at 0x177225fa0>,
#  <matplotlib.collections.PolyCollection at 0x1772333a0>,
#  <matplotlib.collections.PolyCollection at 0x177233760>,
#  <matplotlib.collections.PolyCollection at 0x177233b20>,
#  <matplotlib.collections.PolyCollection at 0x177233ee0>,
#  <matplotlib.collections.PolyCollection at 0x17723c2e0>,
#  <matplotlib.collections.PolyCollection at 0x17723c6a0>,
#  <matplotlib.collections.PolyCollection at 0x17723ca60>,
#  <matplotlib.collections.PolyCollection at 0x17723ce20>,
#  <matplotlib.collections.PolyCollection at 0x17724c220>,
#  <matplotlib.collections.PolyCollection at 0x17724c5e0>,
#  <matplotlib.collections.PolyCollection at 0x17724c9a0>,
#  <matplotlib.collections.PolyCollection at 0x17724cd60>,
#  <matplotlib.collections.PolyCollection at 0x17725a160>,
#  <matplotlib.collections.PolyCollection at 0x17725a520>,
#  <matplotlib.collections.PolyCollection at 0x17725a8e0>,
#  <matplotlib.collections.PolyCollection at 0x17725aca0>,
#  <matplotlib.collections.PolyCollection at 0x1772650a0>,
#  <matplotlib.collections.PolyCollection at 0x177265460>,
#  <matplotlib.collections.PolyCollection at 0x177265820>,
#  <matplotlib.collections.PolyCollection at 0x177265be0>,
#  <matplotlib.collections.PolyCollection at 0x177265fa0>,
#  <matplotlib.collections.PolyCollection at 0x1772733a0>,
#  <matplotlib.collections.PolyCollection at 0x177273760>,
#  <matplotlib.collections.PolyCollection at 0x177273b20>,
#  <matplotlib.collections.PolyCollection at 0x177273ee0>,
#  <matplotlib.collections.PolyCollection at 0x1772812e0>,
#  <matplotlib.collections.PolyCollection at 0x1772816a0>,
#  <matplotlib.collections.PolyCollection at 0x177281a60>,
#  <matplotlib.collections.PolyCollection at 0x177281e20>,
#  <matplotlib.collections.PolyCollection at 0x17728d220>,
#  <matplotlib.collections.PolyCollection at 0x17728d5e0>,
#  <matplotlib.collections.PolyCollection at 0x17728d9a0>,
#  <matplotlib.collections.PolyCollection at 0x17728dd60>,
#  <matplotlib.collections.PolyCollection at 0x17729b160>,
#  <matplotlib.collections.PolyCollection at 0x17729b520>,
#  <matplotlib.collections.PolyCollection at 0x17729b8e0>,
#  <matplotlib.collections.PolyCollection at 0x17729bca0>,
#  <matplotlib.collections.PolyCollection at 0x1772a70a0>,
#  <matplotlib.collections.PolyCollection at 0x1772a7460>,
#  <matplotlib.collections.PolyCollection at 0x1772a7820>,
#  <matplotlib.collections.PolyCollection at 0x1772a7be0>,
#  <matplotlib.collections.PolyCollection at 0x1772a7fa0>,
#  <matplotlib.collections.PolyCollection at 0x1772b43a0>,
#  <matplotlib.collections.PolyCollection at 0x1772b4760>,
#  <matplotlib.collections.PolyCollection at 0x1772b4b20>,
#  <matplotlib.collections.PolyCollection at 0x1772b4ee0>,
#  <matplotlib.collections.PolyCollection at 0x1772c12e0>,
#  <matplotlib.collections.PolyCollection at 0x1772c16a0>,
#  <matplotlib.collections.PolyCollection at 0x1772c1a60>,
#  <matplotlib.collections.PolyCollection at 0x1772c1e20>,
#  <matplotlib.collections.PolyCollection at 0x1772cf220>,
#  <matplotlib.collections.PolyCollection at 0x1772cf5e0>,
#  <matplotlib.collections.PolyCollection at 0x1772cf9a0>,
#  <matplotlib.collections.PolyCollection at 0x1772cfd60>,
#  <matplotlib.collections.PolyCollection at 0x1772dc160>,
#  <matplotlib.collections.PolyCollection at 0x1772dc520>,
#  <matplotlib.collections.PolyCollection at 0x1772dc8e0>,
#  <matplotlib.collections.PolyCollection at 0x1772dcca0>,
#  <matplotlib.collections.PolyCollection at 0x1772e90a0>,
#  <matplotlib.collections.PolyCollection at 0x1772e9460>,
#  <matplotlib.collections.PolyCollection at 0x1772e9820>,
#  <matplotlib.collections.PolyCollection at 0x1772e9be0>,
#  <matplotlib.collections.PolyCollection at 0x1772e9fa0>,
#  <matplotlib.collections.PolyCollection at 0x1772f43a0>,
#  <matplotlib.collections.PolyCollection at 0x1772f4760>,
#  <matplotlib.collections.PolyCollection at 0x1772f4b20>,
#  <matplotlib.collections.PolyCollection at 0x1772f4ee0>,
#  <matplotlib.collections.PolyCollection at 0x1773022e0>,
#  <matplotlib.collections.PolyCollection at 0x1773026a0>,
#  <matplotlib.collections.PolyCollection at 0x177302a60>,
#  <matplotlib.collections.PolyCollection at 0x177302e20>,
#  <matplotlib.collections.PolyCollection at 0x17730f220>,
#  <matplotlib.collections.PolyCollection at 0x17730f5e0>,
#  <matplotlib.collections.PolyCollection at 0x17730f9a0>,
#  <matplotlib.collections.PolyCollection at 0x17730fd60>,
#  <matplotlib.collections.PolyCollection at 0x17731c160>,
#  <matplotlib.collections.PolyCollection at 0x17731c520>,
#  <matplotlib.collections.PolyCollection at 0x17731c8e0>,
#  <matplotlib.collections.PolyCollection at 0x17731cca0>,
#  <matplotlib.collections.PolyCollection at 0x1773290a0>,
#  <matplotlib.collections.PolyCollection at 0x177329460>,
#  <matplotlib.collections.PolyCollection at 0x177329820>,
#  <matplotlib.collections.PolyCollection at 0x177329be0>,
#  <matplotlib.collections.PolyCollection at 0x177329fa0>,
#  <matplotlib.collections.PolyCollection at 0x1773393a0>,
#  <matplotlib.collections.PolyCollection at 0x177339760>,
#  <matplotlib.collections.PolyCollection at 0x177339b20>,
#  <matplotlib.collections.PolyCollection at 0x177339ee0>,
#  <matplotlib.collections.PolyCollection at 0x1773442e0>,
#  <matplotlib.collections.PolyCollection at 0x1773446a0>,
#  <matplotlib.collections.PolyCollection at 0x177344a60>,
#  <matplotlib.collections.PolyCollection at 0x177344e20>,
#  <matplotlib.collections.PolyCollection at 0x177351220>,
#  <matplotlib.collections.PolyCollection at 0x1773515e0>,
#  <matplotlib.collections.PolyCollection at 0x1773519a0>,
#  <matplotlib.collections.PolyCollection at 0x177351d60>,
#  <matplotlib.collections.PolyCollection at 0x177360160>,
#  <matplotlib.collections.PolyCollection at 0x177360520>,
#  <matplotlib.collections.PolyCollection at 0x1773608e0>,
#  <matplotlib.collections.PolyCollection at 0x177360ca0>,
#  <matplotlib.collections.PolyCollection at 0x17736a0a0>,
#  <matplotlib.collections.PolyCollection at 0x17736a460>,
#  <matplotlib.collections.PolyCollection at 0x17736a820>,
#  <matplotlib.collections.PolyCollection at 0x17736abe0>,
#  <matplotlib.collections.PolyCollection at 0x17736afa0>,
#  <matplotlib.collections.PolyCollection at 0x1773783a0>,
#  <matplotlib.collections.PolyCollection at 0x177378760>,
#  <matplotlib.collections.PolyCollection at 0x177378b20>,
#  <matplotlib.collections.PolyCollection at 0x177378ee0>,
#  <matplotlib.collections.PolyCollection at 0x1773862e0>,
#  <matplotlib.collections.PolyCollection at 0x1773866a0>,
#  <matplotlib.collections.PolyCollection at 0x177386a60>,
#  <matplotlib.collections.PolyCollection at 0x177386e20>,
#  <matplotlib.collections.PolyCollection at 0x177392220>,
#  <matplotlib.collections.PolyCollection at 0x1773925e0>,
#  <matplotlib.collections.PolyCollection at 0x1773929a0>,
#  <matplotlib.collections.PolyCollection at 0x177392d60>,
#  <matplotlib.collections.PolyCollection at 0x17739f160>,
#  <matplotlib.collections.PolyCollection at 0x17739f520>,
#  <matplotlib.collections.PolyCollection at 0x17739f8e0>,
#  <matplotlib.collections.PolyCollection at 0x17739fca0>,
#  <matplotlib.collections.PolyCollection at 0x1773ae0a0>,
#  <matplotlib.collections.PolyCollection at 0x1773ae460>,
#  <matplotlib.collections.PolyCollection at 0x1773ae820>,
#  <matplotlib.collections.PolyCollection at 0x1773aebe0>,
#  <matplotlib.collections.PolyCollection at 0x1773aefa0>,
#  <matplotlib.collections.PolyCollection at 0x1773bb3a0>,
#  <matplotlib.collections.PolyCollection at 0x1773bb760>,
#  <matplotlib.collections.PolyCollection at 0x1773bbb20>,
#  <matplotlib.collections.PolyCollection at 0x1773bbee0>,
#  <matplotlib.collections.PolyCollection at 0x1773c62e0>,
#  <matplotlib.collections.PolyCollection at 0x1773c66a0>,
#  <matplotlib.collections.PolyCollection at 0x1773c6a60>,
#  <matplotlib.collections.PolyCollection at 0x1773c6e20>,
#  <matplotlib.collections.PolyCollection at 0x1773d3220>,
#  <matplotlib.collections.PolyCollection at 0x1773d35e0>,
#  <matplotlib.collections.PolyCollection at 0x1773d39a0>,
#  <matplotlib.collections.PolyCollection at 0x1773d3d60>,
#  <matplotlib.collections.PolyCollection at 0x1773e1160>,
#  <matplotlib.collections.PolyCollection at 0x1773e1520>,
#  <matplotlib.collections.PolyCollection at 0x1773e18e0>,
#  <matplotlib.collections.PolyCollection at 0x1773e1ca0>,
#  <matplotlib.collections.PolyCollection at 0x1773eb0a0>,
#  <matplotlib.collections.PolyCollection at 0x1773eb460>,
#  <matplotlib.collections.PolyCollection at 0x1773eb820>,
#  <matplotlib.collections.PolyCollection at 0x1773ebbe0>,
#  <matplotlib.collections.PolyCollection at 0x1773ebfa0>,
#  <matplotlib.collections.PolyCollection at 0x1773f93a0>,
#  <matplotlib.collections.PolyCollection at 0x1773f9760>,
#  <matplotlib.collections.PolyCollection at 0x1773f9b20>,
#  <matplotlib.collections.PolyCollection at 0x1773f9ee0>,
#  <matplotlib.collections.PolyCollection at 0x1774082e0>,
#  <matplotlib.collections.PolyCollection at 0x1774086a0>,
#  <matplotlib.collections.PolyCollection at 0x177408a60>,
#  <matplotlib.collections.PolyCollection at 0x177408e20>,
#  <matplotlib.collections.PolyCollection at 0x177415220>,
#  <matplotlib.collections.PolyCollection at 0x1774155e0>,
#  <matplotlib.collections.PolyCollection at 0x1774159a0>,
#  <matplotlib.collections.PolyCollection at 0x177415d60>,
#  <matplotlib.collections.PolyCollection at 0x177423160>,
#  <matplotlib.collections.PolyCollection at 0x177423520>,
#  <matplotlib.collections.PolyCollection at 0x1774238e0>,
#  <matplotlib.collections.PolyCollection at 0x177423ca0>,
#  <matplotlib.collections.PolyCollection at 0x17742f0a0>,
#  <matplotlib.collections.PolyCollection at 0x17742f460>,
#  <matplotlib.collections.PolyCollection at 0x17742f820>,
#  <matplotlib.collections.PolyCollection at 0x17742fbe0>,
#  <matplotlib.collections.PolyCollection at 0x17742ffa0>,
#  <matplotlib.collections.PolyCollection at 0x17743c3a0>,
#  <matplotlib.collections.PolyCollection at 0x17743c760>,
#  <matplotlib.collections.PolyCollection at 0x17743cb20>,
#  <matplotlib.collections.PolyCollection at 0x17743cee0>,
#  <matplotlib.collections.PolyCollection at 0x1774472e0>,
#  <matplotlib.collections.PolyCollection at 0x1774476a0>,
#  <matplotlib.collections.PolyCollection at 0x177447a60>,
#  <matplotlib.collections.PolyCollection at 0x177447e20>,
#  <matplotlib.collections.PolyCollection at 0x177456220>,
#  <matplotlib.collections.PolyCollection at 0x1774565e0>,
#  <matplotlib.collections.PolyCollection at 0x1774569a0>,
#  <matplotlib.collections.PolyCollection at 0x177456d60>,
#  ...]

# %%
sns.color_palette('BuGn',10)
# Out:
# [(0.9176931949250289, 0.9684275278738947, 0.9808381391772395),
#  (0.8545943867743176, 0.9451441753171858, 0.9434525182622069),
#  (0.7670588235294118, 0.9125720876585929, 0.8832295271049596),
#  (0.6164705882352941, 0.8535178777393311, 0.79760092272203),
#  (0.47215686274509805, 0.7919108035371011, 0.6954863514033065),
#  (0.34765090349865435, 0.7324875048058439, 0.5780545943867743),
#  (0.2452133794694348, 0.6710495963091119, 0.4469204152249135),
#  (0.1566320645905421, 0.5677047289504037, 0.302237600922722),
#  (0.06082276047673972, 0.47958477508650516, 0.21599384851980008),
#  (0.0, 0.38268358323721646, 0.15398692810457515)]

# %%
sns.color_palette('#02818a',as_cmap=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/cm.py:131, in ColormapRegistry.__getitem__(self, item)
#     130 try:
# --> 131     return self._cmaps[item].copy()
#     132 except KeyError:
#
# KeyError: '#02818a'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.8/lib/python/site-packages/seaborn/palettes.py:207, in color_palette(palette, n_colors, desat, as_cmap)
#     205 try:
#     206     # Perhaps a named matplotlib colormap?
# --> 207     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     208 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~/Library/Python/3.8/lib/python/site-packages/seaborn/palettes.py:444, in mpl_palette(name, n_colors, as_cmap)
#     443 else:
# --> 444     cmap = get_colormap(name)
#     446 if name in MPL_QUAL_PALS:
#
# File ~/Library/Python/3.8/lib/python/site-packages/seaborn/_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# File ~/Library/Python/3.8/lib/python/site-packages/matplotlib/cm.py:133, in ColormapRegistry.__getitem__(self, item)
#     132 except KeyError:
# --> 133     raise KeyError(f"{item!r} is not a known colormap name")
#
# KeyError: "'#02818a' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 sns.color_palette('#02818a',as_cmap=True)
#
# File ~/Library/Python/3.8/lib/python/site-packages/seaborn/palettes.py:209, in color_palette(palette, n_colors, desat, as_cmap)
#     207             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     208         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 209             raise ValueError(f"{palette} is not a valid palette name")
#     211 if desat is not None:
#     212     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: #02818a is not a valid palette name
