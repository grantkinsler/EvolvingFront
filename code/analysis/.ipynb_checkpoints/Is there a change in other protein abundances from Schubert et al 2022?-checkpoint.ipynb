# %%
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib
import scipy
from scipy import stats
# from adjustText import adjust_text
from Bio import SeqIO
from Bio.Seq import Seq
# %matplotlib inline

import copy


# %load_ext autoreload
# %autoreload 2

# import gzip
# from cyvcf2 import VCF

from matplotlib import gridspec
from matplotlib.gridspec import GridSpec

from itertools import combinations
from itertools import combinations_with_replacement
from itertools import permutations
from ast import literal_eval

import sys
import os

home_dir = '~/Documents/Stanford/Research/EvolvingFront/'
home_dir = os.path.expanduser(home_dir)

tools_path = f'{home_dir}/code/processing/tools/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools as tools
import figures as figures

sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

# %%
merged_fitness = p.read_csv(f'{home_dir}/data/fitness_withMutations.csv',index_col=0)

# %%
schubert_data = p.read_csv(f'{home_dir}/data/Schubert_et_al_2022/combined_perGene.csv')

# %%
q_cols = [col for col in schubert_data.columns if '_q' in col]
log2fc_cols = [col for col in schubert_data.columns if '_log2fc' in col]


schubert_data[schubert_data['gene']=='IRA1']
# Out:
#       geneSys  gene                                          geneDescr
# 2605  YBR140C  IRA1  GTPase-activating protein; negatively regulate...  \
#
#       essential  Eno2_log2fc  Fas1_log2fc  Fas2_log2fc  Htb2_log2fc
# 2605       True     0.762501     0.283887    -0.617963     -0.57636  \
#
#       Rnr2_log2fc  Rpl9A_log2fc  ...    Fas2_q    Htb2_q    Rnr2_q
# 2605    -0.239306      0.598195  ...  0.454997  0.352167  0.863138  \
#
#            Rpl9A_q    Ssa1_q    Tdh1_q    Tdh2_q    Tdh3_q    Yhb1_q
# 2605  4.791525e-07  0.296344  0.000187  0.000573  0.787886  0.000001  \
#
#       FDR0.05_count
# 2605              5
#
# [1 rows x 27 columns]

# %%
unique_genes = np.unique([gene for gene in merged_fitness['gene'].values if not p.isnull(gene) if gene in tools.mutation_color_map.keys()])

overlapping_genes = schubert_data[schubert_data['gene'].isin(unique_genes)]
overlapping_gene_list = overlapping_genes['gene'].values

# %%
overlapping_genes
# Out:
#       geneSys   gene                                          geneDescr
# 7     YAL056W   GPB2  Multistep regulator of cAMP-PKA signaling; inh...  \
# 128   YJL128C   PBS2  MAP kinase kinase of the HOG signaling pathway...
# 149   YJL101C   GSH1  Gamma glutamylcysteine synthetase; catalyzes t...
# 222   YJL005W   CYR1  Adenylate cyclase; required for cAMP productio...
# 273   YJR066W   TOR1  PIK-related protein kinase and rapamycin targe...
# 441   YKL085W   MDH1  Mitochondrial malate dehydrogenase; catalyzes ...
# 486   YKL025C   PAN3  Essential subunit of the Pan2p-Pan3p poly(A)-r...
# 627   YLL013C   PUF3  Protein of the mitochondrial outer surface; li...
# 718   YLR113W   HOG1  Mitogen-activated protein kinase involved in o...
# 765   YLR178C   TFS1  Inhibitor of carboxypeptidase Y (Prc1p), and R...
# 1510  YNL098C   RAS2  GTP-binding protein; regulates nitrogen starva...
# 1519  YNL085W   MKT1  Protein similar to nucleases that forms a comp...
# 1527  YNL076W   MKS1  Pleiotropic negative transcriptional regulator...
# 1582  YNR001C   CIT1  Citrate synthase; catalyzes the condensation o...
# 1605  YNR031C   SSK2  MAP kinase kinase kinase of HOG1 mitogen-activ...
# 1709  YOL081W   IRA2  GTPase-activating protein; negatively regulate...
# 2051  YOR371C   GPB1  Multistep regulator of cAMP-PKA signaling; inh...
# 2605  YBR140C   IRA1  GTPase-activating protein; negatively regulate...
# 3007  YDL035C   GPR1  Plasma membrane G protein coupled receptor (GP...
# 3104  YDR099W   BMH2  14-3-3 protein, minor isoform; controls proteo...
# 3240  YDR277C   MTH1  Negative regulator of the glucose-sensing sign...
# 3349  YDR421W  ARO80  Zinc finger transcriptional activator of the Z...
# 3485  YEL007W   MIT1  Transcriptional regulator of pseudohyphal grow...
# 3546  YER073W   ALD5  Mitochondrial aldehyde dehydrogenase; involved...
# 3622  YER165W   PAB1  Poly(A) binding protein; part of the 3'-end RN...
# 3748  YGL252C   RTG2  Sensor of mitochondrial dysfunction; regulates...
# 3867  YGL094C   PAN2  Catalytic subunit of the Pan2p-Pan3p poly(A)-r...
# 4154  YHL021C  AIM17  Protein of unknown function; the authentic, no...
# 4240  YHR082C   KSP1  Serine/threonine protein kinase; associates wi...
# 4323  YHR186C   KOG1  Subunit of TORC1; TORC1 is a rapamycin-sensiti...
# 4340  YHR205W   SCH9  AGC family protein kinase; functional ortholog...
# 4382  YIL125W   KGD1  Subunit of the mitochondrial alpha-ketoglutara...
#
#       essential  Eno2_log2fc  Fas1_log2fc  Fas2_log2fc  Htb2_log2fc
# 7         False     0.131452    -0.131322     0.295758     0.234837  \
# 128       False     0.292660    -0.162829    -0.475922     0.371039
# 149       False     0.358599     0.247571     0.211149    -0.315836
# 222        True    -0.437842     1.040981     0.653761    -1.021212
# 273       False     0.224548     0.438747     0.416591     0.351381
# 441       False     0.330759     0.112492     0.179883     0.243224
# 486       False     0.037996     0.205923     0.121686     0.144571
# 627       False    -0.078645     0.538691     0.448439     0.262208
# 718       False     0.166924    -0.280478    -0.357156    -0.187872
# 765       False     0.348497     0.321849     0.442792    -0.461653
# 1510      False     0.357265    -0.305792     0.251459    -0.357104
# 1519      False     0.409155     0.204622     0.592959     0.193389
# 1527      False     0.539886    -0.925909    -0.749478     0.469134
# 1582      False    -0.261598    -0.504396    -0.205604     0.395013
# 1605      False     0.641601     0.451505    -0.812931    -0.650149
# 1709      False     0.719536    -0.547796    -0.408269    -0.453311
# 2051      False     0.374846    -0.311614     0.390019     0.400664
# 2605       True     0.762501     0.283887    -0.617963    -0.576360
# 3007      False    -0.476420     0.264507     0.509203     0.115896
# 3104      False     0.496522    -0.042703     0.045712    -0.068518
# 3240      False     0.276232     0.175558     0.278425    -0.061535
# 3349      False    -0.119768     0.296316    -0.449746     0.072008
# 3485      False    -0.250892     0.363082     0.107116    -0.388214
# 3546      False    -0.337860     0.208346    -0.211006     0.327596
# 3622       True     0.444172     1.267880     0.342243    -0.703585
# 3748      False    -0.088576    -0.107496    -0.007038     0.305326
# 3867      False     0.062851     0.206803     0.239568    -0.217364
# 4154      False     0.224389    -0.095391     0.452468     0.066520
# 4240      False     0.061697    -0.324665    -0.503008     0.223937
# 4323       True    -0.314131    -0.448339     0.661624     0.708230
# 4340      False    -1.390940    -0.259330     0.545211    -0.980819
# 4382      False    -0.265414     0.589357    -0.376637    -0.332067
#
# 1519  5.798965e-01  0.767652  2.200736e-01  8.998058e-01  0.864177
# 1527  1.362631e-01  0.898343  2.536170e-02  6.353285e-01  0.360208
# 1582  7.198931e-01  0.745041  6.559801e-01  9.003469e-01  0.901092
# 1605  2.422472e-01  0.819557  5.382444e-01  6.877824e-01  0.901092
# 1709  6.647730e-05  0.855798  1.538410e-03  3.782747e-18  0.024714
# 2051  4.489359e-01  0.822376  1.055377e-01  4.075175e-01  0.792464
# 2605  4.791525e-07  0.296344  1.869320e-04  5.733254e-04  0.787886
# 3007  2.362300e-01  0.504197  7.392848e-02  4.918145e-01  0.877806
# 3104  3.165819e-01  0.822376  8.509218e-01  9.323463e-01  0.901092
# 3240  3.027353e-01  0.821640  6.014309e-01  8.806882e-01  0.901092
# 3349  6.954622e-01  0.769353  8.511161e-01  9.516692e-01  0.825506
# 3485  1.590888e-01  0.862955  1.204023e-02  9.250069e-01  0.901092
# 3546  4.968004e-01  0.908709  7.897013e-01  4.306852e-01  0.874253
# 3622  2.235057e-01  0.761378  1.915532e-01  8.494604e-01  0.557981
# 3748  6.920325e-01  0.859943  8.506701e-01  7.543126e-01  0.901092
# 3867  5.608339e-01  0.884155  7.419328e-01  8.628893e-01  0.901092
# 4154  4.228982e-01  0.894286  7.218174e-01  5.638688e-01  0.620660
# 4240  6.014555e-01  0.882430  8.511161e-01  7.323267e-01  0.901092
# 4323  7.448008e-03  0.844297  6.837325e-01  1.784479e-01  0.617952
# 4340  1.142108e-57  0.120915  6.052746e-01  4.727314e-01  0.050356
# 4382  2.899388e-01  0.397743  3.866035e-01  8.494604e-01  0.901092
#
#             Yhb1_q  FDR0.05_count
# 7     9.250724e-01              0
# 128   1.416735e-01              1
# 149   2.218198e-26              1
# 222   6.347083e-24              5
# 273   4.549676e-01              0
# 441   9.286473e-01              0
# 486   9.524157e-01              0
# 627   6.576012e-08              1
# 718   2.270609e-03              1
# 765   6.052869e-01              0
# 1510  1.598344e-02              2
# 1519  8.739497e-01              0
# 1527  7.800053e-01              2
# 1582  8.501557e-01              0
# 1605  2.710276e-02              1
# 1709  4.293468e-08              7
# 2051  2.299167e-03              1
# 2605  1.228329e-06              5
# 3007  2.050191e-01              0
# 3104  7.617766e-02              1
# 3240  9.286473e-01              0
# 3349  9.360865e-01              0
# 3485  1.381961e-04              2
# 3546  8.981324e-01              0
# 3622  5.856138e-01              2
# 3748  9.536692e-01              0
# 3867  8.287753e-01              0
# 4154  6.714931e-01              0
# 4240  8.739497e-01              0
# 4323  9.103915e-03              2
# 4340  3.330744e-01              3
# 4382  2.981290e-01              0
#
# [32 rows x 27 columns]

# %%
plt.figure()
for gene in overlapping_gene_list:
    
    this_gene = overlapping_genes[overlapping_genes['gene']==gene]
    
    print(this_gene[q_cols].values[0])
    print(tools.find_mutation_color(gene))
    plt.plot(range(len(this_gene[q_cols].values[0])),this_gene[q_cols].values[0],
             label=gene,color=tools.find_mutation_color(gene),marker='o')
plt.xticks(range(len(q_cols)),q_cols)

plt.ylim(0,0.1)
# plt.legend()
# Out:
# [0.87789648 0.89920928 0.988598   0.57899891 0.89775406 0.2176498
#  0.90807613 0.42821269 0.77930474 0.874905   0.92507241]
# #2171b5
# #9ecae1
# [0.01765024 0.89671938 0.99576179 0.78148897 0.8993743  0.31658193
#  0.8223758  0.85092184 0.93234626 0.90109193 0.07617766]
# #af6f09
# [0.71689495 0.89671938 0.9835551  0.82284508 0.9139757  0.30273527
#  0.82163976 0.60143092 0.88068825 0.90109193 0.92864727]
# steelblue
# [0.91629005 0.853231   0.83437998 0.84770031 0.89889626 0.69546222
#  0.76935333 0.85111611 0.95166915 0.82550573 0.93608647]
# #e377c2
# [8.25229362e-01 7.03493673e-01 9.89054877e-01 3.59288621e-01
#  8.99374302e-01 1.59088776e-01 8.62954775e-01 1.20402337e-02
#  9.25006851e-01 9.01091930e-01 1.38196139e-04]
# (0.4, 0.7607843137254902, 0.6470588235294118)
# [0.72396683 0.89920928 0.9835551  0.53720006 0.8993743  0.49680039
#  0.90870873 0.7897013  0.43068524 0.87425292 0.89813236]
# #bae4b3
# [0.74891257 0.02043251 0.85550611 0.03972981 0.85899492 0.22350568
#  0.7613781  0.19155318 0.84946036 0.55798093 0.58561376]
# (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)
# [0.91853875 0.89671938 0.99787879 0.52786483 0.8563799  0.69203252
#  0.85994253 0.85067012 0.75431263 0.90109193 0.9536692 ]
# #8c510a
# [0.92229173 0.89671938 0.9835551  0.76014623 0.89192094 0.56083388
#  0.88415496 0.74193276 0.86288928 0.90109193 0.8287753 ]
# #a50f15
# [0.90287437 0.90045827 0.9835551  0.84976516 0.8993743  0.42289818
#  0.8942855  0.7218174  0.56386881 0.62066039 0.67149308]
# #fc9272
# [0.93229951 0.89846253 0.82966909 0.42613486 0.74678938 0.60145552
#  0.88242957 0.85111611 0.7323267  0.90109193 0.87394967]
# #54278f
# [0.71042389 0.55682177 0.70208836 0.05754342 0.35826038 0.00744801
#  0.84429675 0.68373249 0.17844789 0.61795166 0.00910391]
# #807dba
# [3.13314000e-04 7.80106577e-01 8.37662493e-01 1.40807998e-02
#  6.40123387e-02 1.14210757e-57 1.20915138e-01 6.05274630e-01
#  4.72731390e-01 5.03556071e-02 3.33074368e-01]
# #807dba
# [0.80840347 0.47198791 0.80991281 0.62131013 0.87301841 0.28993883
#  0.39774254 0.3866035  0.84946036 0.90109193 0.29812902]
# #31a354
# (0.0, 0.1)

# %%
overlapping_genes.sort_values('FDR0.05_count',ascending=False)
# Out:
#       geneSys   gene                                          geneDescr
# 1709  YOL081W   IRA2  GTPase-activating protein; negatively regulate...  \
# 222   YJL005W   CYR1  Adenylate cyclase; required for cAMP productio...
# 2605  YBR140C   IRA1  GTPase-activating protein; negatively regulate...
# 4340  YHR205W   SCH9  AGC family protein kinase; functional ortholog...
# 1510  YNL098C   RAS2  GTP-binding protein; regulates nitrogen starva...
# 1527  YNL076W   MKS1  Pleiotropic negative transcriptional regulator...
# 4323  YHR186C   KOG1  Subunit of TORC1; TORC1 is a rapamycin-sensiti...
# 3622  YER165W   PAB1  Poly(A) binding protein; part of the 3'-end RN...
# 3485  YEL007W   MIT1  Transcriptional regulator of pseudohyphal grow...
# 3104  YDR099W   BMH2  14-3-3 protein, minor isoform; controls proteo...
# 128   YJL128C   PBS2  MAP kinase kinase of the HOG signaling pathway...
# 1605  YNR031C   SSK2  MAP kinase kinase kinase of HOG1 mitogen-activ...
# 2051  YOR371C   GPB1  Multistep regulator of cAMP-PKA signaling; inh...
# 718   YLR113W   HOG1  Mitogen-activated protein kinase involved in o...
# 627   YLL013C   PUF3  Protein of the mitochondrial outer surface; li...
# 149   YJL101C   GSH1  Gamma glutamylcysteine synthetase; catalyzes t...
# 3748  YGL252C   RTG2  Sensor of mitochondrial dysfunction; regulates...
# 3867  YGL094C   PAN2  Catalytic subunit of the Pan2p-Pan3p poly(A)-r...
# 4154  YHL021C  AIM17  Protein of unknown function; the authentic, no...
# 4240  YHR082C   KSP1  Serine/threonine protein kinase; associates wi...
# 3546  YER073W   ALD5  Mitochondrial aldehyde dehydrogenase; involved...
# 7     YAL056W   GPB2  Multistep regulator of cAMP-PKA signaling; inh...
# 3349  YDR421W  ARO80  Zinc finger transcriptional activator of the Z...
# 3240  YDR277C   MTH1  Negative regulator of the glucose-sensing sign...
# 3007  YDL035C   GPR1  Plasma membrane G protein coupled receptor (GP...
# 1582  YNR001C   CIT1  Citrate synthase; catalyzes the condensation o...
# 1519  YNL085W   MKT1  Protein similar to nucleases that forms a comp...
# 765   YLR178C   TFS1  Inhibitor of carboxypeptidase Y (Prc1p), and R...
# 486   YKL025C   PAN3  Essential subunit of the Pan2p-Pan3p poly(A)-r...
# 441   YKL085W   MDH1  Mitochondrial malate dehydrogenase; catalyzes ...
# 273   YJR066W   TOR1  PIK-related protein kinase and rapamycin targe...
# 4382  YIL125W   KGD1  Subunit of the mitochondrial alpha-ketoglutara...
#
#       essential  Eno2_log2fc  Fas1_log2fc  Fas2_log2fc  Htb2_log2fc
# 1709      False     0.719536    -0.547796    -0.408269    -0.453311  \
# 222        True    -0.437842     1.040981     0.653761    -1.021212
# 2605       True     0.762501     0.283887    -0.617963    -0.576360
# 4340      False    -1.390940    -0.259330     0.545211    -0.980819
# 1510      False     0.357265    -0.305792     0.251459    -0.357104
# 1527      False     0.539886    -0.925909    -0.749478     0.469134
# 4323       True    -0.314131    -0.448339     0.661624     0.708230
# 3622       True     0.444172     1.267880     0.342243    -0.703585
# 3485      False    -0.250892     0.363082     0.107116    -0.388214
# 3104      False     0.496522    -0.042703     0.045712    -0.068518
# 128       False     0.292660    -0.162829    -0.475922     0.371039
# 1605      False     0.641601     0.451505    -0.812931    -0.650149
# 2051      False     0.374846    -0.311614     0.390019     0.400664
# 718       False     0.166924    -0.280478    -0.357156    -0.187872
# 627       False    -0.078645     0.538691     0.448439     0.262208
# 149       False     0.358599     0.247571     0.211149    -0.315836
# 3748      False    -0.088576    -0.107496    -0.007038     0.305326
# 3867      False     0.062851     0.206803     0.239568    -0.217364
# 4154      False     0.224389    -0.095391     0.452468     0.066520
# 4240      False     0.061697    -0.324665    -0.503008     0.223937
# 3546      False    -0.337860     0.208346    -0.211006     0.327596
# 7         False     0.131452    -0.131322     0.295758     0.234837
# 3349      False    -0.119768     0.296316    -0.449746     0.072008
# 3240      False     0.276232     0.175558     0.278425    -0.061535
# 3007      False    -0.476420     0.264507     0.509203     0.115896
# 1582      False    -0.261598    -0.504396    -0.205604     0.395013
# 3622  2.235057e-01  0.761378  1.915532e-01  8.494604e-01  0.557981
# 3485  1.590888e-01  0.862955  1.204023e-02  9.250069e-01  0.901092
# 3104  3.165819e-01  0.822376  8.509218e-01  9.323463e-01  0.901092
# 128   1.580827e-02  0.858994  8.403312e-01  8.957321e-01  0.901092
# 1605  2.422472e-01  0.819557  5.382444e-01  6.877824e-01  0.901092
# 2051  4.489359e-01  0.822376  1.055377e-01  4.075175e-01  0.792464
# 718   3.753864e-01  0.756777  7.634678e-01  3.497492e-01  0.900950
# 627   2.572642e-01  0.826872  7.790487e-01  9.624190e-01  0.874843
# 149   3.826035e-01  0.861858  6.373650e-01  6.662431e-01  0.894798
# 3748  6.920325e-01  0.859943  8.506701e-01  7.543126e-01  0.901092
# 3867  5.608339e-01  0.884155  7.419328e-01  8.628893e-01  0.901092
# 4154  4.228982e-01  0.894286  7.218174e-01  5.638688e-01  0.620660
# 4240  6.014555e-01  0.882430  8.511161e-01  7.323267e-01  0.901092
# 3546  4.968004e-01  0.908709  7.897013e-01  4.306852e-01  0.874253
# 7     2.176498e-01  0.908076  4.282127e-01  7.793047e-01  0.874905
# 3349  6.954622e-01  0.769353  8.511161e-01  9.516692e-01  0.825506
# 3240  3.027353e-01  0.821640  6.014309e-01  8.806882e-01  0.901092
# 3007  2.362300e-01  0.504197  7.392848e-02  4.918145e-01  0.877806
# 1582  7.198931e-01  0.745041  6.559801e-01  9.003469e-01  0.901092
# 1519  5.798965e-01  0.767652  2.200736e-01  8.998058e-01  0.864177
# 765   6.508685e-01  0.898343  5.393235e-01  8.217707e-01  0.901092
# 486   6.247374e-01  0.881507  8.612772e-01  9.629710e-01  0.901092
# 441   6.449056e-01  0.893959  6.925713e-01  9.370879e-01  0.880688
# 273   6.677862e-01  0.608789  2.490638e-01  5.905703e-01  0.885443
# 4382  2.899388e-01  0.397743  3.866035e-01  8.494604e-01  0.901092
#
#             Yhb1_q  FDR0.05_count
# 1709  4.293468e-08              7
# 222   6.347083e-24              5
# 2605  1.228329e-06              5
# 4340  3.330744e-01              3
# 1510  1.598344e-02              2
# 1527  7.800053e-01              2
# 4323  9.103915e-03              2
# 3622  5.856138e-01              2
# 3485  1.381961e-04              2
# 3104  7.617766e-02              1
# 128   1.416735e-01              1
# 1605  2.710276e-02              1
# 2051  2.299167e-03              1
# 718   2.270609e-03              1
# 627   6.576012e-08              1
# 149   2.218198e-26              1
# 3748  9.536692e-01              0
# 3867  8.287753e-01              0
# 4154  6.714931e-01              0
# 4240  8.739497e-01              0
# 3546  8.981324e-01              0
# 7     9.250724e-01              0
# 3349  9.360865e-01              0
# 3240  9.286473e-01              0
# 3007  2.050191e-01              0
# 1582  8.501557e-01              0
# 1519  8.739497e-01              0
# 765   6.052869e-01              0
# 486   9.524157e-01              0
# 441   9.286473e-01              0
# 273   4.549676e-01              0
# 4382  2.981290e-01              0
#
# [32 rows x 27 columns]

# %%
first_step_genes = tools.gene_pathway_map['Ras/PKA'] + ['TOR1','SCH9']
first_step_counts = []
second_step_counts = []

np.random.seed(99)
for gene in overlapping_gene_list:
    
    
    if gene in first_step_genes:
        this_count = overlapping_genes[overlapping_genes['gene']==gene]['FDR0.05_count'].values[0]
        first_step_counts.append(this_count)
        
        jitter = tools.jitter_point(0,0.05)
        
        plt.scatter(jitter,this_count,color=tools.find_mutation_color(gene))
        
        if this_count > 1:
            plt.annotate(gene,(jitter,this_count),(jitter+0.05,this_count+0.1),color=tools.find_mutation_color(gene))
        
    else:
        this_count = overlapping_genes[overlapping_genes['gene']==gene]['FDR0.05_count'].values[0]
        second_step_counts.append(this_count)
        
        jitter = tools.jitter_point(1,0.05)
        
        plt.scatter(jitter,this_count,color=tools.find_mutation_color(gene))
#         plt.annotate(gene,(jitter,this_count),(jitter+0.2,this_count+0.1),color=tools.find_mutation_color(gene))

plt.boxplot(first_step_counts,positions=[0])
plt.boxplot(second_step_counts,positions=[1])

plt.title('Number of proteins affected from Schubert et al 2022')
        
plt.ylabel('Number of Proteins with differential abundance (of 11 total)')
plt.xticks([0,1],['First Step Mutations','Second Step Mutations'])

plt.ylim(-0.5,11)

ttest = scipy.stats.ttest_ind(first_step_counts,second_step_counts)

plt.annotate(f'p={ttest.pvalue:.3f}', xy=(0.5,0.75), xytext=(0.5,0.8),xycoords='axes fraction',ha='center', va='bottom',
           arrowprops=dict(arrowstyle='-[, widthB=9, lengthB=0.5', lw=1.0,color='k'))


plt.savefig(f'{home_dir}/figures/analysis/modularity/modularity_of_protein_abundance.pdf',bbox_inches='tight')

# %%
first_step_genes = tools.gene_pathway_map['Ras/PKA'] + ['TOR1','SCH9']
first_step_counts = []
second_step_counts = []

np.random.seed(99)

fdr = 0.01
for gene in overlapping_gene_list:
    
    
    if gene in first_step_genes:
        this_count = np.sum(overlapping_genes[overlapping_genes['gene']==gene][q_cols].values < fdr)
        first_step_counts.append(this_count)
        
        jitter = tools.jitter_point(0,0.05)
        
        plt.scatter(jitter,this_count,color=tools.find_mutation_color(gene))
        
        if this_count > 1:
            plt.annotate(gene,(jitter,this_count),(jitter+0.05,this_count+0.1),color=tools.find_mutation_color(gene))
        
    else:
        this_count = np.sum(overlapping_genes[overlapping_genes['gene']==gene][q_cols].values < fdr)
        second_step_counts.append(this_count)
        
        jitter = tools.jitter_point(1,0.05)
        
        plt.scatter(jitter,this_count,color=tools.find_mutation_color(gene))
#         plt.annotate(gene,(jitter,this_count),(jitter+0.2,this_count+0.1),color=tools.find_mutation_color(gene))

plt.boxplot(first_step_counts,positions=[0])
plt.boxplot(second_step_counts,positions=[1])

plt.title('Data from Schubert et al 2022')
        
plt.ylabel(f'Number of proteins with differential abundance (FDR = {fdr:.2f})')
plt.xticks([0,1],['First Step Mutations','Second Step Mutations'])

plt.ylim(-0.5,11)

ttest = scipy.stats.ttest_ind(first_step_counts,second_step_counts)

plt.annotate(f'p={ttest.pvalue:.3f}', xy=(0.5,0.75), xytext=(0.5,0.8),xycoords='axes fraction',ha='center', va='bottom',
           arrowprops=dict(arrowstyle='-[, widthB=9, lengthB=0.5', lw=1.0,color='k'))


plt.savefig(f'{home_dir}/figures/analysis/modularity/modularity_of_protein_abundance_FDR{fdr}.pdf',bbox_inches='tight')

# %%
np.sum(overlapping_genes[overlapping_genes['gene']==gene][q_cols].values < 0.9)
# Out:
# 10
