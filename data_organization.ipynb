# %%
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib
import scipy
from scipy import stats
# from adjustText import adjust_text
from Bio import SeqIO
from Bio.Seq import Seq
# %matplotlib inline

import copy

# %load_ext autoreload
# %autoreload 2

from matplotlib import gridspec
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

from itertools import combinations
from itertools import combinations_with_replacement
from itertools import permutations
from itertools import product
from ast import literal_eval

import sys
import os

home_dir = '~/Documents/Stanford/Research/EvolvingFront/'
home_dir = os.path.expanduser(home_dir)

tools_path = f'{home_dir}/code/processing/tools/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools as tools
import figures as figures

sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

# %%
merged_fitness = p.read_csv(f'{home_dir}/data/fitness_withMutations.csv',index_col=0)
# noLi2019 = merged_fitness[merged_fitness['source_publication']!='Li2019']

# %%
list(merged_fitness.columns)
# Out:
# ['Fit1D-2%-R1_fitness',
#  'Fit1D-2%-R1_error',
#  'Fit1D-2%-R2_fitness',
#  'Fit1D-2%-R2_error',
#  'Fit1D-5%-R1_fitness',
#  'Fit1D-5%-R1_error',
#  'Fit1D-5%-R2_fitness',
#  'Fit1D-5%-R2_error',
#  'Fit2D-2%-R1_fitness',
#  'Fit2D-2%-R1_error',
#  'Fit2D-2%-R2_fitness',
#  'Fit2D-2%-R2_error',
#  'Fit2D-5%-R1_fitness',
#  'Fit2D-5%-R1_error',
#  'Fit2D-5%-R2_fitness',
#  'Fit2D-5%-R2_error',
#  'Fit3D-2%-R1_fitness',
#  'Fit3D-2%-R1_error',
#  'Fit3D-2%-R2_fitness',
#  'Fit3D-2%-R2_error',
#  'Fit3D-2%-R3_fitness',
#  'Fit3D-2%-R3_error',
#  'Fit3D-5%-R1_fitness',
#  'Fit3D-5%-R1_error',
#  'Fit3D-5%-R2_fitness',
#  'Fit3D-5%-R2_error',
#  'Fit3D-5%-R3_fitness',
#  'Fit3D-5%-R3_error',
#  'Fit5D-2%-R1_fitness',
#  'Fit5D-2%-R1_error',
#  'Fit5D-2%-R2_fitness',
#  'Fit5D-2%-R2_error',
#  'Fit5D-2%-R3_fitness',
#  'Fit5D-2%-R3_error',
#  'Fit5D-5%-R1_fitness',
#  'Fit5D-5%-R1_error',
#  'Fit5D-5%-R2_fitness',
#  'Fit5D-5%-R2_error',
#  'Fit5D-5%-R3_fitness',
#  'Fit5D-5%-R3_error',
#  'BCID',
#  'Fit1D-5%-R1-T2',
#  'Fit5D-2%-R2-T2-PCRb',
#  'Fit1D-2%-R1-T4',
#  'Fit5D-2%-R2-T1',
#  'Fit2D-2%-R1-T1',
#  'Fit5D-2%-R3-T2',
#  'Fit3D-2%-R3-T2',
#  'Fit3D-5%-R2-T2-PCRb',
#  'Fit2D-5%-R2-T2',
#  'Fit1D-2%-R1-T3',
#  'Fit1D-2%-R1-T6',
#  'Fit2D-2%-R1-T4',
#  'Fit5D-2%-R3-T1',
#  'Fit2D-5%-R1-T4',
#  'Fit1D-2%-R1-T2',
#  'Fit2D-2%-R2-T4',
#  'Fit5D-5%-R3-T2',
#  'Fit2D-5%-R1-T2',
#  'Fit2D-2%-R1-T5',
#  'Fit2D-5%-R2-T5',
#  'Fit3D-5%-R2-T1',
#  'Fit1D-2%-T0',
#  'Fit3D-2%-T0',
#  'Fit2D-5%-R1-T1',
#  'Fit3D-2%-R1-T2',
#  'Fit1D-2%-R2-T3',
#  'Fit1D-2%-R2-T6',
#  'Fit3D-5%-R3-T2',
#  'Fit2D-5%-R1-T6',
#  'Fit1D-5%-R1-T3',
#  'Fit5D-5%-R3-T1',
#  'Fit3D-5%-T0',
#  'Fit1D-5%-R1-T5',
#  'Fit5D-5%-R1-T2',
#  'Fit5D-2%-T0',
#  'Fit2D-2%-R1-T2',
#  'Fit2D-2%-R2-T6',
#  'Fit5D-5%-R3-T2-PCRb',
#  'Fit2D-2%-R2-T2',
#  'Fit2D-2%-R2-T5',
#  'Fit5D-2%-R1-T2',
#  'Fit3D-2%-R3-T1',
#  'Fit2D-5%-R1-T5',
#  'Fit3D-5%-R1-T1',
#  'Fit1D-5%-T0',
#  'Fit3D-5%-R2-T2',
#  'Fit3D-5%-R1-T2',
#  'Fit2D-2%-R1-T6',
#  'Fit3D-5%-R3-T1',
#  'Fit1D-2%-R1-T1',
#  'Fit5D-2%-R1-T1',
#  'Fit1D-5%-R1-T6',
#  'Fit1D-5%-R1-T4',
#  'Fit1D-5%-R2-T5',
#  'Fit2D-2%-T0',
#  'Fit3D-2%-R2-T2',
#  'Fit1D-2%-R1-T5',
#  'Fit1D-2%-R2-T4',
#  'Fit2D-5%-R2-T4',
#  'Fit2D-2%-R2-T1',
#  'Fit2D-5%-R1-T3',
#  'Fit5D-5%-T0',
#  'Fit2D-5%-R2-T3',
#  'Fit1D-5%-R2-T4',
#  'Fit3D-2%-R2-T1',
#  'Fit5D-5%-R1-T1',
#  'Fit1D-5%-R2-T6',
#  'Fit1D-2%-R2-T1',
#  'Fit2D-5%-R2-T6',
#  'Fit5D-5%-R2-T2',
#  'Fit2D-2%-R2-T3',
#  'Fit1D-2%-R2-T5',
#  'Fit1D-5%-R2-T1',
#  'Fit1D-5%-R1-T1',
#  'Fit2D-2%-R1-T3',
#  'Fit5D-5%-R2-T1',
#  'Fit2D-5%-T0',
#  'Fit1D-5%-R2-T2',
#  'Fit1D-2%-R2-T2',
#  'Fit2D-5%-R2-T1',
#  'Fit1D-5%-R2-T3',
#  'Fit5D-2%-R2-T2',
#  'Fit3D-5%-R1-T2-PCRb',
#  'Fit5D-5%-R1-T2-PCRb',
#  'Fit3D-2%-R1-T1',
#  'bc_merged',
#  'barcode',
#  'barcode_lowcomplexity',
#  'barcode_highcomplexity',
#  'cloneID',
#  'source_publication',
#  'evolution_condition',
#  'ancestor',
#  'class',
#  'ploidy',
#  'gene',
#  'type',
#  'additional_muts',
#  '1D_Fitness_Li2019',
#  '1D_Error_Li2019',
#  '2D_Fitness_Li2019',
#  '2D_Error_Li2019',
#  '3D_Fitness_Li2019',
#  '3D_Error_Li2019',
#  '5D_Fitness_Li2019',
#  '5D_Error_Li2019',
#  'FerPerHour_Li2019',
#  'ResPerHour_Li2019',
#  'StaPerHour_Li2019',
#  'Fit1D-2%_fitness',
#  'Fit1D-2%_error',
#  'Fit1D-5%_fitness',
#  'Fit1D-5%_error',
#  'Fit2D-2%_fitness',
#  'Fit2D-2%_error',
#  'Fit2D-5%_fitness',
#  'Fit2D-5%_error',
#  'Fit3D-2%_fitness',
#  'Fit3D-2%_error',
#  'Fit3D-5%_fitness',
#  'Fit3D-5%_error',
#  'Fit5D-2%_fitness',
#  'Fit5D-2%_error',
#  'Fit5D-5%_fitness',
#  'Fit5D-5%_error',
#  'Fit1D-2%-R1_fitness_Li2019Neutrals',
#  'Fit1D-2%-R1_error_Li2019Neutrals',
#  'Fit1D-2%-R2_fitness_Li2019Neutrals',
#  'Fit1D-2%-R2_error_Li2019Neutrals',
#  'Fit1D-5%-R1_fitness_Li2019Neutrals',
#  'Fit1D-5%-R1_error_Li2019Neutrals',
#  'Fit1D-5%-R2_fitness_Li2019Neutrals',
#  'Fit1D-5%-R2_error_Li2019Neutrals',
#  'Fit2D-2%-R1_fitness_Li2019Neutrals',
#  'Fit2D-2%-R1_error_Li2019Neutrals',
#  'Fit2D-2%-R2_fitness_Li2019Neutrals',
#  'Fit2D-2%-R2_error_Li2019Neutrals',
#  'Fit2D-5%-R1_fitness_Li2019Neutrals',
#  'Fit2D-5%-R1_error_Li2019Neutrals',
#  'Fit2D-5%-R2_fitness_Li2019Neutrals',
#  'Fit2D-5%-R2_error_Li2019Neutrals',
#  'Fit3D-2%-R1_fitness_Li2019Neutrals',
#  'Fit3D-2%-R1_error_Li2019Neutrals',
#  'Fit3D-2%-R2_fitness_Li2019Neutrals',
#  'Fit3D-2%-R2_error_Li2019Neutrals',
#  'Fit3D-2%-R3_fitness_Li2019Neutrals',
#  'Fit3D-2%-R3_error_Li2019Neutrals',
#  'Fit3D-5%-R1_fitness_Li2019Neutrals',
#  'Fit3D-5%-R1_error_Li2019Neutrals',
#  'Fit3D-5%-R2_fitness_Li2019Neutrals',
#  'Fit3D-5%-R2_error_Li2019Neutrals',
#  'Fit3D-5%-R3_fitness_Li2019Neutrals',
#  'Fit3D-5%-R3_error_Li2019Neutrals',
#  'Fit5D-2%-R1_fitness_Li2019Neutrals',
#  'Fit5D-2%-R1_error_Li2019Neutrals',
#  'Fit5D-2%-R2_fitness_Li2019Neutrals',
#  'Fit5D-2%-R2_error_Li2019Neutrals',
#  'Fit5D-2%-R3_fitness_Li2019Neutrals',
#  'Fit5D-2%-R3_error_Li2019Neutrals',
#  'Fit5D-5%-R1_fitness_Li2019Neutrals',
#  'Fit5D-5%-R1_error_Li2019Neutrals',
#  'Fit5D-5%-R2_fitness_Li2019Neutrals',
#  'Fit5D-5%-R2_error_Li2019Neutrals',
#  'Fit5D-5%-R3_fitness_Li2019Neutrals',
#  'Fit5D-5%-R3_error_Li2019Neutrals',
#  'Fit1D-5%-R1-T2_Li2019Neutrals',
#  'Fit5D-2%-R2-T2-PCRb_Li2019Neutrals',
#  'Fit1D-2%-R1-T4_Li2019Neutrals',
#  'Fit5D-2%-R2-T1_Li2019Neutrals',
#  'Fit2D-2%-R1-T1_Li2019Neutrals',
#  'Fit5D-2%-R3-T2_Li2019Neutrals',
#  'Fit3D-2%-R3-T2_Li2019Neutrals',
#  'Fit3D-5%-R2-T2-PCRb_Li2019Neutrals',
#  'Fit2D-5%-R2-T2_Li2019Neutrals',
#  'Fit1D-2%-R1-T3_Li2019Neutrals',
#  'Fit1D-2%-R1-T6_Li2019Neutrals',
#  'Fit2D-2%-R1-T4_Li2019Neutrals',
#  'Fit5D-2%-R3-T1_Li2019Neutrals',
#  'Fit2D-5%-R1-T4_Li2019Neutrals',
#  'Fit1D-2%-R1-T2_Li2019Neutrals',
#  'Fit2D-2%-R2-T4_Li2019Neutrals',
#  'Fit5D-5%-R3-T2_Li2019Neutrals',
#  'Fit2D-5%-R1-T2_Li2019Neutrals',
#  'Fit2D-2%-R1-T5_Li2019Neutrals',
#  'Fit2D-5%-R2-T5_Li2019Neutrals',
#  'Fit3D-5%-R2-T1_Li2019Neutrals',
#  'Fit1D-2%-T0_Li2019Neutrals',
#  'Fit3D-2%-T0_Li2019Neutrals',
#  'Fit2D-5%-R1-T1_Li2019Neutrals',
#  'Fit3D-2%-R1-T2_Li2019Neutrals',
#  'Fit1D-2%-R2-T3_Li2019Neutrals',
#  'Fit1D-2%-R2-T6_Li2019Neutrals',
#  'Fit3D-5%-R3-T2_Li2019Neutrals',
#  'Fit2D-5%-R1-T6_Li2019Neutrals',
#  'Fit1D-5%-R1-T3_Li2019Neutrals',
#  'Fit5D-5%-R3-T1_Li2019Neutrals',
#  'Fit3D-5%-T0_Li2019Neutrals',
#  'Fit1D-5%-R1-T5_Li2019Neutrals',
#  'Fit5D-5%-R1-T2_Li2019Neutrals',
#  'Fit5D-2%-T0_Li2019Neutrals',
#  'Fit2D-2%-R1-T2_Li2019Neutrals',
#  'Fit2D-2%-R2-T6_Li2019Neutrals',
#  'Fit5D-5%-R3-T2-PCRb_Li2019Neutrals',
#  'Fit2D-2%-R2-T2_Li2019Neutrals',
#  'Fit2D-2%-R2-T5_Li2019Neutrals',
#  'Fit5D-2%-R1-T2_Li2019Neutrals',
#  'Fit3D-2%-R3-T1_Li2019Neutrals',
#  'Fit2D-5%-R1-T5_Li2019Neutrals',
#  'Fit3D-5%-R1-T1_Li2019Neutrals',
#  'Fit1D-5%-T0_Li2019Neutrals',
#  'Fit3D-5%-R2-T2_Li2019Neutrals',
#  'Fit3D-5%-R1-T2_Li2019Neutrals',
#  'Fit2D-2%-R1-T6_Li2019Neutrals',
#  'Fit3D-5%-R3-T1_Li2019Neutrals',
#  'Fit1D-2%-R1-T1_Li2019Neutrals',
#  'Fit5D-2%-R1-T1_Li2019Neutrals',
#  'Fit1D-5%-R1-T6_Li2019Neutrals',
#  'Fit1D-5%-R1-T4_Li2019Neutrals',
#  'Fit1D-5%-R2-T5_Li2019Neutrals',
#  'Fit2D-2%-T0_Li2019Neutrals',
#  'Fit3D-2%-R2-T2_Li2019Neutrals',
#  'Fit1D-2%-R1-T5_Li2019Neutrals',
#  'Fit1D-2%-R2-T4_Li2019Neutrals',
#  'Fit2D-5%-R2-T4_Li2019Neutrals',
#  'Fit2D-2%-R2-T1_Li2019Neutrals',
#  'Fit2D-5%-R1-T3_Li2019Neutrals',
#  'Fit5D-5%-T0_Li2019Neutrals',
#  'Fit2D-5%-R2-T3_Li2019Neutrals',
#  'Fit1D-5%-R2-T4_Li2019Neutrals',
#  'Fit3D-2%-R2-T1_Li2019Neutrals',
#  'Fit5D-5%-R1-T1_Li2019Neutrals',
#  'Fit1D-5%-R2-T6_Li2019Neutrals',
#  'Fit1D-2%-R2-T1_Li2019Neutrals',
#  'Fit2D-5%-R2-T6_Li2019Neutrals',
#  'Fit5D-5%-R2-T2_Li2019Neutrals',
#  'Fit2D-2%-R2-T3_Li2019Neutrals',
#  'Fit1D-2%-R2-T5_Li2019Neutrals',
#  'Fit1D-5%-R2-T1_Li2019Neutrals',
#  'Fit1D-5%-R1-T1_Li2019Neutrals',
#  'Fit2D-2%-R1-T3_Li2019Neutrals',
#  'Fit5D-5%-R2-T1_Li2019Neutrals',
#  'Fit2D-5%-T0_Li2019Neutrals',
#  'Fit1D-5%-R2-T2_Li2019Neutrals',
#  'Fit1D-2%-R2-T2_Li2019Neutrals',
#  'Fit2D-5%-R2-T1_Li2019Neutrals',
#  'Fit1D-5%-R2-T3_Li2019Neutrals',
#  'Fit5D-2%-R2-T2_Li2019Neutrals',
#  'Fit3D-5%-R1-T2-PCRb_Li2019Neutrals',
#  'Fit5D-5%-R1-T2-PCRb_Li2019Neutrals',
#  'Fit3D-2%-R1-T1_Li2019Neutrals',
#  '1D_Fitness_Li2019_Li2019Neutrals',
#  '2D_Fitness_Li2019_Li2019Neutrals',
#  '3D_Fitness_Li2019_Li2019Neutrals',
#  '5D_Fitness_Li2019_Li2019Neutrals',
#  'Fit1D-2%_fitness_Li2019Neutrals',
#  'Fit1D-2%_error_Li2019Neutrals',
#  'Fit1D-5%_fitness_Li2019Neutrals',
#  'Fit1D-5%_error_Li2019Neutrals',
#  'Fit2D-2%_fitness_Li2019Neutrals',
#  'Fit2D-2%_error_Li2019Neutrals',
#  'Fit2D-5%_fitness_Li2019Neutrals',
#  'Fit2D-5%_error_Li2019Neutrals',
#  'Fit3D-2%_fitness_Li2019Neutrals',
#  'Fit3D-2%_error_Li2019Neutrals',
#  'Fit3D-5%_fitness_Li2019Neutrals',
#  'Fit3D-5%_error_Li2019Neutrals',
#  'Fit5D-2%_fitness_Li2019Neutrals',
#  'Fit5D-2%_error_Li2019Neutrals',
#  'Fit5D-5%_fitness_Li2019Neutrals',
#  'Fit5D-5%_error_Li2019Neutrals',
#  'cloneID_new',
#  'ploidy_new',
#  'all_mutations',
#  'all_mutations_verbose',
#  'effect',
#  'other_genes',
#  'Fit1D_both2%5%_fitness',
#  'Fit1D_both2%5%_error',
#  'Fit1D_both2%5%_fitness_Li2019Neutrals',
#  'Fit1D_both2%5%_error_Li2019Neutrals',
#  'Fit2D_both2%5%_fitness',
#  'Fit2D_both2%5%_error',
#  'Fit2D_both2%5%_fitness_Li2019Neutrals',
#  'Fit2D_both2%5%_error_Li2019Neutrals',
#  'Fit3D_both2%5%_fitness',
#  'Fit3D_both2%5%_error',
#  'Fit3D_both2%5%_fitness_Li2019Neutrals',
#  'Fit3D_both2%5%_error_Li2019Neutrals',
#  'Fit5D_both2%5%_fitness',
#  'Fit5D_both2%5%_error',
#  'Fit5D_both2%5%_fitness_Li2019Neutrals',
#  'Fit5D_both2%5%_error_Li2019Neutrals',
#  'Fit2D_early_fitness',
#  'Fit2D_early_error',
#  'Fit3D_early_fitness',
#  'Fit3D_early_error',
#  'Fit5D_early_fitness',
#  'Fit5D_early_error',
#  'Fit2D_early-Fit1D_both2%5%_fitness',
#  'Fit2D_early-Fit1D_both2%5%_error',
#  'Fit5D_early-Fit3D_early_fitness',
#  'Fit5D_early-Fit3D_early_error',
#  'ResPerHour',
#  'FerPerHour',
#  'StaPerHour',
#  'ResPerHour_error',
#  'FerPerHour_error',
#  'StaPerHour_error',
#  'class_new',
#  'FerPerHour_relative',
#  'FerPerHour_ancestor',
#  'ResPerHour_relative',
#  'ResPerHour_ancestor',
#  'StaPerHour_relative',
#  'StaPerHour_ancestor',
#  'Fit1D_both2%5%_fitness_relative',
#  'Fit1D_both2%5%_fitness_ancestor',
#  'Fit2D_both2%5%_fitness_relative',
#  'Fit2D_both2%5%_fitness_ancestor',
#  'Fit2D_early_fitness_relative',
#  'Fit2D_early_fitness_ancestor',
#  'Fit3D_early_fitness_relative',
#  'Fit3D_early_fitness_ancestor',
#  'Fit5D_early_fitness_relative',
#  'Fit5D_early_fitness_ancestor']

# %%
merged_fitness[['barcode','cloneID_new','class_new',
                'ancestor','evolution_condition','source_publication',
                'gene','effect','additional_muts','all_mutations_verbose',
                'ploidy_new',
               'ResPerHour',
             'FerPerHour',
             'StaPerHour',
             'ResPerHour_error',
             'FerPerHour_error',
         'StaPerHour_error',
         'FerPerHour_relative',
#          'FerPerHour_ancestor',
         'ResPerHour_relative',
#          'ResPerHour_ancestor',
         'StaPerHour_relative',
#          'StaPerHour_ancestor'
               ]].to_csv('data/Kinsler2024_performance_by_mutant.csv',index=False)
