# %%
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib
# from adjustText import adjust_text
from Bio import SeqIO
from Bio.Seq import Seq
# %matplotlib inline

import scipy

from itertools import combinations

sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

from matplotlib import gridspec
from matplotlib.gridspec import GridSpec

import os
import sys

home_dir = '~/Documents/Stanford/Research/EvolvingFront/'
home_dir = os.path.expanduser(home_dir)

tools_path = f'{home_dir}/code/processing/tools/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools as tools



# sns.set_style('dark')
# sns.set_style('ticks')
# plt.style.use('dark_background')

# %%
condition_properties = {
#                     'Evo1D_IRAs':{1:[0,1,4,7,10,13,16,19,22,24],
#                                       2:[0,1,4,7,10,13,16,19,22,24]},
#                         'Evo1D_TCG':{1:[0,1,4,8,10,13,16,19,22,24],
#                                     2:[0,1,4,8,10,13,16,19,22,24]},
                        
                        
                        'Evo2D_Ira1_Mis':{1:[0,1,4,7,10,13,17,21,25],
                                         2:[0,1,4,7,10,13,17,21,25]
                                         },
#                         'Evo2D_Ira1_Non':{1:[0,1,4,7,10,13,17,21,25],
#                                          2:[0,1,4,7,10,13,17,21,25]},
                        
#                         'Evo2D_CYR1':{1:[0, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160],
#                                          2:[0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 128, 136, 144, 152, 160]},
#                         'Evo2D_GPB2':{1:[0, 8, 32, 56, 64, 80, 104, 120],
#                                          2:[0, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 136, 144, 160]},
#                         'Evo2D_TOR1':{1:[0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160],
#                                          2:[0, 16, 24, 40, 48, 64, 72, 88, 104, 112, 120, 128, 136, 152, 160]},                        
  
                        
#                         'Evo3D_Ira1_Mis':{1:[0,1,4,7,10,14,17,21],
#                                          2:[0,1,4,7,10,14,17,21],
#                                          3:[0,1,4,7,10,14,17,21]},
#                         'Evo3D_Ira1_Non':{1:[0,1,4,7,10,14,17,21],
#                                          2:[0,1,4,7,10,14,17,21],
#                                          3:[0,1,4,7,10,14,17,21]},
                        
#                         'Evo3D_TCG':{1:[0,1,4,7,10,14,17,21],
#                                          2:[0,1,4,7,10,14,17,21]},               
                       }


n_gens = 8
effective_n = 6 * 10**8

# %%
mean_fitness_dict = {}

evolution_fitness_dict = {}

for condition,reps in condition_properties.items():
    this_data = p.read_csv(f'{condition}_counts_curated.csv')

    for rep,timepoints in reps.items():
        
        all_samples = []
        for time in timepoints:
            if time == 0:
                all_samples.append(f'{condition}_0_0_count')
            else:
                all_samples.append(f'{condition}_{rep}_{time}_count')
                
    
        this_data['barcode'] = this_data['fused_bc']

        this_fit_mut = p.read_csv(f'FitMut2_processing/out_fitmut1_thresholded/{condition}_{rep}_MutSeq_Result.csv')

        mean_fitness = this_fit_mut['Mean_Fitness'].values
        mean_fitness = mean_fitness[~np.isnan(mean_fitness)]
        
        mean_fitness_dict[f'{condition}_{rep}'] = mean_fitness

        kappas = this_fit_mut['Kappa_Value'].values
        kappas = kappas[~np.isnan(kappas)]


        mutant_cell_fraction = this_fit_mut['Mutant_Cell_Fraction'].values
        mutant_cell_fraction = mutant_cell_fraction[~np.isnan(mutant_cell_fraction)]

        this_fit_mut = this_fit_mut[['Fitness','Establishment_Time','Error_Fitness','Error_Establishment_Time','Likelihood_Log_Adaptive']]
#         this_fit_mut = this_fit_mut[['Fitness','Establishment_Time','Error_Fitness','Error_Establishment_Time','Probability_Adaptive']]
        this_fit_mut['barcode'] = this_data['barcode'] 
    
        for bc,fitness in zip(this_fit_mut['barcode'].values,this_fit_mut['Fitness'].values):
            if bc in evolution_fitness_dict:
                evolution_fitness_dict[bc][0].append(fitness)
                evolution_fitness_dict[bc][1].append(f'{condition}_R{rep}')

            else:
                evolution_fitness_dict[bc] = [[fitness],[f'{condition}_R{rep}']]

# %%
home_dir = '~/Documents/Stanford/Research/EvolvingFront/'
# home_dir = os.path.expanduser(home_dir)
rearray_map = p.read_csv(f'{home_dir}/data/BenomylTest/EvolvingFront_rearray_map_with_ploidy.csv')

remeasurement_data = p.read_csv(f'{home_dir}/data/fitness_withMutations.csv',index_col=0)

# %%
evolution_fitness_values = {}
evolution_fitness_conditions = {}
evolution_fitness_all = {}

for bc,condition_sets in evolution_fitness_dict.items():
    fs = condition_sets[0]
    conditions = condition_sets[1]
    if bc in remeasurement_data['barcode'].values:
        use_condition_of_origin = False
        evo_cond = remeasurement_data[remeasurement_data['barcode']==bc]['evolution_condition'].values[0]
        cloneID = remeasurement_data[remeasurement_data['barcode']==bc]['cloneID_new'].values[0]
        if cloneID in rearray_map['destination_well'].values:
            use_condition_of_origin = True
            condition_of_origin = rearray_map[rearray_map['destination_well']==cloneID]['source_well'].values[0]
            condition_of_origin = '_'.join(condition_of_origin.split('_')[:-2])
#             print(condition_of_origin)

        fs_filtered = []
        conditions_filtered = []
        for f,cond in zip(fs,conditions):
            if use_condition_of_origin:
                if condition_of_origin == cond.upper():
                    fs_filtered.append(f)
                    conditions_filtered.append(cond)
#                     print('here',condition_of_origin,cond)
            else:
                if evo_cond in cond:
                    fs_filtered.append(f)
                    conditions_filtered.append(cond)

        if not np.any(fs_filtered): # if they are all 0
            evolution_fitness_values[bc] = np.nan
            evolution_fitness_conditions[bc] = np.nan
        else:
#             if np.count_nonzero(fs_filtered) > 1:
#                 print(bc,fs_filtered,conditions_filtered)
#                 print(remeasurement_data)
#             if bc == 'TGATCAATCTACAAAAATATTTAATG_ACGACAATCTCGAATAGGTTTTTCTG': # this barcode has very high fitness in one replicate that's unrealisitic
#                 entry = np.where(fs_filtered==np.min(fs_filtered))[0][0]
#                 evolution_fitness_values[bc] = fs_filtered[entry]
# #                 evolution_fitness_conditions[bc] = conditions_filtered[entry]
#             else:
            evolution_fitness_all[bc] = {condition:f for condition,f in zip(conditions_filtered,fs_filtered)}
            entry = np.where(fs_filtered==np.max(fs_filtered))[0][0]
            evolution_fitness_values[bc] = fs_filtered[entry]
            evolution_fitness_conditions[bc] = conditions_filtered[entry]

# %%
home_dir = '~/Documents/Stanford/Research/EvolvingFront/'
# home_dir = os.path.expanduser(home_dir)
rearray_map = p.read_csv(f'{home_dir}/data/BenomylTest/EvolvingFront_rearray_map_with_ploidy.csv')

remeasurement_data = p.read_csv(f'{home_dir}/data/fitness_withMutations.csv',index_col=0)

evolution_fitness = []
evolution_conditions = []

bcs_isolated_here = []
for bc,cloneID in zip(remeasurement_data['barcode'].values,remeasurement_data['cloneID_new'].values):
    
    if bc in evolution_fitness_values.keys():
        evolution_fitness.append( evolution_fitness_values[bc])
        evolution_conditions.append( evolution_fitness_conditions[bc])
    else:
        evolution_fitness.append(np.nan)
        evolution_conditions.append(np.nan)


remeasurement_data['evolution_fitness'] = evolution_fitness
remeasurement_data['isolated_evolution_condition'] = evolution_conditions
        
# overlapping_bcs = [bc for bc in this_data['barcode'].values if bc in isolated_here['barcode'].values]

# %%
set_to_plot = remeasurement_data[(remeasurement_data['ancestor']=='IRA1_MIS') & 
                   (remeasurement_data['class_new']=='adaptive_haploid') & 
                                (remeasurement_data['evolution_condition']=='Evo2D')]
#                    (remeasurement_data['gene'].isin(['CIT1','KGD1','MDH1','RTG2','ARO80','GSH1']))
#                                 ]

# %%
evolution_fitness_values
# Out:
# {'TGATCAATCTACAAAAATATTTAATG_CTCTTAATAGTGAATATTGTTAACAC': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_CTAAAAACCTTAAATTAATTTCAAAT': 0.0428227913742537,
#  'CATTGAATCACAAAATAGGTTAGATG_TGTTAAACCCATAAATTCGTTTGGCG': 0.0479157797373039,
#  'CATTGAATCACAAAATAGGTTAGATG_CGGTAAACGGGAAACTTGCTTGGGGC': 0.0462686739544508,
#  'CATTGAATCACAAAATAGGTTAGATG_AATCTAACTTTGAAGGTTATTAATTT': 0.0437632761864294,
#  'TGATCAATCTACAAAAATATTTAATG_TGATTAACTAAAAAAGAACTTACATC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GGGCGAAACTGCAAGGCAGTTAGGCG': 0.0481690693292577,
#  'CATTGAATCACAAAATAGGTTAGATG_AACGAAAGTTCCAACTACTTTTGAAT': 0.0305628917870283,
#  'TGATCAATCTACAAAAATATTTAATG_GCGAGAAGGGTTAATGAACTTCAGCC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_CCGGGAAGAAAGAAACGGATTACTAG': 0.0569522108230221,
#  'TGATCAATCTACAAAAATATTTAATG_CCTTTAAACCAGAAATCAATTTTCCT': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GCCTGAATCTTTAAGCCGTTTAGGGA': 0.0532558343398763,
#  'CATTGAATCACAAAATAGGTTAGATG_TCATTAAGTTAGAAGCTGATTCTTTG': nan,
#  'TGATCAATCTACAAAAATATTTAATG_ATTACAACTCATAAGAATGTTTTGCG': 0.0447172331380674,
#  'TGATCAATCTACAAAAATATTTAATG_TTAGCAAAACTAAACTTACTTATAAA': 0.0458029054570765,
#  'CATTGAATCACAAAATAGGTTAGATG_ACGCAAACCACAAATGCCGTTAGAAG': 0.0285787187128782,
#  'TGATCAATCTACAAAAATATTTAATG_AGTTAAAGCATGAACCGATTTTTCCC': 0.0703003390998658,
#  'TGATCAATCTACAAAAATATTTAATG_ATCACAACCATAAAGGGAGTTTATGG': nan,
#  'TGATCAATCTACAAAAATATTTAATG_AGATCAATTAAGAATGAGATTTCAAG': 0.0433438053662026,
#  'CATTGAATCACAAAATAGGTTAGATG_AGCTTAATCCAAAACGACGTTATAAG': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GAGGTAAATACCAACCTATTTGTATA': 0.0352155344613461,
#  'CATTGAATCACAAAATAGGTTAGATG_TCGCTAACTAATAATGCTGTTTCAAT': 0.0459188548267115,
#  'CATTGAATCACAAAATAGGTTAGATG_GCTGGAAATGAGAAAGTCGTTTTGTC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GAAACAAGGCAGAAAACACTTCATAA': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_TTCAAAACATTCAAGGCTATTTCTCC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_ACACTAACTCTCAACTATTTAGTTT': 0.051133315970577,
#  'CATTGAATCACAAAATAGGTTAGATG_TTAAGAAAAAGAAAGGGTGTTGATGA': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_GTGACAATTTCCAAGGTTATTAGAAA': 0.079694991167155,
#  'TGATCAATCTACAAAAATATTTAATG_ACACAAAAAGTTAAGGTGGTTGAGCA': 0.0333504083845363,
#  'CATTGAATCACAAAATAGGTTAGATG_TTGATAACAAACAAAGCGATTACAAT': 0.0640924945915539,
#  'TGATCAATCTACAAAAATATTTAATG_CACGGAAGGTTGAACTCCGTTTCCCC': 0.0414605078399549,
#  'TGATCAATCTACAAAAATATTTAATG_CCGGAAAGCTGAAATATATTTTTTAT': 0.0807848631277788,
#  'CATTGAATCACAAAATAGGTTAGATG_TTAACAAAACAAAATTACATTCGAAG': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_TTGAAAACATGAAAAACGGTTGTCCA': nan,
#  'TGATCAATCTACAAAAATATTTAATG_ACGTAAATTAAAAAGCCAGTTCATCA': 0.0493160828482562,
#  'TGATCAATCTACAAAAATATTTAATG_TATATAAGATGCAATCCCTTTATGCG': 0.0486619506737789,
#  'CATTGAATCACAAAATAGGTTAGATG_TAAACAACATTTAATTACTTTCGAAT': 0.0423162157948952,
#  'TGATCAATCTACAAAAATATTTAATG_TACACAACGGGAAATGAAGTTTAACA': 0.0364445131350407,
#  'TGATCAATCTACAAAAATATTTAATG_GGCACAATGTGTAAGTTCTTTATTAG': 0.0509856027869612,
#  'CATTGAATCACAAAATAGGTTAGATG_GCCTTAAGTGCTAATCTCGTTGAGAC': 0.0403331301466039,
#  'TGATCAATCTACAAAAATATTTAATG_AGAGTAATTAGCAAATGAGTTTGCGT': 0.0394706650665449,
#  'TGATCAATCTACAAAAATATTTAATG_ACATCAATACGGAATCGCTTTATAAG': 0.0538369973480822,
#  'CATTGAATCACAAAATAGGTTAGATG_TTCTTAACCGCTAAAATCCTTTAGAT': 0.0322183058928282,
#  'CATTGAATCACAAAATAGGTTAGATG_ATCATAATTGTCAAGTCATTTATTAG': 0.0436684453823896,
#  'TGATCAATCTACAAAAATATTTAATG_GATTTAAAAGATAATATAATTTCGTT': 0.0455067449929274,
#  'CATTGAATCACAAAATAGGTTAGATG_CCTCCAATACCGAACACGGTTAATCT': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GTCACAAATGTTAATGGGTTTTATGT': 0.0420650463536512,
#  'CATTGAATCACAAAATAGGTTAGATG_GAGACAAGCCTTAATTGGGTTCTACG': 0.0645224675900196,
#  'TGATCAATCTACAAAAATATTTAATG_GCTAAAACATTAAAGCGGTTTAGAAA': 0.0414754642270454,
#  'CATTGAATCACAAAATAGGTTAGATG_GTTAAAATTTTTAAATATATTCTCAC': 0.0569447851729811,
#  'TGATCAATCTACAAAAATATTTAATG_ATTAGAAGCAAAAATTTCGTTTGAAG': 0.0451972842041587,
#  'CATTGAATCACAAAATAGGTTAGATG_AACTTAAAGCCTAAATCATTTCCTCT': 0.0387521080467758,
#  'TGATCAATCTACAAAAATATTTAATG_CTCTTAAACAGGAAATATATTATAGA': 0.0514043731474513,
#  'TGATCAATCTACAAAAATATTTAATG_CCCACAACGGCGAACTATATTTATTT': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_CTGATAAAATTAAAGTTCATTAATTT': 0.0468335028790002,
#  'CATTGAATCACAAAATAGGTTAGATG_CCACCAACGCGAAAGAGGCTTGGGAG': 0.0405053016758722,
#  'TGATCAATCTACAAAAATATTTAATG_ATTGGAAAACATAATGGGGTTCTGCG': nan,
#  'TGATCAATCTACAAAAATATTTAATG_CCAAAAACCGTCAAAAGGATTCAACT': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_CACCCAAACAAAAAAGGAGTTCTCAC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_GCAACAACTACCAAGTCGTTTGTGTT': nan,
#  'TGATCAATCTACAAAAATATTTAATG_TTCTCAAACTTGAATACAGTTCCGGG': 0.0505771868675996,
#  'CATTGAATCACAAAATAGGTTAGATG_TTTGTAATTTGTAAGCAATTTTTTAA': 0.0477614077315078,
#  'CATTGAATCACAAAATAGGTTAGATG_GCGTGAACGCAAAAGTGGGTTAGCTG': 0.0415779868419308,
#  'CATTGAATCACAAAATAGGTTAGATG_CTAGGAACATAGAAGGTTTTTGGATT': 0.0320037773764264,
#  'CATTGAATCACAAAATAGGTTAGATG_TTTGTAAGAGATAACGCTTTTGGTCC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_CTTCCAATATCGAACAGGTTTGCTAT': 0.0516901586382548,
#  'CATTGAATCACAAAATAGGTTAGATG_CAAGCAATAAATAAATAGCTTGTAGT': nan,
#  'TGATCAATCTACAAAAATATTTAATG_AACTGAAGACTAAATATGATTTCGGT': 0.078740997551304,
#  'TGATCAATCTACAAAAATATTTAATG_ATAGAAAACATGAAAATGGTTGGGTT': 0.0522883229302208,
#  'CATTGAATCACAAAATAGGTTAGATG_GGGCAAAATTTAAATTCGATTCTAGT': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_AGATAAAATTATAAATTGTTTCTGGC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_TTCGAAAGCAGCAAACTTTTTTCAAA': 0.037161492979682,
#  'CATTGAATCACAAAATAGGTTAGATG_GCGTGAAAGCCCAACAGGTTTAGGGA': 0.0776670306317297,
#  'TGATCAATCTACAAAAATATTTAATG_GGAAGAACACGCAATCAGGTTCCAAT': 0.0555489048863989,
#  'CATTGAATCACAAAATAGGTTAGATG_TGCGCAACGCCTAAGTAAATTTCGAA': 0.0416085277136763,
#  'CATTGAATCACAAAATAGGTTAGATG_GTTAAAACCCTTAATTCTTTTATGGT': 0.0406381202349969,
#  'CATTGAATCACAAAATAGGTTAGATG_CTCAAAAACAAAAATAAAATTGTTAC': 0.0572133891281407,
#  'TGATCAATCTACAAAAATATTTAATG_ATAACAACAGCGAAGGAGGTTAACCC': 0.0454802280528286,
#  'TGATCAATCTACAAAAATATTTAATG_TTGCAAATTGTGAAGAAACTTCAACC': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_TATGTAACAGAAAAAGAGGTTCCAAC': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_AAGGGAAGGGGGAAGGGGTTTGAAGC': 0.0469752371790471,
#  'TGATCAATCTACAAAAATATTTAATG_CTGTGAACGACCAATTAATTTCTACT': 0.0665940114547355,
#  'TGATCAATCTACAAAAATATTTAATG_CTCGTAACCTGGAATAGAATTGTCGG': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_GCTCTAATTTATAATACATTTAAGTA': 0.0427220069251882,
#  'TGATCAATCTACAAAAATATTTAATG_CTCTGAAACCTCAAGCGACTTAGTTG': 0.075573592860558,
#  'TGATCAATCTACAAAAATATTTAATG_ATGGGAAGCCGGAAGTCGGTTACGCA': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_TTAAGAATCACAAATAAATTTTCCCT': 0.0633077623622942,
#  'TGATCAATCTACAAAAATATTTAATG_ATAAGAAATGCGAACGCGATTTGCTG': nan,
#  'TGATCAATCTACAAAAATATTTAATG_TCCGCAAGACGGAATTTGGTTTGTTG': 0.0576210191704377,
#  'TGATCAATCTACAAAAATATTTAATG_AATTTAAACATTAATTCGTTTTTTAT': 0.0447280587679673,
#  'TGATCAATCTACAAAAATATTTAATG_CATAGAAAGGGCAATTCCGTTGGGGC': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_GTACCAATATACAATGCACTTTATCA': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_GAAGGAATGGTCAACGTCTTTACCAC': 0.0399752803917073,
#  'CATTGAATCACAAAATAGGTTAGATG_TATAGAAGCGTAAATCTTCTTTAGGC': 0.0541363971836785,
#  'CATTGAATCACAAAATAGGTTAGATG_CTGTCAAACGGGAAGGGGCTTTGAGG': 0.0365801601583794,
#  'TGATCAATCTACAAAAATATTTAATG_TTATTAAATGTAAAATAGGTTGCCTC': 0.0535997722712322,
#  'TGATCAATCTACAAAAATATTTAATG_GACAAAAACTACAATAGTCTTTTACC': 0.0530174770697827,
#  'CATTGAATCACAAAATAGGTTAGATG_TAAAAAACTTCGAAGTTGATTAGACT': 0.0383956416198623,
#  'CATTGAATCACAAAATAGGTTAGATG_TCTGTAATCATCAAATTAGTTATCAG': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_CCTTCAAATGAAAAGTGAATTTAGAA': 0.0504919944412608,
#  'CATTGAATCACAAAATAGGTTAGATG_CAAGGAAATACGAACTTACTTATGAC': 0.0694215315760932,
#  'CATTGAATCACAAAATAGGTTAGATG_CTCTTAATGATGAAGCGGTTTAGATT': 0.0549592009236113,
#  'CATTGAATCACAAAATAGGTTAGATG_AGACTAACATCGAACGCTTTTACACA': 0.0431879405837651,
#  'CATTGAATCACAAAATAGGTTAGATG_CCGAGAATACAGAATTTAATTTGTGT': 0.0416950951209976,
#  'TGATCAATCTACAAAAATATTTAATG_AAGGAAACCGATAAGGTGTTTTTTAC': 0.0497232926691489,
#  'TGATCAATCTACAAAAATATTTAATG_GATGCAAAAAATAAACCTTTTGGATC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_ATCAAAACTACCAATACTCTTTATTT': 0.0472695020523346,
#  'TGATCAATCTACAAAAATATTTAATG_GGGCCAAACTGTAACGTTCTTGGGGG': 0.0563338697797279,
#  'CATTGAATCACAAAATAGGTTAGATG_TAATTAACCGGCAATTTTGTTTAAGG': 0.038946916873351,
#  'TGATCAATCTACAAAAATATTTAATG_CAGATAATGATAAAATCCTTTACTAG': 0.0403794765045305,
#  'TGATCAATCTACAAAAATATTTAATG_GAAGAAATTGAGAAGGAACTTACATC': 0.051064640154315,
#  'TGATCAATCTACAAAAATATTTAATG_GAGCGAAAATTTAATACGGTTATGGG': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_ATCGTAAGCGTGAAAGGGTTTTTCTC': 0.0436287276290842,
#  'TGATCAATCTACAAAAATATTTAATG_GAGGGAATTTGGAAGGGGGTTTATGT': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_ATGTTAAAAAGGAAAGGCGTTGCCTG': 0.0331931695822309,
#  'CATTGAATCACAAAATAGGTTAGATG_TTCTCAACAATAAAACCCGTTGTGCT': 0.0398278745917172,
#  'TGATCAATCTACAAAAATATTTAATG_TTCAAAATGTGTAATTCGATTCTAGC': nan,
#  'TGATCAATCTACAAAAATATTTAATG_TTTTTAATACCTAAAGACCTTGCAGG': 0.0409940662022627,
#  'TGATCAATCTACAAAAATATTTAATG_CACATAATGCTTAACTGCTTTGGATC': 0.0579421661064434,
#  'CATTGAATCACAAAATAGGTTAGATG_AGATTAACACAGAATCTCGTTAGACC': 0.0471416987816325,
#  'TGATCAATCTACAAAAATATTTAATG_ACGACAATCTCGAATAGGTTTTTCTG': 0.0508153728375555,
#  'TGATCAATCTACAAAAATATTTAATG_TCAATAATAGTTAAGGTGATTTAGTT': nan,
#  'CATTGAATCACAAAATAGGTTAGATG_CATTTAACCGCAAAGGAATTTTGAAA': 0.0474772138131975,
#  'CATTGAATCACAAAATAGGTTAGATG_ATTATAAATCAGAATTGCGTTTGGCA': 0.0506104712167106,
#  'TGATCAATCTACAAAAATATTTAATG_TGATAAATACATAAAGTATTTCTTGA': 0.0545064808815123,
#  'TGATCAATCTACAAAAATATTTAATG_TCTTAAATACGGAATCCACTTGGTGA': nan,
#  'TGATCAATCTACAAAAATATTTAATG_AGCATAAAGGTAAAAATAGTTCGGCA': 0.0466437510828909,
#  'TGATCAATCTACAAAAATATTTAATG_TTGGCAAGTCGTAACATCGTTCGAGG': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TGCCCAATGCTTAATTCGATTATGGT': nan,
#  'TGATCAATCTACAAAAATATTTAATG_CGATCAAATCTTAAAAATTTTGCTAA': 0.048615268076746,
#  'TGATCAATCTACAAAAATATTTAATG_CCACTAAGCGTGAAGGCAGTTGGTGA': 0.0358681203801736,
#  'CATTGAATCACAAAATAGGTTAGATG_TGGACAATACCAAAGCTCCTTTGCCG': 0.0749960298505834,
#  'CATTGAATCACAAAATAGGTTAGATG_ATGACAACAGTGAATTCTATTCCTGT': 0.0436698192560463,
#  'CATTGAATCACAAAATAGGTTAGATG_TTGATAAAAACCAAATCAATTTACGG': 0.0396340085632169,
#  'TGATCAATCTACAAAAATATTTAATG_TGTGGAACGCAAAAGGAAATTCTTGC': 0.0516815913770251,
#  'TGATCAATCTACAAAAATATTTAATG_GAGTGAAACATGAATGGTATTCATCA': 0.0816817031537089,
#  'TGATCAATCTACAAAAATATTTAATG_CATAGAAAGAAAAAGTTTGTTCTGCC': 0.0376442858482516,
#  'TGATCAATCTACAAAAATATTTAATG_ATGAAAAGTTCTAAGGGAGTTTACTG': 0.0315161302981587,
#  'CCGCCAATCCCGAACCCCGTTTCGCC_ACTCTAACGTGTAACTAATTTTGAGT': 0.0392137440464963,
#  'GACAGAAAAGCCAAATGGATTTACCG_CGACAAATCCCGAAGAACTTTTTTTA': 0.0589242272431996,
#  'TTAAAAATACAAAAAAAGATTTAAGG_GCTAGAAAGACGAATGCCCTTGCGTC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CATCGAAACACTAAATATTTTAGCTC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CTTCCAACAAAAAATCATTTTTATAC': nan,
#  'AGAACAAAAACTAAACTCATTCATGG_AGTTAAATTGGGAAGGGTATTTTGAG': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCCACAAGCGGAAAGTTGCTTACGGC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_AGCAAAATAGTAAATCGGTTTCCTTA': nan,
#  'TTAAAAATACAAAAAAAGATTTAAGG_ACACGAATACCTAACTGTGTTCAGAT': nan,
#  'CCAACAAAAGGAAACGTATTTATTGA_TGGAGAAACCATAATAGCGTTTCGAA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_AGGTAAAACTGCAAGCCATTTAGTAC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TAATCAATACATAATGCATTTAAGAC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GTCTTAATTGGAAACGCAATTGAAAC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GCTTAAAATGTCAAAGCTGTTGGGAT': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TTGAAAAACCGTAATCTGTTTTTTAT': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GGGTCAACGACTAAGTGTCTTCCCCA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCATGAACGGATAAGCTGGTTGGTTG': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCACTAAGAAGGAAGTCCATTATTAC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CGAGCAAGCCGGAAGAGTCTTGCGAC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCGCCAACAATTAACTCGATTACGGC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CAGTAAACTCTAAATCGCATTAAAGT': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_AACTAAACAAGTAAAGGCTTTGGTGT': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_AGCCAAAAAAGTAATATTTTTGACCA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GACAAAATAATGAAGTAAATTCGTGG': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CAGGCAAGAGTGAAGGGCCTTGGTGC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TAAGAAACAATTAACAGGGTTTGGTA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCCATAATTGGGAATTGGATTTTGGC': 0.0964239413728551,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TTCTGAATTAGTAAGTTTCTTTGCAA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCGGCAACAGATAAGCTTCTTAACTT': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GGGGCAAGTGGGAAGAGGGTTGGGGA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_ATTACAACGCTCAACTAGGTTGGACC': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_GGCTGAAGAGGAAAACAAATTGATAA': nan,
#  'CGCTAAAGACATAATGTGGTTTGTTG_CCAAAAATAACTAAGTACATTTCAGG': nan}

# %%
evolution_fitness_all
# Out:
# {'CATTGAATCACAAAATAGGTTAGATG_CTAAAAACCTTAAATTAATTTCAAAT': {'Evo2D_Ira1_Mis_R2': 0.0428227913742537},
#  'CATTGAATCACAAAATAGGTTAGATG_TGTTAAACCCATAAATTCGTTTGGCG': {'Evo2D_Ira1_Mis_R2': 0.0479157797373039},
#  'CATTGAATCACAAAATAGGTTAGATG_CGGTAAACGGGAAACTTGCTTGGGGC': {'Evo2D_Ira1_Mis_R2': 0.0462686739544508},
#  'CATTGAATCACAAAATAGGTTAGATG_AATCTAACTTTGAAGGTTATTAATTT': {'Evo2D_Ira1_Mis_R2': 0.0437632761864294},
#  'TGATCAATCTACAAAAATATTTAATG_GGGCGAAACTGCAAGGCAGTTAGGCG': {'Evo2D_Ira1_Mis_R2': 0.0481690693292577},
#  'CATTGAATCACAAAATAGGTTAGATG_AACGAAAGTTCCAACTACTTTTGAAT': {'Evo2D_Ira1_Mis_R2': 0.0305628917870283},
#  'TGATCAATCTACAAAAATATTTAATG_CCGGGAAGAAAGAAACGGATTACTAG': {'Evo2D_Ira1_Mis_R2': 0.0569522108230221},
#  'TGATCAATCTACAAAAATATTTAATG_GCCTGAATCTTTAAGCCGTTTAGGGA': {'Evo2D_Ira1_Mis_R2': 0.0532558343398763},
#  'TGATCAATCTACAAAAATATTTAATG_ATTACAACTCATAAGAATGTTTTGCG': {'Evo2D_Ira1_Mis_R2': 0.0447172331380674},
#  'TGATCAATCTACAAAAATATTTAATG_TTAGCAAAACTAAACTTACTTATAAA': {'Evo2D_Ira1_Mis_R2': 0.0458029054570765},
#  'CATTGAATCACAAAATAGGTTAGATG_ACGCAAACCACAAATGCCGTTAGAAG': {'Evo2D_Ira1_Mis_R2': 0.0285787187128782},
#  'TGATCAATCTACAAAAATATTTAATG_AGTTAAAGCATGAACCGATTTTTCCC': {'Evo2D_Ira1_Mis_R2': 0.0703003390998658},
#  'TGATCAATCTACAAAAATATTTAATG_AGATCAATTAAGAATGAGATTTCAAG': {'Evo2D_Ira1_Mis_R2': 0.0433438053662026},
#  'TGATCAATCTACAAAAATATTTAATG_GAGGTAAATACCAACCTATTTGTATA': {'Evo2D_Ira1_Mis_R2': 0.0352155344613461},
#  'CATTGAATCACAAAATAGGTTAGATG_TCGCTAACTAATAATGCTGTTTCAAT': {'Evo2D_Ira1_Mis_R2': 0.0459188548267115},
#  'TGATCAATCTACAAAAATATTTAATG_ACACTAACTCTCAACTATTTAGTTT': {'Evo2D_Ira1_Mis_R2': 0.051133315970577},
#  'CATTGAATCACAAAATAGGTTAGATG_GTGACAATTTCCAAGGTTATTAGAAA': {'Evo2D_Ira1_Mis_R2': 0.079694991167155},
#  'TGATCAATCTACAAAAATATTTAATG_ACACAAAAAGTTAAGGTGGTTGAGCA': {'Evo2D_Ira1_Mis_R2': 0.0333504083845363},
#  'CATTGAATCACAAAATAGGTTAGATG_TTGATAACAAACAAAGCGATTACAAT': {'Evo2D_Ira1_Mis_R2': 0.0640924945915539},
#  'TGATCAATCTACAAAAATATTTAATG_CACGGAAGGTTGAACTCCGTTTCCCC': {'Evo2D_Ira1_Mis_R2': 0.0414605078399549},
#  'TGATCAATCTACAAAAATATTTAATG_CCGGAAAGCTGAAATATATTTTTTAT': {'Evo2D_Ira1_Mis_R2': 0.0807848631277788},
#  'TGATCAATCTACAAAAATATTTAATG_ACGTAAATTAAAAAGCCAGTTCATCA': {'Evo2D_Ira1_Mis_R2': 0.0493160828482562},
#  'TGATCAATCTACAAAAATATTTAATG_TATATAAGATGCAATCCCTTTATGCG': {'Evo2D_Ira1_Mis_R2': 0.0486619506737789},
#  'CATTGAATCACAAAATAGGTTAGATG_TAAACAACATTTAATTACTTTCGAAT': {'Evo2D_Ira1_Mis_R2': 0.0423162157948952},
#  'TGATCAATCTACAAAAATATTTAATG_TACACAACGGGAAATGAAGTTTAACA': {'Evo2D_Ira1_Mis_R2': 0.0364445131350407},
#  'TGATCAATCTACAAAAATATTTAATG_GGCACAATGTGTAAGTTCTTTATTAG': {'Evo2D_Ira1_Mis_R2': 0.0509856027869612},
#  'CATTGAATCACAAAATAGGTTAGATG_GCCTTAAGTGCTAATCTCGTTGAGAC': {'Evo2D_Ira1_Mis_R2': 0.0403331301466039},
#  'TGATCAATCTACAAAAATATTTAATG_AGAGTAATTAGCAAATGAGTTTGCGT': {'Evo2D_Ira1_Mis_R2': 0.0394706650665449},
#  'TGATCAATCTACAAAAATATTTAATG_ACATCAATACGGAATCGCTTTATAAG': {'Evo2D_Ira1_Mis_R2': 0.0538369973480822},
#  'CATTGAATCACAAAATAGGTTAGATG_TTCTTAACCGCTAAAATCCTTTAGAT': {'Evo2D_Ira1_Mis_R2': 0.0322183058928282},
#  'CATTGAATCACAAAATAGGTTAGATG_ATCATAATTGTCAAGTCATTTATTAG': {'Evo2D_Ira1_Mis_R2': 0.0436684453823896},
#  'TGATCAATCTACAAAAATATTTAATG_GATTTAAAAGATAATATAATTTCGTT': {'Evo2D_Ira1_Mis_R2': 0.0455067449929274},
#  'TGATCAATCTACAAAAATATTTAATG_GTCACAAATGTTAATGGGTTTTATGT': {'Evo2D_Ira1_Mis_R2': 0.0420650463536512},
#  'CATTGAATCACAAAATAGGTTAGATG_GAGACAAGCCTTAATTGGGTTCTACG': {'Evo2D_Ira1_Mis_R2': 0.0645224675900196},
#  'TGATCAATCTACAAAAATATTTAATG_GCTAAAACATTAAAGCGGTTTAGAAA': {'Evo2D_Ira1_Mis_R2': 0.0414754642270454},
#  'CATTGAATCACAAAATAGGTTAGATG_GTTAAAATTTTTAAATATATTCTCAC': {'Evo2D_Ira1_Mis_R2': 0.0569447851729811},
#  'TGATCAATCTACAAAAATATTTAATG_ATTAGAAGCAAAAATTTCGTTTGAAG': {'Evo2D_Ira1_Mis_R2': 0.0451972842041587},
#  'CATTGAATCACAAAATAGGTTAGATG_AACTTAAAGCCTAAATCATTTCCTCT': {'Evo2D_Ira1_Mis_R2': 0.0387521080467758},
#  'TGATCAATCTACAAAAATATTTAATG_CTCTTAAACAGGAAATATATTATAGA': {'Evo2D_Ira1_Mis_R2': 0.0514043731474513},
#  'CATTGAATCACAAAATAGGTTAGATG_CTGATAAAATTAAAGTTCATTAATTT': {'Evo2D_Ira1_Mis_R2': 0.0468335028790002},
#  'CATTGAATCACAAAATAGGTTAGATG_CCACCAACGCGAAAGAGGCTTGGGAG': {'Evo2D_Ira1_Mis_R2': 0.0405053016758722},
#  'TGATCAATCTACAAAAATATTTAATG_TTCTCAAACTTGAATACAGTTCCGGG': {'Evo2D_Ira1_Mis_R2': 0.0505771868675996},
#  'CATTGAATCACAAAATAGGTTAGATG_TTTGTAATTTGTAAGCAATTTTTTAA': {'Evo2D_Ira1_Mis_R2': 0.0477614077315078},
#  'CATTGAATCACAAAATAGGTTAGATG_GCGTGAACGCAAAAGTGGGTTAGCTG': {'Evo2D_Ira1_Mis_R2': 0.0415779868419308},
#  'CATTGAATCACAAAATAGGTTAGATG_CTAGGAACATAGAAGGTTTTTGGATT': {'Evo2D_Ira1_Mis_R2': 0.0320037773764264},
#  'TGATCAATCTACAAAAATATTTAATG_CTTCCAATATCGAACAGGTTTGCTAT': {'Evo2D_Ira1_Mis_R2': 0.0516901586382548},
#  'TGATCAATCTACAAAAATATTTAATG_AACTGAAGACTAAATATGATTTCGGT': {'Evo2D_Ira1_Mis_R2': 0.078740997551304},
#  'TGATCAATCTACAAAAATATTTAATG_ATAGAAAACATGAAAATGGTTGGGTT': {'Evo2D_Ira1_Mis_R2': 0.0522883229302208},
#  'TGATCAATCTACAAAAATATTTAATG_TTCGAAAGCAGCAAACTTTTTTCAAA': {'Evo2D_Ira1_Mis_R2': 0.037161492979682},
#  'CATTGAATCACAAAATAGGTTAGATG_GCGTGAAAGCCCAACAGGTTTAGGGA': {'Evo2D_Ira1_Mis_R2': 0.0776670306317297},
#  'TGATCAATCTACAAAAATATTTAATG_GGAAGAACACGCAATCAGGTTCCAAT': {'Evo2D_Ira1_Mis_R2': 0.0555489048863989},
#  'CATTGAATCACAAAATAGGTTAGATG_TGCGCAACGCCTAAGTAAATTTCGAA': {'Evo2D_Ira1_Mis_R2': 0.0416085277136763},
#  'CATTGAATCACAAAATAGGTTAGATG_GTTAAAACCCTTAATTCTTTTATGGT': {'Evo2D_Ira1_Mis_R2': 0.0406381202349969},
#  'CATTGAATCACAAAATAGGTTAGATG_CTCAAAAACAAAAATAAAATTGTTAC': {'Evo2D_Ira1_Mis_R2': 0.0572133891281407},
#  'TGATCAATCTACAAAAATATTTAATG_ATAACAACAGCGAAGGAGGTTAACCC': {'Evo2D_Ira1_Mis_R2': 0.0454802280528286},
#  'CATTGAATCACAAAATAGGTTAGATG_AAGGGAAGGGGGAAGGGGTTTGAAGC': {'Evo2D_Ira1_Mis_R2': 0.0469752371790471},
#  'TGATCAATCTACAAAAATATTTAATG_CTGTGAACGACCAATTAATTTCTACT': {'Evo2D_Ira1_Mis_R2': 0.0665940114547355},
#  'CATTGAATCACAAAATAGGTTAGATG_GCTCTAATTTATAATACATTTAAGTA': {'Evo2D_Ira1_Mis_R2': 0.0427220069251882},
#  'TGATCAATCTACAAAAATATTTAATG_CTCTGAAACCTCAAGCGACTTAGTTG': {'Evo2D_Ira1_Mis_R2': 0.075573592860558},
#  'CATTGAATCACAAAATAGGTTAGATG_TTAAGAATCACAAATAAATTTTCCCT': {'Evo2D_Ira1_Mis_R2': 0.0633077623622942},
#  'TGATCAATCTACAAAAATATTTAATG_TCCGCAAGACGGAATTTGGTTTGTTG': {'Evo2D_Ira1_Mis_R2': 0.0576210191704377},
#  'TGATCAATCTACAAAAATATTTAATG_AATTTAAACATTAATTCGTTTTTTAT': {'Evo2D_Ira1_Mis_R2': 0.0447280587679673},
#  'CATTGAATCACAAAATAGGTTAGATG_GAAGGAATGGTCAACGTCTTTACCAC': {'Evo2D_Ira1_Mis_R2': 0.0399752803917073},
#  'CATTGAATCACAAAATAGGTTAGATG_TATAGAAGCGTAAATCTTCTTTAGGC': {'Evo2D_Ira1_Mis_R2': 0.0541363971836785},
#  'CATTGAATCACAAAATAGGTTAGATG_CTGTCAAACGGGAAGGGGCTTTGAGG': {'Evo2D_Ira1_Mis_R2': 0.0365801601583794},
#  'TGATCAATCTACAAAAATATTTAATG_TTATTAAATGTAAAATAGGTTGCCTC': {'Evo2D_Ira1_Mis_R2': 0.0535997722712322},
#  'TGATCAATCTACAAAAATATTTAATG_GACAAAAACTACAATAGTCTTTTACC': {'Evo2D_Ira1_Mis_R2': 0.0530174770697827},
#  'CATTGAATCACAAAATAGGTTAGATG_TAAAAAACTTCGAAGTTGATTAGACT': {'Evo2D_Ira1_Mis_R2': 0.0383956416198623},
#  'CATTGAATCACAAAATAGGTTAGATG_CCTTCAAATGAAAAGTGAATTTAGAA': {'Evo2D_Ira1_Mis_R2': 0.0504919944412608},
#  'CATTGAATCACAAAATAGGTTAGATG_CAAGGAAATACGAACTTACTTATGAC': {'Evo2D_Ira1_Mis_R2': 0.0694215315760932},
#  'CATTGAATCACAAAATAGGTTAGATG_CTCTTAATGATGAAGCGGTTTAGATT': {'Evo2D_Ira1_Mis_R2': 0.0549592009236113},
#  'CATTGAATCACAAAATAGGTTAGATG_AGACTAACATCGAACGCTTTTACACA': {'Evo2D_Ira1_Mis_R2': 0.0431879405837651},
#  'CATTGAATCACAAAATAGGTTAGATG_CCGAGAATACAGAATTTAATTTGTGT': {'Evo2D_Ira1_Mis_R2': 0.0416950951209976},
#  'TGATCAATCTACAAAAATATTTAATG_AAGGAAACCGATAAGGTGTTTTTTAC': {'Evo2D_Ira1_Mis_R2': 0.0497232926691489},
#  'TGATCAATCTACAAAAATATTTAATG_ATCAAAACTACCAATACTCTTTATTT': {'Evo2D_Ira1_Mis_R2': 0.0472695020523346},
#  'TGATCAATCTACAAAAATATTTAATG_GGGCCAAACTGTAACGTTCTTGGGGG': {'Evo2D_Ira1_Mis_R2': 0.0563338697797279},
#  'CATTGAATCACAAAATAGGTTAGATG_TAATTAACCGGCAATTTTGTTTAAGG': {'Evo2D_Ira1_Mis_R2': 0.038946916873351},
#  'TGATCAATCTACAAAAATATTTAATG_CAGATAATGATAAAATCCTTTACTAG': {'Evo2D_Ira1_Mis_R2': 0.0403794765045305},
#  'TGATCAATCTACAAAAATATTTAATG_GAAGAAATTGAGAAGGAACTTACATC': {'Evo2D_Ira1_Mis_R2': 0.051064640154315},
#  'CATTGAATCACAAAATAGGTTAGATG_ATCGTAAGCGTGAAAGGGTTTTTCTC': {'Evo2D_Ira1_Mis_R2': 0.0436287276290842},
#  'CATTGAATCACAAAATAGGTTAGATG_ATGTTAAAAAGGAAAGGCGTTGCCTG': {'Evo2D_Ira1_Mis_R2': 0.0331931695822309},
#  'CATTGAATCACAAAATAGGTTAGATG_TTCTCAACAATAAAACCCGTTGTGCT': {'Evo2D_Ira1_Mis_R2': 0.0398278745917172},
#  'TGATCAATCTACAAAAATATTTAATG_TTTTTAATACCTAAAGACCTTGCAGG': {'Evo2D_Ira1_Mis_R2': 0.0409940662022627},
#  'TGATCAATCTACAAAAATATTTAATG_CACATAATGCTTAACTGCTTTGGATC': {'Evo2D_Ira1_Mis_R2': 0.0579421661064434},
#  'CATTGAATCACAAAATAGGTTAGATG_AGATTAACACAGAATCTCGTTAGACC': {'Evo2D_Ira1_Mis_R2': 0.0471416987816325},
#  'TGATCAATCTACAAAAATATTTAATG_ACGACAATCTCGAATAGGTTTTTCTG': {'Evo2D_Ira1_Mis_R2': 0.0508153728375555},
#  'CATTGAATCACAAAATAGGTTAGATG_CATTTAACCGCAAAGGAATTTTGAAA': {'Evo2D_Ira1_Mis_R2': 0.0474772138131975},
#  'CATTGAATCACAAAATAGGTTAGATG_ATTATAAATCAGAATTGCGTTTGGCA': {'Evo2D_Ira1_Mis_R2': 0.0506104712167106},
#  'TGATCAATCTACAAAAATATTTAATG_TGATAAATACATAAAGTATTTCTTGA': {'Evo2D_Ira1_Mis_R2': 0.0545064808815123},
#  'TGATCAATCTACAAAAATATTTAATG_AGCATAAAGGTAAAAATAGTTCGGCA': {'Evo2D_Ira1_Mis_R2': 0.0466437510828909},
#  'TGATCAATCTACAAAAATATTTAATG_CGATCAAATCTTAAAAATTTTGCTAA': {'Evo2D_Ira1_Mis_R2': 0.048615268076746},
#  'TGATCAATCTACAAAAATATTTAATG_CCACTAAGCGTGAAGGCAGTTGGTGA': {'Evo2D_Ira1_Mis_R2': 0.0358681203801736},
#  'CATTGAATCACAAAATAGGTTAGATG_TGGACAATACCAAAGCTCCTTTGCCG': {'Evo2D_Ira1_Mis_R2': 0.0749960298505834},
#  'CATTGAATCACAAAATAGGTTAGATG_ATGACAACAGTGAATTCTATTCCTGT': {'Evo2D_Ira1_Mis_R2': 0.0436698192560463},
#  'CATTGAATCACAAAATAGGTTAGATG_TTGATAAAAACCAAATCAATTTACGG': {'Evo2D_Ira1_Mis_R2': 0.0396340085632169},
#  'TGATCAATCTACAAAAATATTTAATG_TGTGGAACGCAAAAGGAAATTCTTGC': {'Evo2D_Ira1_Mis_R2': 0.0516815913770251},
#  'TGATCAATCTACAAAAATATTTAATG_GAGTGAAACATGAATGGTATTCATCA': {'Evo2D_Ira1_Mis_R2': 0.0816817031537089},
#  'TGATCAATCTACAAAAATATTTAATG_CATAGAAAGAAAAAGTTTGTTCTGCC': {'Evo2D_Ira1_Mis_R2': 0.0376442858482516},
#  'TGATCAATCTACAAAAATATTTAATG_ATGAAAAGTTCTAAGGGAGTTTACTG': {'Evo2D_Ira1_Mis_R2': 0.0315161302981587},
#  'CCGCCAATCCCGAACCCCGTTTCGCC_ACTCTAACGTGTAACTAATTTTGAGT': {'Evo2D_Ira1_Mis_R1': 0.0392137440464963,
#   'Evo2D_Ira1_Mis_R2': 0.0},
#  'GACAGAAAAGCCAAATGGATTTACCG_CGACAAATCCCGAAGAACTTTTTTTA': {'Evo2D_Ira1_Mis_R1': 0.0589242272431996,
#   'Evo2D_Ira1_Mis_R2': 0.0},
#  'CGCTAAAGACATAATGTGGTTTGTTG_TCCATAATTGGGAATTGGATTTTGGC': {'Evo2D_Ira1_Mis_R1': 0.0,
#   'Evo2D_Ira1_Mis_R2': 0.0964239413728551}}

# %%
fitness = 'Fit2D_both2%5%_fitness'
fitness = 'Fit2D_early_fitness'


set_to_plot = remeasurement_data[(remeasurement_data['ancestor'].isin(['IRA1_MIS','IRA1_NON'])) & 
                   (remeasurement_data['class_new'].isin(['adaptive_haploid','high_fitness_diploids'])) & 
                                (remeasurement_data['evolution_condition']=='Evo2D')]


set_to_plot = remeasurement_data[
                   (remeasurement_data['class_new'].isin(['adaptive_haploid','high_fitness_diploids'])) & 
                                (remeasurement_data['evolution_condition']=='Evo2D')]


# this_df = p.DataFrame(
#                      {'barcode':set_to_plot['barcode'],
#                       'evolution_fitness':overlap_evo['Fitness'].values,
#                       'remeasured_fitness':overlap_fit[fitness].values-ancestor_fit,
#                       'FerPerHour_relative':overlap_fit['FerPerHour_relative'].values,
#                       'ResPerHour_relative':overlap_fit['ResPerHour_relative'].values})

# %%
import pingouin as pg

# %%
set_to_plot
# Out:
#       Fit1D-2%-R1_fitness  Fit1D-2%-R1_error  Fit1D-2%-R2_fitness
# 0                0.770538           0.056064             0.798667  \
# 1                0.938763           0.035535             1.009834
# 3                1.074590           0.049368             1.048208
# 10               0.754952           0.069179             0.733293
# 11               0.954536           0.048001             1.016103
# ...                   ...                ...                  ...
# 4959             2.059598           0.241756             0.747945
# 4982             0.613519           0.165061             0.627840
# 4987             0.565860           0.096155             0.651235
# 5004             1.107639           0.056887             1.162029
# 5017             0.617577           0.112687             0.712826
#
#       Fit1D-2%-R2_error  Fit1D-5%-R1_fitness  Fit1D-5%-R1_error
# 0              0.056490             0.793227           0.037792  \
# 1              0.036124             0.936852           0.024449
# 3              0.050017             0.913976           0.039413
# 10             0.071339             0.648263           0.048402
# 11             0.047771             0.975953           0.034040
# ...                 ...                  ...                ...
# 4959           0.184822             0.350479           0.160900
# 4982           0.192093             0.721715           0.131600
# 4987           0.098367             0.552731           0.071922
# 5004           0.060838             1.006517           0.043387
# 5017           0.120766             0.574083           0.088885
#
#       Fit1D-5%-R2_fitness  Fit1D-5%-R2_error  Fit2D-2%-R1_fitness
# 0                0.777312           0.034586             1.152181  \
# 1                0.940881           0.024295             1.721427
# 3                0.963205           0.035169             1.364335
# 10               0.673180           0.046180             0.982740
# 11               0.983339           0.030787             1.380704
# ...                   ...                ...                  ...
# 4959             0.409983           0.159029             0.398892
# 4982             0.557184           0.114920             0.755782
# 4987             0.567498           0.057465             0.616294
# 5004             1.102517           0.037567             1.092998
# 5017             0.720080           0.073909             0.616551
#
#       Fit2D-2%-R1_error  ...  Fit2D_both2%5%_fitness_relative
# 0              0.032200  ...                         0.500499  \
# 1              0.024800  ...                         1.042312
# 3              0.032921  ...                         0.475804
# 10             0.039512  ...                         0.323005
# 11             0.029268  ...                         0.518183
# ...                 ...  ...                              ...
# 4959           0.315192  ...                         0.359326
# 4982           0.171871  ...                         0.689655
# 4987           0.132032  ...                         0.584273
# 5004           0.060551  ...                         0.438916
# 5017           0.145207  ...                         0.042139
#
#       Fit2D_both2%5%_fitness_ancestor  Fit2D_early_fitness_relative
# 0                            0.677807                      1.490798  \
# 1                            0.624987                      1.888121
# 3                            0.901522                      0.926555
# 10                           0.677807                      1.661512
# 11                           0.901522                      1.235137
# ...                               ...                           ...
# 4959                         0.000000                      0.290578
# 4982                         0.000000                      1.123674
# 4987                         0.000000                      1.460944
# 5004                         0.641719                      0.959902
# 5017                         0.556667                      1.088711
#
#       Fit2D_early_fitness_ancestor  Fit3D_early_fitness_relative
# 0                         1.300109                      1.823799  \
# 1                         1.497699                      2.667791
# 3                         1.553199                      2.378539
# 10                        1.300109                      2.082873
# 11                        1.553199                      2.185454
# ...                            ...                           ...
# 4959                      0.000000                     -0.303907
# 4982                      0.000000                      0.496977
# 4987                      0.000000                      0.587150
# 5004                      1.564134                      1.029052
# 5017                      1.067288                      1.412209
#
#       Fit3D_early_fitness_ancestor  Fit5D_early_fitness_relative
# 0                         0.456141                      1.452134  \
# 1                         0.846150                      2.526322
# 3                        -0.844753                      1.924667
# 10                        0.456141                      2.091507
# 11                       -0.844753                     -1.509793
# ...                            ...                           ...
# 4959                      0.000000                     -0.676511
# 4982                      0.000000                     -1.315578
# 4987                      0.000000                      0.309251
# 5004                      0.914799                      0.601126
# 5017                      0.022317                      1.474727
#
#       Fit5D_early_fitness_ancestor  evolution_fitness
# 0                         0.340931           0.081682  \
# 1                         0.547042           0.039214
# 3                        -1.905910                NaN
# 10                        0.340931           0.080785
# 11                       -1.905910                NaN
# ...                            ...                ...
# 4959                      0.000000                NaN
# 4982                      0.000000                NaN
# 4987                      0.000000                NaN
# 5004                      0.481995                NaN
# 5017                      0.023241                NaN
#
#       isolated_evolution_condition
# 0                Evo2D_Ira1_Mis_R2
# 1                Evo2D_Ira1_Mis_R1
# 3                              NaN
# 10               Evo2D_Ira1_Mis_R2
# 11                             NaN
# ...                            ...
# 4959                           NaN
# 4982                           NaN
# 4987                           NaN
# 5004                           NaN
# 5017                           NaN
#
# [425 rows x 368 columns]

# %%
colors = [tools.find_mutation_color(gene) for gene in set_to_plot['gene'].values]

fig,axs = plt.subplots(ncols=2,figsize=(8,4))
axs[0].scatter(set_to_plot['Fit2D_early_fitness_relative'].values,8*set_to_plot['evolution_fitness'].values,c=colors)
# axs[0].plot([0,2],[0,2],'k--')
axs[1].scatter(set_to_plot['Fit2D_both2%5%_fitness_relative'].values,8*set_to_plot['evolution_fitness'].values,c=colors)
# axs[1].plot([0,1],[0,1],'k--')

# %%
indices_to_keep = np.argwhere(~np.isnan(set_to_plot['evolution_fitness'].values))

# %%
colors = [matplotlib.colors.to_hex(tools.find_mutation_color(gene)) for gene in set_to_plot['gene'].values]

# %%
colors
# Out:
# ['#808080',
#  '#bcbd22',
#  '#d62728',
#  '#d62728',
#  '#4682b4',
#  '#808080',
#  '#8c510a',
#  '#bcbd22',
#  '#808080',
#  '#00cdcd',
#  '#bf812d',
#  '#006d2c',
#  '#8c510a',
#  '#ffd700',
#  '#008080',
#  '#808080',
#  '#ff7f0e',
#  '#31a354',
#  '#006d2c',
#  '#808080',
#  '#008080',
#  '#808080',
#  '#808080',
#  '#00cdcd',
#  '#808080',
#  '#808080',
#  '#d62728',
#  '#808080',
#  '#808080',
#  '#006d2c',
#  '#d62728',
#  '#808080',
#  '#e377c2',
#  '#808080',
#  '#808080',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#00cdcd',
#  '#d62728',
#  '#808080',
#  '#08519c',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#8c510a',
#  '#808080',
#  '#808080',
#  '#2171b5',
#  '#54278f',
#  '#08519c',
#  '#808080',
#  '#ff7f0e',
#  '#2171b5',
#  '#006d2c',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#ffd700',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#008080',
#  '#808080',
#  '#4682b4',
#  '#8c510a',
#  '#808080',
#  '#8c510a',
#  '#808080',
#  '#8c510a',
#  '#8c510a',
#  '#006d2c',
#  '#808080',
#  '#808080',
#  '#bcbd22',
#  '#006d2c',
#  '#d62728',
#  '#08519c',
#  '#ffd700',
#  '#a50f15',
#  '#808080',
#  '#54278f',
#  '#08519c',
#  '#808080',
#  '#8c510a',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#2171b5',
#  '#006d2c',
#  '#008080',
#  '#2171b5',
#  '#808080',
#  '#d62728',
#  '#ff7f0e',
#  '#bf812d',
#  '#2171b5',
#  '#808080',
#  '#54278f',
#  '#bf812d',
#  '#ff7f0e',
#  '#008080',
#  '#ff7f0e',
#  '#808080',
#  '#d62728',
#  '#808080',
#  '#e377c2',
#  '#00cdcd',
#  '#808080',
#  '#808080',
#  '#ff7f0e',
#  '#2171b5',
#  '#4292c6',
#  '#808080',
#  '#31a354',
#  '#808080',
#  '#00cdcd',
#  '#808080',
#  '#808080',
#  '#d62728',
#  '#17becf',
#  '#54278f',
#  '#54278f',
#  '#808080',
#  '#bf812d',
#  '#4292c6',
#  '#808080',
#  '#808080',
#  '#af6f09',
#  '#a50f15',
#  '#bae4b3',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#bf812d',
#  '#08519c',
#  '#2171b5',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#08519c',
#  '#808080',
#  '#31a354',
#  '#808080',
#  '#2171b5',
#  '#006d2c',
#  '#bf812d',
#  '#8c510a',
#  '#808080',
#  '#54278f',
#  '#808080',
#  '#d62728',
#  '#4292c6',
#  '#008080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#a50f15',
#  '#d62728',
#  '#54278f',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#2171b5',
#  '#9ecae1',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#808080',
#  '#bf812d',
#  '#808080',
#  '#808080',
#  '#ff7f0e',
#  '#54278f',
#  '#8c510a',
#  '#08519c',
#  '#808080',
#  '#8c510a',
#  '#808080',
#  '#2171b5',
#  '#ff7f0e',
#  '#808080',
#  '#4292c6',
#  '#808080',
#  '#08519c',
#  '#008080',
#  '#31a354',
#  '#d62728',
#  '#bcbddc',
#  '#808080',
#  '#ff7f0e',
#  '#54278f',
#  '#2171b5',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#ffd700',
#  '#9ecae1',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#d62728',
#  '#54278f',
#  '#808080',
#  '#006d2c',
#  '#808080',
#  '#808080',
#  '#6baed6',
#  '#808080',
#  '#808080',
#  '#00cdcd',
#  '#bf812d',
#  '#2171b5',
#  '#808080',
#  '#bf812d',
#  '#08519c',
#  '#006d2c',
#  '#ff7f0e',
#  '#ff7f0e',
#  '#54278f',
#  '#ff7f0e',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#ff7f0e',
#  '#807dba',
#  '#e377c2',
#  '#808080',
#  '#2171b5',
#  '#4292c6',
#  '#ff7f0e',
#  '#2171b5',
#  '#808080',
#  '#808080',
#  '#8c510a',
#  '#ffd700',
#  '#808080',
#  '#808080',
#  '#006d2c',
#  '#2171b5',
#  '#54278f',
#  '#74c476',
#  '#807dba',
#  '#54278f',
#  '#808080',
#  '#54278f',
#  '#ffd700',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#ff7f0e',
#  '#ff7f0e',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#4292c6',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#006d2c',
#  '#808080',
#  '#08519c',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#74c476',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#4292c6',
#  '#808080',
#  '#ffd700',
#  '#bae4b3',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#008080',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#08519c',
#  '#808080',
#  '#bae4b3',
#  '#9ecae1',
#  '#006d2c',
#  '#808080',
#  '#ff7f0e',
#  '#808080',
#  '#08519c',
#  '#e377c2',
#  '#4292c6',
#  '#ffd700',
#  '#808080',
#  '#08519c',
#  '#ff7f0e',
#  '#ff7f0e',
#  '#54278f',
#  '#808080',
#  '#4292c6',
#  '#808080',
#  '#08519c',
#  '#fc9272',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#e377c2',
#  '#a50f15',
#  '#808080',
#  '#008080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#fc9272',
#  '#006d2c',
#  '#808080',
#  '#ff7f0e',
#  '#808080',
#  '#ff7f0e',
#  '#2171b5',
#  '#6baed6',
#  '#808080',
#  '#08519c',
#  '#08519c',
#  '#54278f',
#  '#808080',
#  '#006d2c',
#  '#808080',
#  '#54278f',
#  '#006d2c',
#  '#808080',
#  '#ff7f0e',
#  '#808080',
#  '#54278f',
#  '#54278f',
#  '#08519c',
#  '#006d2c',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#4292c6',
#  '#54278f',
#  '#ff7f0e',
#  '#08519c',
#  '#54278f',
#  '#08519c',
#  '#ffd700',
#  '#808080',
#  '#4292c6',
#  '#bae4b3',
#  '#08519c',
#  '#808080',
#  '#ff7f0e',
#  '#808080',
#  '#2171b5',
#  '#9ecae1',
#  '#08519c',
#  '#08519c',
#  '#006d2c',
#  '#808080',
#  '#08519c',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#54278f',
#  '#808080',
#  '#808080',
#  '#6baed6',
#  '#2171b5',
#  '#2171b5',
#  '#ff7f0e',
#  '#808080',
#  '#2171b5',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#808080',
#  '#08519c',
#  '#08519c',
#  '#08519c',
#  '#808080',
#  '#08519c',
#  '#08519c',
#  '#e377c2',
#  '#808080']

# %%
indices_to_keep = np.argwhere(~np.isnan(set_to_plot['evolution_fitness'].values)).flatten()


lr_x = pg.linear_regression(
                            set_to_plot['Fit2D_early_fitness_ancestor'].values[indices_to_keep],
                            set_to_plot['FerPerHour_relative'].values[indices_to_keep],
                            remove_na=True)
lr_y = pg.linear_regression(
                            set_to_plot['Fit2D_early_fitness_ancestor'].values[indices_to_keep],
                            set_to_plot['evolution_fitness'].values[indices_to_keep],
                            remove_na=True)

# lr_x = pg.linear_regression(
#                             set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)
# lr_y = pg.linear_regression(
#                             set_to_plot['evolution_fitness'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)

plt.scatter(lr_x.residuals_,lr_y.residuals_,c=np.asarray(colors)[indices_to_keep])


lr_partial = pg.linear_regression(lr_x.residuals_,lr_y.residuals_)
print(lr_partial)


plt.xlabel('Residuals of FerPerHour~Fit2D')
plt.ylabel('Residuals of EvoFitness~Fit2D')

pg.partial_corr(data=set_to_plot, x='FerPerHour_relative', y='evolution_fitness', covar=['Fit2D_early_fitness_relative'])
# Out:
#        names          coef        se             T      pval        r2
# 0  Intercept -3.048146e-17  0.001246 -2.446752e-14  1.000000  0.048054  \
# 1         x1  2.253169e-01  0.110077  2.046906e+00  0.043831  0.048054
#
#      adj_r2  CI[2.5%]  CI[97.5%]
# 0  0.036585 -0.002478   0.002478
# 1  0.036585  0.006379   0.444255
#           n        r         CI95%     p-val
# pearson  85  0.19972  [-0.02, 0.4]  0.068541

# %%
indices_to_keep = np.argwhere(~np.isnan(set_to_plot['evolution_fitness'].values)).flatten()


lr_x = pg.linear_regression(
                            set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            set_to_plot['ResPerHour_relative'].values[indices_to_keep],
                            remove_na=True)
lr_y = pg.linear_regression(
                            set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            set_to_plot['evolution_fitness'].values[indices_to_keep],
                            remove_na=True)

# lr_x = pg.linear_regression(
#                             set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)
# lr_y = pg.linear_regression(
#                             set_to_plot['evolution_fitness'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)

plt.scatter(lr_x.residuals_,lr_y.residuals_,c=np.asarray(colors)[indices_to_keep])


lr_partial = pg.linear_regression(lr_x.residuals_,lr_y.residuals_)
print(lr_partial)


plt.xlabel('Residuals of ResPerHour~Fit2D')
plt.ylabel('Residuals of EvoFitness~Fit2D')

pg.partial_corr(data=set_to_plot, x='ResPerHour_relative', y='evolution_fitness', covar=['Fit2D_early_fitness_relative'])
# Out:
#        names          coef        se             T      pval        r2
# 0  Intercept -2.257886e-18  0.001030 -2.192723e-15  1.000000  0.029159  \
# 1         x1 -2.389131e-01  0.151318 -1.578882e+00  0.118167  0.029159
#
#      adj_r2  CI[2.5%]  CI[97.5%]
# 0  0.017462 -0.002048   0.002048
# 1  0.017462 -0.539878   0.062052
#           n         r          CI95%     p-val
# pearson  85 -0.170759  [-0.37, 0.05]  0.120419

# %%
lr_fit2d = pg.linear_regression(
                            np.asarray([set_to_plot['FerPerHour_relative'].values[indices_to_keep],
                                set_to_plot['ResPerHour_relative'].values[indices_to_keep]]).swapaxes(0,1),
                            set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            remove_na=True)

lr_evo = pg.linear_regression(
                            np.asarray([set_to_plot['FerPerHour_relative'].values[indices_to_keep],
                                set_to_plot['ResPerHour_relative'].values[indices_to_keep]]).swapaxes(0,1),
                            8*set_to_plot['evolution_fitness'].values[indices_to_keep],
                            remove_na=True)

lr_evo_nointercept = pg.linear_regression(
                            np.asarray([set_to_plot['FerPerHour_relative'].values[indices_to_keep],
                                set_to_plot['ResPerHour_relative'].values[indices_to_keep]]).swapaxes(0,1),
                            8*set_to_plot['evolution_fitness'].values[indices_to_keep],
                            remove_na=True)
print(lr_fit2d)
print(lr_evo)

# plt.figure()
# plt.scatter(8*set_to_plot['evolution_fitness'].values[indices_to_keep]/(lr_evo.coef[1]+lr_evo.coef[2]),
#             lr_evo.coef[0]/(lr_evo.coef[1]+lr_evo.coef[1])+
#             lr_evo.coef[1]/(lr_evo.coef[1]+lr_evo.coef[2])*set_to_plot['FerPerHour_relative'].values[indices_to_keep]+
#             lr_evo.coef[2]/(lr_evo.coef[1]+lr_evo.coef[2])*set_to_plot['ResPerHour_relative'].values[indices_to_keep])

# plt.figure()



# fractions = [0.45,0.5,0.55,0.6,0.65,0.7,0.75]
fractions = np.linspace(0.2,0.8,100)

coef_sum = lr_evo.coef[1]+lr_evo.coef[2]

plt.figure(figsize=(4,4))

for fraction in fractions:
    
    estimates = lr_evo.coef[0]+\
            fraction*coef_sum*set_to_plot['FerPerHour_relative'].values[indices_to_keep]+\
            fraction*coef_sum*set_to_plot['ResPerHour_relative'].values[indices_to_keep]
    
#     plt.subplot(121)
#     plt.scatter(8*set_to_plot['evolution_fitness'].values[indices_to_keep],
#                 estimates
#             ,label=fraction,alpha=0.4)
    
#     plt.subplot(122),marker='.'
    plt.scatter(fraction,np.sum((8*set_to_plot['evolution_fitness'].values[indices_to_keep]-estimates)**2),color='k',marker='.')
    
coef_sum = lr_fit2d.coef[1]+lr_fit2d.coef[2]
for fraction in fractions:
#     plt.subplot(122)
    estimates = lr_fit2d.coef[0]+\
            fraction*coef_sum*set_to_plot['FerPerHour_relative'].values[indices_to_keep]+\
            fraction*coef_sum*set_to_plot['ResPerHour_relative'].values[indices_to_keep]
    plt.scatter(fraction,np.sum((set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep]-estimates)**2),color='r',marker='.')

plt.yscale('log')


# plt.figure(figsize=(12,4))
# plt.subplot(121)
# plt.scatter(set_to_plot['FerPerHour_relative'].values[indices_to_keep],
#             8*set_to_plot['evolution_fitness'].values[indices_to_keep]
#            )
# plt.subplot(122)
# plt.scatter(set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#             8*set_to_plot['evolution_fitness'].values[indices_to_keep]
#            )
# plt.subplot(123)
# plt.scatter(set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#             8*set_to_plot['evolution_fitness'].values[indices_to_keep]
#            )
# Out:
#        names       coef        se          T          pval        r2
# 0  Intercept   0.004525  0.012354   0.366263  7.151123e-01  0.991881  \
# 1         x1  15.642217  0.361436  43.277933  3.036163e-58  0.991881
# 2         x2  27.933900  0.294110  94.977873  1.218505e-85  0.991881
#
#      adj_r2   CI[2.5%]  CI[97.5%]
# 0  0.991683  -0.020051   0.029101
# 1  0.991683  14.923205  16.361229
# 2  0.991683  27.348822  28.518977
#        names      coef        se          T          pval        r2   adj_r2
# 0  Intercept  0.276958  0.022430  12.347867  2.124347e-20  0.456506  0.44325  \
# 1         x1  3.376571  0.656217   5.145511  1.789824e-06  0.456506  0.44325
# 2         x2  3.795101  0.533980   7.107202  3.971635e-10  0.456506  0.44325
#
#    CI[2.5%]  CI[97.5%]
# 0  0.232338   0.321578
# 1  2.071147   4.681995
# 2  2.732846   4.857357

# %%
# Out:
# 0    0.276958
# 1    3.376571
# 2    3.795101
# Name: coef, dtype: float64

# %%
indices_to_keep = np.argwhere(~np.isnan(set_to_plot['evolution_fitness'].values)).flatten()


# lr_x = pg.linear_regression(
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
#                             set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#                             remove_na=True)
lr_y = pg.linear_regression(
                            set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            set_to_plot['evolution_fitness'].values[indices_to_keep],
                            remove_na=True)

# lr_x = pg.linear_regression(
#                             set_to_plot['ResPerHour_relative'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)
# lr_y = pg.linear_regression(
#                             set_to_plot['evolution_fitness'].values[indices_to_keep],
#                             set_to_plot['Fit2D_early_fitness_relative'].values[indices_to_keep],
                            
#                             remove_na=True)

plt.scatter(set_to_plot['ResPerHour_relative'].values[indices_to_keep],lr_y.residuals_,c=np.asarray(colors)[indices_to_keep])


lr_partial = pg.linear_regression(set_to_plot['ResPerHour_relative'].values[indices_to_keep],lr_y.residuals_)
print(lr_partial)


plt.xlabel('Respiration Per Hour')
plt.ylabel('Residuals of EvoFitness~Fit2D')

pg.partial_corr(data=set_to_plot, x='ResPerHour_relative', y='evolution_fitness', covar=['Fit2D_early_fitness_relative'])
# Out:
#        names      coef        se         T      pval        r2    adj_r2  \
# 0  Intercept -0.000656  0.001723 -0.381013  0.703648  0.000947 -0.004666
# 1         x1  0.019699  0.047957  0.410772  0.681734  0.000947 -0.004666
#
#    CI[2.5%]  CI[97.5%]
# 0 -0.004056   0.002743
# 1 -0.074938   0.114336
# /var/folders/x6/q0wb9df97nj1wnk5c4t0k7840000gn/T/ipykernel_80659/2834578954.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   plt.scatter(set_to_plot['ResPerHour_relative'].values[indices_to_keep],lr_y.residuals_,c=np.asarray(colors)[indices_to_keep])
#            n         r          CI95%     p-val
# pearson  180  0.063843  [-0.08, 0.21]  0.395859

# %%
pg.partial_corr(data=set_to_plot, x='ResPerHour_relative', y='evolution_fitness', covar=['Fit2D_early_fitness_relative'])
# Out:
#            n         r          CI95%     p-val
# pearson  180  0.063843  [-0.08, 0.21]  0.395859

# %%
set_to_plot[['evolution_fitness',fitness+'_relative','Fit2D_both2%5%_fitness_relative','FerPerHour_relative','ResPerHour_relative']].pcorr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 set_to_plot[['evolution_fitness',fitness+'_relative','Fit2D_both2%5%_fitness_relative','FerPerHour_relative','ResPerHour_relative']].pcorr()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pcorr'

# %%
colors = [tools.find_mutation_color(gene) for gene in set_to_plot['gene'].values]

fig,axs = plt.subplots(ncols=2,figsize=(8,4))
axs[0].scatter(set_to_plot['Fit2D_early_fitness_relative'].values,8*set_to_plot['evolution_fitness'].values,c=colors)
axs[0].plot([0,2],[0,2],'k--')
axs[1].scatter(set_to_plot['Fit2D_both2%5%_fitness_relative'].values,8*set_to_plot['evolution_fitness'].values,c=colors)
axs[1].plot([0,1],[0,1],'k--')

# %%
fig,axs = plt.subplots(ncols=2,figsize=(8,4))
axs[0].scatter((set_to_plot['Fit2D_early_fitness']-set_to_plot['Fit2D_early_fitness_ancestor']),8*set_to_plot['evolution_fitness'],c=colors)
axs[1].scatter((set_to_plot['Fit2D_both2%5%_fitness']-set_to_plot['Fit2D_both2%5%_fitness_ancestor']),8*set_to_plot['evolution_fitness'],c=colors)

# %%
colors = [tools.find_mutation_color(gene) for gene in set_to_plot['gene'].values]

fig,axs = plt.subplots(ncols=3,figsize=(12,4))
axs[0].scatter(set_to_plot['FerPerHour_relative'],set_to_plot['evolution_fitness'],c=colors)

axs[1].scatter(set_to_plot['FerPerHour_relative'],set_to_plot[fitness+'_relative'],c=colors)

axs[2].scatter(8*set_to_plot['evolution_fitness'],set_to_plot[fitness+'_relative'],c=colors)

# %%
set_to_plot[['evolution_fitness',fitness+'_relative','FerPerHour_relative','ResPerHour_relative']].pcorr()
# Out:
#                               evolution_fitness  Fit2D_early_fitness_relative
# evolution_fitness                      1.000000                     -0.053788  \
# Fit2D_early_fitness_relative          -0.053788                      1.000000
# FerPerHour_relative                    0.097927                      0.950879
# ResPerHour_relative                    0.130828                      0.985882
#
#                               FerPerHour_relative  ResPerHour_relative
# evolution_fitness                        0.097927             0.130828
# Fit2D_early_fitness_relative             0.950879             0.985882
# FerPerHour_relative                      1.000000            -0.938205
# ResPerHour_relative                     -0.938205             1.000000

# %%
plt.scatter(set_to_plot['FerPerHour_relative'],set_to_plot['ResPerHour_relative'],c=colors)

# %%
fig,axs = plt.subplots(ncols=2,nrows=2)
axs[0,0].scatter(28*set_to_plot['ResPerHour_relative']+16*set_to_plot['FerPerHour_relative'],
            set_to_plot[fitness+'_relative'],c=colors)

axs[0,1].scatter(28*set_to_plot['ResPerHour_relative']+16*set_to_plot['FerPerHour_relative'],
            set_to_plot['Fit2D_both2%5%_fitness_relative'],c=colors)

axs[1,0].scatter(28*set_to_plot['ResPerHour_relative']+16*set_to_plot['FerPerHour_relative'],
            8*set_to_plot['evolution_fitness'],c=colors)

axs[1,1].scatter(set_to_plot[fitness+'_relative'],
            8*set_to_plot['evolution_fitness'],c=colors)

# %%
medium_fitness = set_to_plot[(set_to_plot['Fit2D_early_fitness_relative']>0.75) & (set_to_plot['Fit2D_early_fitness_relative']<1.25)]

# %%
fig,axs=plt.subplots(figsize=(12,4),ncols=3,nrows=1)

colors = [tools.find_mutation_color(gene) for gene in set_to_plot['gene'].values]

axs[0].scatter(set_to_plot['FerPerHour_relative'],set_to_plot['evolution_fitness'],c=colors)
axs[0].set_xlabel('FerPerHour relative')
axs[0].set_ylabel('Evolution Fitness')

axs[1].scatter(set_to_plot['FerPerHour_relative'],set_to_plot[fitness+'_relative'],c=colors)
axs[1].set_xlabel('FerPerHour relative')
axs[1].set_ylabel(fitness+'_relative')

axs[1].axhspan(0.75,1.25,alpha=0.2)



# for f,fitness_interval in [(-0.25,0.25),(0.25,0.75),(0.75,1.25)]
medium_fitness = set_to_plot[(set_to_plot['Fit2D_early_fitness_relative']>0.75) & 
                             (set_to_plot['Fit2D_early_fitness_relative']<1.25)]

colors = [tools.find_mutation_color(gene) for gene in medium_fitness['gene'].values]

axs[2].scatter(medium_fitness['FerPerHour_relative'],8*medium_fitness['evolution_fitness'],c=colors)

axs[2].set_ylabel('Evolution Fitness')
axs[2].set_xlabel('FerPerHour relative')



medium_fitness[['FerPerHour_relative','ResPerHour_relative','evolution_fitness']].pcorr()
# Out:
#                      FerPerHour_relative  ResPerHour_relative
# FerPerHour_relative             1.000000            -0.880477  \
# ResPerHour_relative            -0.880477             1.000000
# evolution_fitness               0.469002             0.416044
#
#                      evolution_fitness
# FerPerHour_relative           0.469002
# ResPerHour_relative           0.416044
# evolution_fitness             1.000000
