# %%
import numpy as np
import pandas as p

# %%
condition_properties = {'Evo1D_IRAs':{1:[0,1,4,7,10,13,16,19,22,24],
                                      2:[0,1,4,7,10,13,16,19,22,24]},
                        'Evo1D_TCG':{1:[0,1,4,8,10,13,16,19,22,24],
                                    2:[0,1,4,8,10,13,16,19,22,24]},
                        
                        'Evo2D_Ira1_Mis':{1:[0,1,4,7,10,13,17,21,25],
                                         2:[0,1,4,7,10,13,17,21,25]},
                        'Evo2D_Ira1_Non':{1:[0,1,4,7,10,13,17,21,25],
                                         2:[0,1,4,7,10,13,17,21,25]},
                        
                        'Evo3D_Ira1_Mis':{1:[0,1,4,7,10,14,17,21],
                                         2:[0,1,4,7,10,14,17,21],
                                         3:[0,1,4,7,10,14,17,21]},
                        'Evo3D_Ira1_Non':{1:[0,1,4,7,10,14,17,21],
                                         2:[0,1,4,7,10,14,17,21],
                                         3:[0,1,4,7,10,14,17,21]},
                        
                        'Evo3D_TCG':{1:[0,1,4,7,10,14,17,21],
                                         2:[0,1,4,7,10,14,17,21]},               
                       }


n_gens = 8

# %%
for condition,reps in condition_properties.items():
    this_data = p.read_csv(f'{condition}_counts_curated.csv')
    
    for rep,timepoints in reps.items():
        
        all_samples = []
        for time in timepoints:
            if time == 0:
                all_samples.append(f'{condition}_0_0_count')
            else:
                all_samples.append(f'{condition}_{rep}_{time}_count')
    
    pared_data = this_data[['fused_bc']+all_samples]
    pared_data.rename({f'{all_samples[t]}':n_gens*timepoints[t] for t in range(len(timepoints))})
    pared_data.rename({'fused_bc':'BC'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x6/q0wb9df97nj1wnk5c4t0k7840000gn/T/ipykernel_15571/1078529407.py in <module>
#      11                 all_samples.append(f'{condition}_{rep}_{time}_count')
#      12
# ---> 13     pared_data = this_data[['fused_bc']+all_samples]
#      14     pared_data.rename({f'{all_samples[t]}':n_gens*timepoints[t] for t in range(len(timepoints))})
#      15     pared_data.rename({'fused_bc':'BC'})
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Evo3D_TCG_2_14_count', 'Evo3D_TCG_2_17_count', 'Evo3D_TCG_2_21_count'] not in index"

# %%
this_data
# Out:
#                  high_diversity_BC            low_diversity_BC  \
# 0       AAACTAATTGGGAACACTTTTTAATG  GAAATAAACCACAACGACATTCTAAT
# 1       GCATAAATATCGAAGTCTCTTATTAG  GAAATAAACCACAACGACATTCTAAT
# 2       CCATTAATTTTCAATATTATTTTGGC  GAAATAAACCACAACGACATTCTAAT
# 3       GTGACAATATGAAACAGGATTTGACT  CATAAAAAGACTAATCTTATTAATGC
# 4       GTGTGAACAACTAAACGTGTTGTTGA  CATAAAAAGACTAATCTTATTAATGC
# ...                            ...                         ...
# 116599  CGATTAATCGGTAAATCCCTTGTATA  GAAATAAACCACAACGACATTCTAAT
# 116600  TTCTAAATAATCAATTATCTTGACAC  GAAATAAACCACAACGACATTCTAAT
# 116601   CGACAAATTATCAATCGATTTATAG  AATGCAATAATGAAATGATTTGAGGA
# 116602  CTGTTAAAAACGAAATTCGTTATACT  CGCTAAAGACATAATGTGGTTTGTTG
# 116603  AATGCAAAAATGAAATGTCTTTCGAT  CGCTAAAGACATAATGTGGTTTGTTG
#
#         Evo1D_IRAs_0_0_count  \
# 0                       15.0
# 1                       37.0
# 2                       25.0
# 3                       39.0
# 4                       11.0
# ...                      ...
# 116599                   0.0
# 116600                   0.0
# 116601                   0.0
# 116602                   0.0
# 116603                   0.0
#
#                                                  fused_bc  \
# 0       GAAATAAACCACAACGACATTCTAAT_AAACTAATTGGGAACACTT...
# 1       GAAATAAACCACAACGACATTCTAAT_GCATAAATATCGAAGTCTC...
# 2       GAAATAAACCACAACGACATTCTAAT_CCATTAATTTTCAATATTA...
# 3       CATAAAAAGACTAATCTTATTAATGC_GTGACAATATGAAACAGGA...
# 4       CATAAAAAGACTAATCTTATTAATGC_GTGTGAACAACTAAACGTG...
# ...                                                   ...
# 116599  GAAATAAACCACAACGACATTCTAAT_CGATTAATCGGTAAATCCC...
# 116600  GAAATAAACCACAACGACATTCTAAT_TTCTAAATAATCAATTATC...
# 116601  AATGCAATAATGAAATGATTTGAGGA_CGACAAATTATCAATCGAT...
# 116602  CGCTAAAGACATAATGTGGTTTGTTG_CTGTTAAAAACGAAATTCG...
# 116603  CGCTAAAGACATAATGTGGTTTGTTG_AATGCAAAAATGAAATGTC...
#
#         Evo1D_IRAs_1_1_count  Evo1D_IRAs_2_1_count  Evo1D_IRAs_1_4_count  \
# 0                       11.0                  14.0                   7.0
# 1                       26.0                  36.0                  23.0
# 2                       13.0                  20.0                  21.0
# 3                       46.0                  35.0                  52.0
# 4                       16.0                  22.0                  17.0
# ...                      ...                   ...                   ...
# 116599                   0.0                   0.0                   0.0
# 116600                   0.0                   0.0                   0.0
# 116601                   0.0                   0.0                   0.0
# 116602                   0.0                   0.0                   0.0
# 116603                   0.0                   0.0                   0.0
#
#         Evo1D_IRAs_2_4_count  Evo1D_IRAs_1_7_count  Evo1D_IRAs_2_7_count  ...  \
# 0                        6.0                   9.0                   9.0  ...
# 1                       33.0                  18.0                  41.0  ...
# 2                       25.0                  31.0                  32.0  ...
# 3                       36.0                  40.0                  33.0  ...
# 4                       23.0                  26.0                  16.0  ...
# ...                      ...                   ...                   ...  ...
# 116599                   0.0                   0.0                   0.0  ...
# 116600                   0.0                   0.0                   0.0  ...
# 116601                   0.0                   0.0                   0.0  ...
# 116602                   0.0                   0.0                   0.0  ...
# 116603                   0.0                   0.0                   0.0  ...
#
#         Evo1D_IRAs_1_13_count  Evo1D_IRAs_2_13_count  Evo1D_IRAs_1_16_count  \
# 0                        17.0                    6.0                   13.0
# 1                        14.0                   46.0                   20.0
# 2                        45.0                   59.0                   60.0
# 3                        14.0                   21.0                   16.0
# 4                         7.0                    7.0                    6.0
# ...                       ...                    ...                    ...
# 116599                    0.0                    0.0                    0.0
# 116600                    0.0                    0.0                    0.0
# 116601                    0.0                    0.0                    0.0
# 116602                    0.0                    0.0                    0.0
# 116603                    0.0                    0.0                    0.0
#
#         Evo1D_IRAs_2_16_count  Evo1D_IRAs_1_19_count  Evo1D_IRAs_2_19_count  \
# 0                        10.0                    9.0                    4.0
# 1                        12.0                   10.0                   16.0
# 2                        50.0                   37.0                   53.0
# 3                        16.0                    3.0                    7.0
# 4                         5.0                    1.0                    2.0
# ...                       ...                    ...                    ...
# 116599                    7.0                    5.0                    8.0
# 116600                    1.0                    2.0                    7.0
# 116601                    0.0                    4.0                    1.0
# 116602                    0.0                    3.0                    3.0
# 116603                    0.0                    2.0                    4.0
#
#         Evo1D_IRAs_1_22_count  Evo1D_IRAs_2_22_count  Evo1D_IRAs_1_24_count  \
# 0                         2.0                    0.0                    1.0
# 1                        10.0                   12.0                    3.0
# 2                        18.0                   30.0                   17.0
# 3                         2.0                    5.0                    0.0
# 4                         0.0                    3.0                    0.0
# ...                       ...                    ...                    ...
# 116599                    4.0                   15.0                    3.0
# 116600                    5.0                   11.0                    3.0
# 116601                   14.0                    4.0                   16.0
# 116602                    6.0                   16.0                    3.0
# 116603                    2.0                   13.0                    6.0
#
#         Evo1D_IRAs_2_24_count
# 0                         0.0
# 1                         2.0
# 2                        12.0
# 3                         2.0
# 4                         0.0
# ...                       ...
# 116599                    3.0
# 116600                    2.0
# 116601                    8.0
# 116602                    6.0
# 116603                    7.0
#
# [116604 rows x 22 columns]
